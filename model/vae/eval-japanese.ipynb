# %%
import argparse
import os
import random

import numpy as np
import pandas as pd
import torch
from tqdm.notebook import tqdm, trange
from transformers import BertJapaneseTokenizer

from eval import eval_vae
from trainer import VAETrainer
from utils import batch_to_device, get_harv_data_loader, get_squad_data_loader
from models import DiscreteVAE, return_mask_lengths

# %%
import collections
import json

from transformers import BertJapaneseTokenizer
from tqdm.notebook import tqdm

from qgevalcap.eval import eval_qg
from squad_utils import evaluate, write_predictions
from eval import Result, to_string

# %%
parser = argparse.ArgumentParser()
parser.add_argument("--seed", default=1004, type=int)
parser.add_argument('--debug', dest='debug', action='store_true')
parser.add_argument('--train_dir', default='../data/kosodate/train.json')
parser.add_argument('--dev_dir', default='../data/kosodate/test.json')

parser.add_argument("--max_c_len", default=384, type=int, help="max context length")
parser.add_argument("--max_q_len", default=64, type=int, help="max query length")

parser.add_argument("--model_dir", default="../save/vae-checkpoint-jp", type=str)
parser.add_argument("--epochs", default=30, type=int)
parser.add_argument("--lr", default=1e-3, type=float, help="lr")
parser.add_argument("--batch_size", default=32, type=int, help="batch_size")
parser.add_argument("--weight_decay", default=0.0, type=float, help="weight decay")
parser.add_argument("--clip", default=5.0, type=float, help="max grad norm")

parser.add_argument("--bert_model", default='cl-tohoku/bert-base-japanese-whole-word-masking', type=str)
parser.add_argument('--enc_nhidden', type=int, default=300)
parser.add_argument('--enc_nlayers', type=int, default=1)
parser.add_argument('--enc_dropout', type=float, default=0.2)
parser.add_argument('--dec_a_nhidden', type=int, default=300)
parser.add_argument('--dec_a_nlayers', type=int, default=1)
parser.add_argument('--dec_a_dropout', type=float, default=0.2)
parser.add_argument('--dec_q_nhidden', type=int, default=900)
parser.add_argument('--dec_q_nlayers', type=int, default=2)
parser.add_argument('--dec_q_dropout', type=float, default=0.3)
parser.add_argument('--nzqdim', type=int, default=50)
parser.add_argument('--nza', type=int, default=20)
parser.add_argument('--nzadim', type=int, default=10)
parser.add_argument('--lambda_kl', type=float, default=0.1)
parser.add_argument('--lambda_info', type=float, default=1.0)

args = parser.parse_args([])

# %%
torch.backends.cudnn.benchmark = False
torch.backends.cudnn.enabled = False

# %%
if args.debug:
    args.model_dir = "./dummy"
# set model dir
model_dir = args.model_dir
os.makedirs(model_dir, exist_ok=True)
args.model_dir = os.path.abspath(model_dir)

random.seed(args.seed)
np.random.seed(args.seed)
torch.manual_seed(args.seed)
torch.cuda.manual_seed(args.seed)

# %%
tokenizer = BertJapaneseTokenizer.from_pretrained(args.bert_model)
train_data = get_squad_data_loader(tokenizer, args.train_dir,
                                     shuffle=False, args=args)
eval_data = get_squad_data_loader(tokenizer, args.dev_dir,
                                  shuffle=False, args=args)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  8.47it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████| 593/593 [00:03<00:00, 155.97it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 66.67it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████| 67/67 [00:00<00:00, 270.14it/s]

# %%
args.device = torch.cuda.current_device()
args.device = 'cuda:1' if torch.cuda.is_available() else 'cpu'
print(args.device)
# Out:
# cuda:1

# %%
trainer = VAETrainer(args)

# %%
vae = DiscreteVAE(args).to(args.device)

# %%
vae.load_state_dict(torch.load(os.path.join(args.model_dir, "best_f1_model.pt"))['state_dict'])
# Out:
# <All keys matched successfully>

# %%
trainer.vae = vae

# %%
RawResult = collections.namedtuple("RawResult", ["unique_id", "start_logits", "end_logits"])

# %% [markdown]
# ## evalデータで検証

# %%
eval_loader, eval_examples, eval_features = eval_data

# %%
all_results = []
qa_results = []
qg_results = {}
res_dict = {}
example_index = -1
qa_posterior_pair = []
qa_prior_pair = []

# %%
for batch in tqdm(eval_loader, desc="Eval iter", leave=False, position=4):
    c_ids, q_ids, a_ids, start, end = batch_to_device(batch, args.device)
    batch_size = c_ids.size(0)
    batch_c_ids = c_ids.cpu().tolist()
    batch_q_ids = q_ids.cpu().tolist()
    batch_start = start.cpu().tolist()
    batch_end = end.cpu().tolist()

    batch_posterior_q_ids, \
    batch_posterior_start, batch_posterior_end, \
    posterior_z_prob = trainer.generate_posterior(c_ids, q_ids, a_ids)

    batch_start_logits, batch_end_logits \
    = trainer.generate_answer_logits(c_ids, q_ids, a_ids)

    batch_posterior_q_ids, \
    batch_posterior_start, batch_posterior_end = \
    batch_posterior_q_ids.cpu().tolist(), \
    batch_posterior_start.cpu().tolist(), batch_posterior_end.cpu().tolist()
    posterior_z_prob = posterior_z_prob.cpu()

    batch_prior_q_ids, \
    batch_prior_start, batch_prior_end, \
    prior_z_prob = trainer.generate_prior(c_ids)

    batch_prior_q_ids, \
    batch_prior_start, batch_prior_end = \
    batch_prior_q_ids.cpu().tolist(), \
    batch_prior_start.cpu().tolist(), batch_prior_end.cpu().tolist()
    prior_z_prob = prior_z_prob.cpu()
    
    for i in range(batch_size):
        example_index += 1
        start_logits = batch_start_logits[i].detach().cpu().tolist()
        end_logits = batch_end_logits[i].detach().cpu().tolist()
        eval_feature = eval_features[example_index]
        unique_id = int(eval_feature.unique_id)

        context = to_string(batch_c_ids[i], tokenizer)

        real_question = to_string(batch_q_ids[i], tokenizer)
        posterior_question = to_string(batch_posterior_q_ids[i], tokenizer)
        prior_question = to_string(batch_prior_q_ids[i], tokenizer)

        real_answer = to_string(batch_c_ids[i][batch_start[i]:(batch_end[i] + 1)], tokenizer)
        posterior_answer = to_string(batch_c_ids[i][batch_posterior_start[i]:(batch_posterior_end[i] + 1)], tokenizer)
        prior_answer = to_string(batch_c_ids[i][batch_prior_start[i]:(batch_prior_end[i] + 1)], tokenizer)

        all_results.append(Result(context=context,
                                  real_question=real_question,
                                  posterior_question=posterior_question,
                                  prior_question=prior_question,
                                  real_answer=real_answer,
                                  posterior_answer=posterior_answer,
                                  prior_answer=prior_answer,
                                  posterior_z_prob=posterior_z_prob[i],
                                  prior_z_prob=prior_z_prob[i]))
        
        qa_prior_pair.append([prior_question, prior_answer])
        qa_posterior_pair.append([posterior_question, posterior_answer])

        qg_results[unique_id] = posterior_question
        res_dict[unique_id] = real_question
        qa_results.append(RawResult(unique_id=unique_id,
                                    start_logits=start_logits,
                                    end_logits=end_logits))
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Eval iter', max=3.0, style=ProgressStyle(description_widt…

# %%
output_prediction_file = os.path.join(args.model_dir, "pred.json")
write_predictions(eval_examples, eval_features, qa_results, n_best_size=20,
                  max_answer_length=100, do_lower_case=True, 
                  output_prediction_file=output_prediction_file,
                  verbose_logging=False,
                  version_2_with_negative=False,
                  null_score_diff_threshold=0,
                  noq_position=True)

# %%
with open(args.dev_dir, "r", encoding='utf-8') as f:
    dataset_json = json.load(f)
    dataset = dataset_json["data"]
with open(os.path.join(args.model_dir, "pred.json")) as prediction_file:
    predictions = json.load(prediction_file)

# %%
predictions['000']
# Out:
# '窓口 で 妊娠 届 を ご 記入 いただ ##き 、 母子 手帳 を お 渡し し ます 。 住民 票 の 世帯 が 別 の 方 が 代理 で 窓口 に 来 ##ら れる 場合 は 、 委任 状 が 必要 に なり ます 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR ##L )'

# %% [markdown]
# ### prior: (C) -> (C, Zq, Za) -> (Q, A)

# %%
for pair in qa_prior_pair: 
    print(pair[0])
    print(pair[1], '\n')
# Out:
# 母子 手帳 の 他 に 窓口 し まし た が 、 母子 手帳 の 他 に 窓口 に 必要 です か ?
# 窓口 で 妊娠 届 を ご 記入 い た だ き 、 母子 手帳 を お 渡し し ます 。 住民 票 の 世帯 が 別 の 方 が 代理 で 窓口 に 来 ら れる 場合 は 、 委任 状 が 必要 に なり ます 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# ● ● 県内 で 引っ越し たら 、 子ども の 受 診 票 は ?
# 1 歳 6 か月 健 診 の 受 診 券 は 、 ○ ○ 市内 のみ で の ご 利用 に なり ます 。 それ 以外 の 受 診 票 は 、 ● ● 県内 共通 に なり ます ので 、 そのまま お 使い い た だ け ます 。 各 自治体 独自 の サービス が 受け られる 場合 が ある ので 、 引っ越し 先 の 自治体 に お 問い合わせ ください 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# 9 ・ 7 か月 健 診 の 券 を 失 くし て しまい まし た 。
# 受 診 票 を 再 発行 し ます 。 ( 自治体 の 担当 課 や 子育て センター 等 の 名称 ) へ お 問い合わせ ください 。 [UNK] お 問い合わせ ( 自治体 の 担当 課 や 子育て センター 等 の 名称 ) ( 電話 番号 )/( 開 庁 時間 )
#
# 予 診 が やっ て き ませ ん 。
# ○ ○ 市 で は 市内 に 住民 登録 の ある お 子 様 へ 予防 接種 す べき 時期 が 近づい たら 予防 接種 記録 票 を お 送り し て い ます 。 ただし 、 転入 さ れる 前 に 発送 時期 を 過ぎ て しまっ た 分 について は 自動 発送 は さ れ ませ ん 。 この 場合 、 予防 接種 記録 票 の 中 で 未 接種 分 について は 、 接種 歴 を もと に 不足 分 を お 送り し ます ので 、 母子 手帳 等 を ご 用意 の 上 、 お 電話 または 窓口 で お 問い合わせ ください 。 [UNK] お 問い合わせ ( 自治体 の 担当 課 や 子育て センター 等 の 名称 ) ( 電話 番号 )/( 開 庁 時間 )
#
# 療 育 医療 の 申請 手続 を 教え て ください 。
# 保護 者 の 住所 地 の 保健 所 に 申請 し ます 。 感染 症 法 の 医療 費 助成 申請 と 同時に おこ ない ます 。 1 療 育 医療 申請 書 、 2 療 育 給付 意見 書 、 3 自己 負担 金 措置 申請 書 、 4 世帯 調 書 、 5 お 子 さん の 健康 保険 証 、 6 乳 幼 児 ( 子ども ) 医療 証 、 7 マイ ナンバー の 記載 に 必要 な 書類 、 8 所得 税 額 証明 書 ( 収入 の ある 方 全員 ) など を 提出 し て ください 。 申請 者 以外 の 方 が 代理 で 申請 する 場合 は 、 委任 状 と 代理人 の 方 の 身元 確認 書類 が 必要 です 。 詳しく は お 問い合わせ ください 。 [UNK] お 問い合わせ ( 自治体 の 担当 課 等 の 名称 ) ( 電話 番号 )/( 開 庁 時間 )
#
# 育成 医療 は どんな 時 に 申請 できる の です か ?
# 身体 に 機能 障害 が ある 18 歳 未満 の 方 で 、 主 に 「 手術 を 伴う 入院 治療 」 など により 機能 回復 が 見込ま れる 場合 に 、 医療 費 の 支給 認定 申請 が でき ます 。 指定 自立 医療 機関 ・ 薬局 で の 保険 内 診療 分 が 対象 です 。
#
# 小児 慢性 特定 疾病 の 申請 手続 は いつ まで に すれ ば いい です か ?
# 小児 慢性 特定 疾病 の 申請 者 と なる 方 は 、 お 子 さん の 健康 保険 の 被 保険 者 です 。 例 ) 父 ( 母 ) の 加入 し て いる 健康 保険 の 被 扶養 者 [UNK] 父 ( 母 ) が 申請 者
#
# 転入 し た とき 、 児童 手当 の 手続き を 教え て ください 。
# 1 . 転出 さ れる 自治体 に 児童 手当 の 消滅 届 を 提出 2 .○○ 市 に 転入 届 を 提出 3 .( 自治体 の 担当 課 等 の 名称 ) へ 「 児童 手当 ・ 特例 給付 認定 請求 書 」 を 提出 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L ) [UNK] お 問い合わせ ( 自治体 の 担当 課 等 の 名称 ) ( 電話 番号 )/( 開 庁 時間 )
#
# 児童 手当 の 申請 後 に 後 分 に 住ん で い ませ ん 。
# 児童 手当 は 認定 請求 を し た 月 の 翌月 分 から 支給 さ れ ます 。 * 出生 日 ・ 前 住 地 の 転出 予定 日 の 翌日 から 数え て 15 日 以内 に 申請 する と 、 出生 日 や 転入 等 の 属する 月 の 翌月 分 から 支給 さ れ ます 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L ) [UNK] お 問い合わせ ( 自治体 の 担当 課 等 の 名称 ) ( 電話 番号 )/( 開 庁 時間 )
#
# 児童 手当 の 給付 額 を 教え て ください 。
# 児童 手当 は 所得 制限 の ある 制度 です が 、 所得 制限 を 超 え た 世帯 に対して は 、 当面 の 間 、 特例 給付 として 中学校 修了 前 まで の お 子 さま 一 人 につき 月額 5 , 000 円 が 支給 さ れ ます 。 [UNK] 所得 制限 額 の 詳細 は こちら ( 自治体 HP 内 関連 ページ の UR L ) [UNK] お 問い合わせ ( 自治体 の 担当 課 等 の 名称 ) ( 電話 番号 )/( 開 庁 時間 )
#
# 雨 の 日 に 子ども と 遊 べ る 場所 は どこ か あり ます か ?
# 雨 の 日 に 子ども と 遊ぶ なら 、 AAA ( 参考 UR L )、 BB B ( 参考 UR L ) 等 は いか が です か ? 詳しく は 各 施設 の ホームページ で ご 確認 ください 。
#
# 保育 利用 料 軽減 の 申請 期限 は ?
# ( 保育 利用 料 軽減 の 申請 について 記載 し て ください 。 ) 例 「 保育 利用 料 軽減 の 申請 期限 は 、 前期 ( 4 月 ~ 8 月 入 園 ) が 8 月 末日 、 後期 ( 9 月 ~ 翌年 3 月 入 園 ) が 3 月 末日 です 。 申請 期限 まで に 申請 書 を 提出 し て い た だ け ない 場合 は 軽減 の 対象 外 と なり ます 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )」
#
# 採用 の 手続き について 教え て ください 。
# 採用 に関して は こちら を ご [UNK] ください 。 ( 自治体 HP 内 関連 ページ の UR L )
#
# 日本 脳 炎 の 予防 接種 は いつ 受け れ ば いい です か ?
# 定期 予防 接種 の 通知 は 接種 時期 ごと に 対象 者 に 通知 さ れ ます 。 接種 時期 は 予防 接種 の 種類 によって 異なり ます ので 、 詳しく は こちら を ご [UNK] ください 。 ( 自治体 HP 内 関連 ページ の UR L )
#
# ( 自治体 の 粗 大 ご み 受付 を 教え て ください 。
# ( 自治体 の 粗 大 ご み 受付 センター 等 ) は 、 ( 電話 や ホームページ 等 の 申し込み 方法 ) から 申し込み が でき ます 。 [UNK] 自治体 の 粗 大 ご み 受付 センター 等 ) ( 電話 番号 ) ( 受付 日時 ) ( 当該 センター 等 の UR L )
#
# 児童 手当 の 手続き は 公務員 後 から 児童 手当 の 手続き を 教え て ください 。
# 公務員 退職 後 は お 住み の 自治体 で の 手続き と なり ます 。 ○ ○ 市 に お 住み の 人 は 、 退職 日 から 15 日 以内 に ○ ○ 市 に 児童 手当 の 申請 を し て ください 。 必要 書類 等 詳しく は 、 お 問い合わせ ください 。 [UNK] お 問い合わせ ( 自治体 の 担当 課 等 の 名称 ) ( 電話 番号 )/( 開 庁 時間 )
#
# 放課後 クラブ について 教え て ください 。
# 放課後 クラブ は 、 保護 者 の 就 労 状況 に かかわら ず 、 全て の 児童 を 対象 と し 、 学校 や 地域 と の 連携 により 、 児童 一 人 一 人 を 健 や か に 育て て いく ため の 事業 です 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# 養子 縁組 の 届出 手続 を 教え て ください 。
# 養子 縁組 は 届出 によって 法的 に 嫡 出 親子 関係 が 成立 し ます 。 養子 縁組 届 に は 成人 の 方 の 証人 が 2 名 必要 な ので 、 あらかじめ 養子 縁組 届 の 用紙 を 取り に 来 て ください 。 自己 または 配偶 者 の 直系 卑 属 を 養子 と する 場合 を 除き 、 未成年 者 を 養子 と する 場合 は 家庭 裁判所 の 許可 が 必要 です 。 本 籍 の 変動 等 注意 事項 が あり ます ので 用紙 の 受け取り の 際 、 担当 職員 に ご 確認 ください 。 本 籍 地 以外 に お 届け に なる 場合 は 戸籍 [UNK] が 必要 と なり ます 。 [UNK] お 問い合わせ ( 自治体 の 担当 課 等 の 名称 ) ( 電話 番号 )/( 開 庁 時間 )
#
# 本 日 営業 し て いる 病院 を 教え て ください 。
# ( 都道府県 や 医師 会 が 提供 する 医療 機関 案内 等 の 名称 ) で ご 確認 い た だ け ます 。 [UNK] 詳しく は こちら ( 当該 医療 機関 案内 等 の UR L )
#
# 氏名 が 変わっ た とき の 乳 幼 児 ・ 子ども 医療 証 の 手続き を 教え て ください 。
# 乳 幼 児 ・ 子ども 医療 証 の 氏名 が 変わっ た とき は 、 子ども 医療 費 助成 申請 事項 変更 届 を 下記 窓口 まで ご 提出 ください 。 申請 後 、 新しい 医療 証 を 郵 送 い た し ます 。 なお 、 新しい 医療 証 が 届く まで の 間 は そのまま 古い 医療 証 を お 使い ください 。 【 提出 先 】 ( 自治体 の 担当 課 等 の 名称 、 場所 、 郵 送 する 場合 の 宛 名 及び 住所 等 ) [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# シングル マザー へ の 手当 や 助成 など 支援 が あり ます か ?
# 児童 扶養 手当 など の 、 ひとり 親 の 手当 ・ 助成 や 、 その他 支援 など が 受け られる 場合 が あり ます 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# 児童 扶養 手当 受給 者 へ の 優遇 制度 を 教え て ください 。
# ( 優遇 制度 が あれ ば 記載 し て ください 。 ) 例 「 児童 扶養 手当 受給 者 へ の 優遇 制度 に は 、 JR 通勤 定期 券 の 割引 、 水道 料金 の 減 免 、 ・ ・ ・ が あり ます 。 」
#
# 児童 扶養 手当 ( ひとり 親 手当 ) について 教え て ください 。
# 児童 扶養 手当 は 、 離婚 による ひとり 親 家庭 など の 生活 の 安定 ・ 自立 促進 に 寄与 する こと により 、 その 家庭 において 養育 さ れ て いる 子ども の 福祉 増進 の ため に 支給 さ れる 手当 です 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# 住民 票 の 受け取り の 決まり 取 せ 住民 票 の 受け取り は でき ます か ?
# 住民 票 の 写し について は 、 ( 請求 ・ 受け取り が できる 場所 ) で 請求 ・ 受け取り が でき ます 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# 通学 する 時 の 学区 について 教え て ください 。
# お 子 さん が 通学 する 学校 は 、 住所 により 以下 の よう に 指定 さ れ て い ます 。 詳しく は こちら を ご [UNK] ください 。 [UNK] 住所 別 通学 区域 一覧 ( 自治体 HP 内 関連 ページ の UR L )
#
# ○ ○ 市 の 電話 番号 を 教え て ください 。
# ○ ○ 税務 署 の 電話 番号 は 、 ( 電話 番号 ) です 。 ( 当該 税務 署 の ホームページ 等 の UR L )
#
# ○ ○ 市 の 子育て 施設 を 教え て ください 。
# 市内 の 子育て 施設 について は こちら を ご [UNK] ください 。 ( 自治体 HP 内 関連 ページ の UR L )
#
# 保育園 入 園 の 申し込み の 必要 な 書類 を 教え て ください 。
# 保育園 入 園 の 申し込み に は 、 保護 者 の 方 全員 分 の 就 労 証明 書 が 必要 に なり ます 。 また 、 65 歳 未満 の 祖父 母 が 同居 ( 同 一 敷地 含む 。 ) し て いる 場合 は 、 その 方 の 就 労 証明 書 など の 保育 が でき ない こと を 確認 する 書類 も 必要 に なり ます 。
#
# 保育園 の 空き 状況 は どこ に あり ます か ?
# 各 保育園 等 の 空き 状況 は ( 時期 ( 例 「 毎月 上旬 」 )) に こちら で 公表 し て い ます 。 ( 自治体 HP 内 関連 ページ の UR L )
#
# 保育園 入 園 の 相談 は 予約 が 必要 です か ?
# 保育園 入 園 の 相談 は 、 予約 は 不要 です 。 ただし 、 窓口 が 混雑 し て いる 場合 に は 、 お 待 ち い た だ く こと も あり ます 。
#
# 海外 勤務 等 で 住民 税 が 課税 さ れ ない 場合 、 認可 保育園 の 保育 料 は どの よう な 取扱い と なり ます か ?
# ( 海外 勤務 等 の 場合 の 取り扱い を 記載 し て ください 。 ) 例 「 海外 勤務 等 で 住民 税 が 課税 さ れ ない 方 の 認可 保育園 保育 料 は 、 年間 収入 申告 書 ( 市 指定 様式 ) を 提出 し て 頂 き 、 保育 料 を 決定 し ます 。 詳しく は 、 ○ ○ 課 ( 電話 番号 ) まで ご 連絡 ください 。 」
#
# 認可 保育園 の 認可 保育園 の 保育 料 は どの よう な 認可 でき ます か ?
# ( 公立 ・ 私立 の 認可 保育園 の 基本 保育 料 について 記載 し て ください 。 ) 例 「 認可 保育園 の 場合 、 基本 保育 料 の 決定 について は 、 市立 ・ 私立 による 違い は あり ませ ん 。 ただし 、 延長 保育 料 に関する こと は 、 市立 と 私立 で 異なり ます 。 」
#
# 病 児 ・ 病 後 児 利用 料金 助成 は 誰 が 上限 でき ます か ?
# ( 病 児 ・ 病 後 児 利用 料金 助成 等 の サービス が ある 場合 は 記載 し て ください 。 ) 例 「 病 児 ・ 病 後 児 利用 料金 助成 は 、 ベビー シ ッター など を 利用 し た 初日 から 連続 し た 7 日 以内 の 期間 で 、 実際 に 利用 し た 日 の 利用 に 要し た 費用 について 、 1 時間 につき 1 , 000 円 を 助成 し ます 。 1 日 の 利用 助成 時間 は 10 時間 まで で 、 年間 上限 額 は 、 平成 29 年 4 月 1 日 利用 分 から は 、 1 人 の お 子 様 につき 100 , 000 円 です 。 (※ 平成 28 年度 利用 分 まで は 上限 50 , 000 円 と なり ます 。 ) [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )」
#
# 保育 利用 料 軽減 を 受け られる 条件 は い つ です か ?
# ( 保育 利用 料 軽減 について 記載 し て ください 。 ) 例 「 保育 利用 料 軽減 を 受け られる 条件 は 、 対象 施設 により 異なり ます 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )」
#
# 母子 手帳 を なくし た 場合 は 再 発行 でき ます か ?
# 母子 手帳 を なくし た とき は 、 再 交付 を 受け て ください 。 お 子 さん が 出生 前 の 母子 手帳 について は 、 ( 再 交付 を 受け られる 場所 ) で 再 交付 を 受け られ ます 。 お 子 さん が 出生 後 の 母子 手帳 について は 、 ( 再 交付 を 受け られる 場所 ) で 受け られ ます 。 申請 の 際 は ご 本人 確認 できる もの を お 持ち ください 。 [UNK] お 問い合わせ ( 自治体 の 担当 課 等 の 名称 ) ( 電話 番号 )/( 開 庁 時間 ) < 私立 > < 幼稚園 > < 補助 金 > < 申請 手続き > < 昨年 度 > < 今年 度 > 昨年 度 と 今年 度 で 私立 幼稚園 が 異なる 場合 は 、 新しい 私立 幼稚園 で 改めて 、 補助 金 の 申請 を し て い た だ き ます 。
#
# 前年度 から ○ ○ 市 在住 で 同じ 私立 幼稚園 に 通っ て い ます 。 昨年 度 と 同様 に 補助 金 の 申請 手続き が 必要 です か ?
# 前年度 から ○ ○ 市 在住 で 同じ 私立 幼稚園 に 通っ て いる 場合 、 進級 園 児 用 の 補助 金 の 申請 書 を 後日 、 幼稚園 宛て に 送付 し ます ので 、 そちら を 園 へ ご 提出 ください 。
#
# ● ● 県内 で 引っ越し たら 、 妊 婦 健 診 の 受 診 票 は ?
# 妊 婦 健 診 受 診 票 を お 渡し し て から の 助成 に なり ます 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L ) < 県内 > 受 診 票 の 妊 婦 歯科 健 診 は 、 ○ ○ 市内 のみ で の ご 利用 に なり ます 。 それ 以外 の 受 診 票 は 、 ● ● 県内 共通 に なり ます ので 、 そのまま お 使い い た だ け ます 。 各 自治体 独自 の サービス が 受け られる 場合 が ある ので 、 引っ越し 先 の 自治体 に お 問い合わせ ください 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L ) < 県 外 > 受 診 票 は ご 利用 い た だ け なく なり ます 。 引っ越し 先 の 自治体 に お 問い合わせ ください 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# 子ども の うん ち が 出 ませ ん 。
# ( 自治体 の 担当 課 や 子育て センター 等 ) で は 、 18 歳 未満 の 子ども と その 家庭 に関する 相談 を 行なっ て い ます 。 困っ て いる こと 、 悩ん で いる こと 、 どんな こと でも 気 軽 に 相談 し て ください 。 相談 内容 に 合っ た 、 他 の 専門 機関 と 一緒 に 考え ます 。 [UNK] 相談 専用 電話 ( 電話 番号 )
#
# 肺炎 球菌 定期 予防 接種 について 教え て ください 。
# 肺炎 球菌 予防 接種 は 、 平成 26 年 10 月 1 日 より 、 定期 予防 接種 に なり まし た 。 過去 に 肺炎 球菌 ワクチン を 接種 し た こと の ない 、 初めて 接種 する 人 が 対象 と なり ます 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# 副 市長 の 名前 を 教え て ください 。
# 現在 の ○ ○ 市 の 副 市長 は ○ ○ ○ ○ 、 ○ ○ ○ ○ です 。
#
# ( 子育て 支援 に対する 支援 センター 等 の 名称 ) の 利用 に 家庭 家庭 を 手伝っ て い ます か ?
# ( 子育て 家庭 に対する 支援 を 行う センター 等 ) について は こちら を ご [UNK] ください 。 ( 自治体 HP 内 関連 ページ の UR L )
#
# 休日 保育 制度 について 教え て ください 。
# ( 休日 保育 等 を 行っ て いる 場合 は 記載 し て ください 。 ) 例 「 休日 保育 制度 と は 、 市内 の 認可 保育園 に 通っ て いる 子ども について 、 保護 者 が 休日 の 就 労 など で 保育 を 必要 と する 場合 に 無料 で お 預かり する 制度 です 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )」
#
# ファミリー ・ ファミリー ・ 子育て 支援 センター 等 の 名称 ) の 利用 に サポート センター は あり ます か ?
# ファミリー ・ サポート ・ センター と は 、 子育て の 援助 が 必要 な 人 ( ファミリー 会員 ) と 子育て の 援助 が できる 人 ( サポート 会員 ) が 登録 し 、 会員 相互 の 子育て 支援 活動 を 行っ て いる ところ です 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# どんな アカウント が あり ます か ?
# ( アカウント の 発信 内容 を 記載 し て ください 。 ) 例 「 この アカウント で は 、 お 子 様 の 年齢 に 合わせ て 健 診 や 予防 接種 の 情報 を 配信 し たり 、 妊 婦 の 方 向け の サービス の 情報 や 保育園 の 入 園 に関する 情報 、 子ども に関する イベント 情報 等 を 配信 し て い ます 。 また 子育て に関する お 問い合わせ に対する 自動 応答 サービス も 行っ て い ます 。 」
#
# ( 市民 体育 大会 等 ) について 教え て ください 。
# ( 市民 体育 大会 等 ) と は 、 ( 市民 体育 大会 等 の 説明 を 記載 し て ください )。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L ) < 電話 番号 > < 出張所 > < 支所 > < サービス センター > ( 支所 ・ 出張所 、 市民 サービス センター 等 ) の 電話 番号 は ( 電話 番号 ) です 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# 転 園 届 の 提出 場所 を 教え て ください 。
# ( 転 園 届 の 提出 について 記載 し て ください 。 ) 例 「 保育園 の 転 園 届 は ○ ○ 課 へ 届出 の 手続き を し て ください 。 郵 送 や 保育園 等 で の 受付 は し て い ませ ん 。 」
#
# ○ ○ 駅 近く で 子ども と 遊 べ る 場所 を 教え て ください 。
# ○ ○ 駅 周辺 で 子ども と 遊 べ る 場所 でし たら 、 ○ ○ 子育て 広場 は いか が です か ? [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# マイ ナ ポー ポー ポー に マイ げ し い の です が 。
# マイ ナ ポー タル と は 、 政府 が 運営 する オンライン サービス で 、 一 人 ひ とり に 専用 の 個人 ポータル サイト を 設定 し ます 。 子育て ワン ストップ サービス で は 、 自分 に 合っ た 子育て に関する サービス を 検索 でき ます 。 [UNK] 詳しく は こちら http s :// my na . go . jp /
#
# ハチ 幼 です が 、 ハチ 虫 の 病院 を 教え て ください 。
# ハチ は 自然 界 で 樹木 に つく ケ ムシ など を 食べる 益 虫 です 。 ハチ は 、 む や み に 人 を 刺 す ため に 生き て いる わけ で は あり ませ ん 。 人 が 巣 に 近づい たり 、 触れ たり する と ハチ は 巣 を 守 ろ う として 人 を 刺し ます 。 生活 に 支障 が ない 場所 に ある ハチ の 巣 は 刺激 せ ず 、 静か に 様子 を 見 ましょ う 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# ○ ○ 市 の 小学校 について 教え て ください 。
# ○ ○ 小学校 の 住所 は ( 小学校 の 住所 ) です 。 ( 自治体 HP 内 関連 ページ の UR L ) 行き 方 は こちら を ご [UNK] ください 。 ( 自治体 HP 内 関連 ページ の UR L )
#
# おし め の 予防 相談 について 教え て ください 。
# 保健 師 に ご 相談 ください 。 AAA 保健 相談 所 :( 電話 番号 )(○ 時 ○ 分 から ○ 時 ○ 分 ) BB B 保健 相談 所 :( 電話 番号 )(○ 時 ○ 分 から ○ 時 ○ 分 )
#
# 赤ちゃん が 泣き 止 ま ない 。
# 赤ちゃん の 出生 通知 票 を お 出し い た だ い た ご 家庭 を 、 保健 師 ・ 助 産 師 もしくは 訪問 相談 員 が 訪問 し ます 。 新生 児 訪問 は 、 生後 2 か月 まで で とくに 必要 が ある 場合 、 保健 師 または 助 産 師 が うか が い ます 。 こん に ち は 赤ちゃん 訪問 は 、 生後 4 か月 まで に すべて の 乳児 の ご 家庭 に 保健 師 または 訪問 相談 員 が うか が い ます 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# 子ども の 体重 の 増え が 悪く なっ て い ます 。
# ご 心配 です ね 。 お 子 さん の 成長 について は 、 保健 師 に ご 相談 ください 。 AAA 保健 相談 所 :( 電話 番号 )(○ 時 ○ 分 から ○ 時 ○ 分 ) BB B 保健 相談 所 :( 電話 番号 )(○ 時 ○ 分 から ○ 時 ○ 分 )
#
# LGBT と は 何 です か ?
# LGBT と は セク シャル ・ マイ ノ リティ 、 性的 少数 者 を 表す 総称 です 。 L ( レズビアン ) は 同性 を 好き に なる 女性 G ( ゲイ ) は 同性 を 好き に なる 男性 B ( バイ セク シュア ル ) は 性別 に かかわら ず 恋愛 対象 に なる 人 T ( トランス ジェン ダー ) は 身体 的 な 性別 と 自 認 する 性 が 一致 し ない ( 性 別 違和 ) 人 。 性 同一 性 障害 の 人 が 含ま れ ます 。 性 分化 疾患 ( DS D ) など も あり 、 実は から だ の 性 も 単純 に は 二 分 でき ませ ん 。 SO G I ( ソ ギ ) と 略さ れる 場合 が 増え て い ます 。 SO = Se x ual Or ient ation ( 性 的 指向 ) GI = Gen der I de n t ity ( 性 自 認 )
#
# ( 子育て 支援 センター 等 の 名称 ) の 名称 ) の 名称 を 教え て ください 。
# ( 子育て 支援 センター 等 の 名称 ) で は 、 ( 実施 し て いる 事業 の 内容 等 を 記載 し て ください ) し て い ます 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# 市 の 保育園 ・ 数 を 教え て ください 。
# 市 の 保育園 ・ 幼 保 一元 化 施設 の 一覧 は こちら を ご [UNK] ください 。 ( 自治体 HP 内 関連 ページ の UR L )
#
# アート スクール について 教え て ください 。
# ( アート スクール について 記載 し て ください 。 ) 例 「 ○ ○ 子育て 支援 センター の アート スクール で は 、 食 ・ もの づくり ・ 体操 ・ 音楽 ・ 写真 など 、 さまざま な 分野 で 活躍 する クリ エー ター を 講師 に 迎え 、 多彩 な テーマ で 講座 を 開催 し て い ます 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )」
#
# ( 当地 当地 グルメ 等 ) について 教え て ください 。
# ( ご 当地 グルメ 等 の 説明 を 記載 し て ください 。 )
#
# 保健 所 ( 保健 相談 所 ) について 教え て ください 。
# 保健 所 (○○ 市 中央 保健 相談 所 ) は ( 所在 場所 ) に あり ます 。 また 、 その他 の 保健 相談 所 が ( 所在 場所 ) と ( 所在 場所 ) に それぞれ あり ます 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# ロ タウ スス の 接種 を 受け なけれ ば なら ない の です か ?
# ロ タウ イルス は 乳 幼 児 の 胃 腸 炎 の 原因 として 上位 を 占め 、 どの お 子 さま で も 5 歳 まで に 1 回 以上 は かかる 感染 症 です 。 嘔 吐 ・ 下痢 が 続き 、 ほとんど の 場合 は 自然 に 回復 し ます が 、 まれ に 脱水 症 で 入院 が 必要 に なっ たり 、 脳 炎 など の 重い 合併症 を 引き起こし たり する こと が あり ます 。 ( 助成 が ある 場合 、 助成 内容 を 記載 し て ください 。 例 「 ○ ○ 市 で は 、 市内 在住 の 生後 6 週 から 32 週 まで の お 子 さま を 対象 として 、 ロ タウ イルス ワ クチン 任意 接種 費用 の 一部 助成 を 実施 し て い ます 。 1 回 8 , 500 円 を 上限 として 2 回 まで 助成 を 行い ます 。 」 ) [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# ○ 年 ○ 月 入 園 の 保育園 の 募集 結果 は い つ です か ?
# ○ 年 4 月 入 園 申 込 の 一 次 募集 の 利用 調整 結果 は ○ 年 ○ 月 ○ 日 (○) を 予定 し て い ます 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# 四 種 混合 の 4 回 目 の 予防 接種 記録 票 の 送付 は あり ます か ?
# 四 種 混合 予防 接種 の 1 期 追加 分 ( 4 回 目 ) は 初回 3 回 接種 後 6 か月 以上 の 間隔 を あ け て 接種 し ます 。 予防 接種 記録 票 は 生後 ○ か月 に 達し た 月末 に 郵 送 い た し ます 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L ) < 送付 > ○ ○ 市 で は 市内 に 住民 登録 の ある お 子 様 へ 予防 接種 す べき 時期 が 近づい たら 予防 接種 記録 票 を お 送り し て い ます 。 送付 時期 は 予防 接種 により 異なり ます ので 、 詳しく は こちら を ご [UNK] ください 。 ( 自治体 HP 内 関連 ページ の UR L )
#
# 乳児 健 診 の 乳児 乳児 の 場所 を 教え て ください 。
# 乳児 健 診 の 実施 場所 は 、 3 から 4 か月 健 診 は AAA 保健 相談 所 で 実施 し て い ます 。 6 から 7 か月 健 診 、 9 から 10 か月 健 診 は 契約 医療 機関 にて 実施 し て い ます 。 [UNK] 契約 医療 機関 について は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# ( 保育 担当 課 ) の 電話 番号 を 教え て ください
# ( 保育 担当 課 ) の 電話 番号 は こちら を ご 確認 ください 。 ( 自治体 HP 内 関連 ページ の UR L )
#
# 児童 扶養 手当 受給 者 へ の 優遇 制度 を 教え て ください 。
# 児童 扶養 手当 の 資格 は 、 お 子 さま の 出生 から 18 歳 に 達し た 日 以降 の 最初 の 3 月 31 日 まで です 。 ( 児童 に 中 度 以上 の 障害 が ある 場合 は 20 歳 未満 まで ) [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# ボタン 電池 について 教え て ください 。
# 万 が 一 お 子 さん が コイン 電池 ・ ボタン 電池 を 誤 飲 、 もしくは その 疑い が ある 場合 は すぐ 医師 等 に 相談 し て ください 。 [UNK] 71 1 9 等 の 救急 相談 センター の 名称 ) ( 電話 番号 )
#
# ○ ○ 市 の 禁煙 公園 について 教え て ください 。
# ○ ○ 市 で は 園内 の 受動 喫煙 防止 対策 として 分 煙 環境 を 整備 する ため 、 市立 公園 ○ か 所 を 、 禁煙 公園 または 分 煙 公園 に 指定 し て い ます 。 [UNK] 禁煙 公園 ・ 分 園 公園 一覧 ( 自治体 HP 内 関連 ページ の UR L )

# %% [markdown]
# ### posterior: (C, Q, A) -> (C, Zq, Za) -> (Q, A)

# %%
for pair in qa_posterior_pair:
    print(pair[0])
    print(pair[1], '\n')
# Out:
# 母子 手帳 の 他 に 窓口 し まし た が 、 母子 手帳 の 他 に 窓口 に 必要 です か ?
# 窓口 で 妊娠 届 を ご 記入 い た だ き 、 母子 手帳 を お 渡し し ます 。 住民 票 の 世帯 が 別 の 方 が 代理 で 窓口 に 来 ら れる 場合 は 、 委任 状 が 必要 に なり ます 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# ● ● 県 外 へ 引っ越し たら 、 子ども の 受 診 票 は ?
# 受 診 票 は ご 利用 い た だ け なく なり ます 。 引っ越し 先 の 自治体 に お 問い合わせ ください 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# 7 ・ 7 か月 健 診 の 券 を 失 くし て しまい まし た 。
# 受 診 票 を 再 発行 し ます 。 ( 自治体 の 担当 課 や 子育て センター 等 の 名称 ) へ お 問い合わせ ください 。 [UNK] お 問い合わせ ( 自治体 の 担当 課 や 子育て センター 等 の 名称 ) ( 電話 番号 )/( 開 庁 時間 )
#
# 予 診 が やっ て き ませ ん 。
# ○ ○ 市 で は 市内 に 住民 登録 の ある お 子 様 へ 予防 接種 す べき 時期 が 近づい たら 予防 接種 記録 票 を お 送り し て い ます 。 ただし 、 転入 さ れる 前 に 発送 時期 を 過ぎ て しまっ た 分 について は 自動 発送 は さ れ ませ ん 。 この 場合 、 予防 接種 記録 票 の 中 で 未 接種 分 について は 、 接種 歴 を もと に 不足 分 を お 送り し ます ので 、 母子 手帳 等 を ご 用意 の 上 、 お 電話 または 窓口 で お 問い合わせ ください 。 [UNK] お 問い合わせ ( 自治体 の 担当 課 や 子育て センター 等 の 名称 ) ( 電話 番号 )/( 開 庁 時間 )
#
# 療 育 医療 の 申請 手続 を 教え て ください 。
# 保護 者 の 住所 地 の 保健 所 に 申請 し ます 。 感染 症 法 の 医療 費 助成 申請 と 同時に おこ ない ます 。 1 療 育 医療 申請 書 、 2 療 育 給付 意見 書 、 3 自己 負担 金 措置 申請 書 、 4 世帯 調 書 、 5 お 子 さん の 健康 保険 証 、 6 乳 幼 児 ( 子ども ) 医療 証 、 7 マイ ナンバー の 記載 に 必要 な 書類 、 8 所得 税 額 証明 書 ( 収入 の ある 方 全員 ) など を 提出 し て ください 。 申請 者 以外 の 方 が 代理 で 申請 する 場合 は 、 委任 状 と 代理人 の 方 の 身元 確認 書類 が 必要 です 。 詳しく は お 問い合わせ ください 。 [UNK] お 問い合わせ ( 自治体 の 担当 課 等 の 名称 ) ( 電話 番号 )/( 開 庁 時間 )
#
# 育成 医療 の 申請 手続 は いつ まで に すれ ば いい です か ?
# 身体 に 機能 障害 が ある 18 歳 未満 の 方 で 、 主 に 「 手術 を 伴う 入院 治療 」 など により 機能 回復 が 見込ま れる 場合 に 、 医療 費 の 支給 認定 申請 が でき ます 。 指定 自立 医療 機関 ・ 薬局 で の 保険 内 診療 分 が 対象 です 。 育成 医療 の 申請 は 保護 者 が 住所 地 の 保健 所 に 申請 し ます 。
#
# 小児 慢性 特定 疾病 の 申請 手続 は いつ まで に すれ ば いい です か ?
# 18 歳 未満 の 方 で 、 小児 慢性 特定 疾病 医療 支援 事業 の 対象 疾病 に かかっ て おり 、 かつ 、 認定 基準 に 該当 する 方 が 申請 でき ます 。 対象 疾病 、 認定 基準 について は お 問い合わせ ください 。 [UNK] お 問い合わせ ( 自治体 の 担当 課 等 の 名称 ) ( 電話 番号 )/( 開 庁 時間 )
#
# 転入 し た とき 、 児童 手当 の 手続き を 教え て ください 。
# 1 . 転出 さ れる 自治体 に 児童 手当 の 消滅 届 を 提出 2 .○○ 市 に 転入 届 を 提出 3 .( 自治体 の 担当 課 等 の 名称 ) へ 「 児童 手当 ・ 特例 給付 認定 請求 書 」 を 提出 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L ) [UNK] お 問い合わせ ( 自治体 の 担当 課 等 の 名称 ) ( 電話 番号 )/( 開 庁 時間 )
#
# 児童 手当 の 申請 後 に 後 分 に 住ん で い ませ ん 。
# 児童 手当 は 認定 請求 を し た 月 の 翌月 分 から 支給 さ れ ます 。 * 出生 日 ・ 前 住 地 の 転出 予定 日 の 翌日 から 数え て 15 日 以内 に 申請 する と 、 出生 日 や 転入 等 の 属する 月 の 翌月 分 から 支給 さ れ ます 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L ) [UNK] お 問い合わせ ( 自治体 の 担当 課 等 の 名称 ) ( 電話 番号 )/( 開 庁 時間 )
#
# 児童 手当 の 給付 額 を 教え て ください 。
# 児童 手当 は 所得 制限 の ある 制度 です が 、 所得 制限 を 超 え た 世帯 に対して は 、 当面 の 間 、 特例 給付 として 中学校 修了 前 まで の お 子 さま 一 人 につき 月額 5 , 000 円 が 支給 さ れ ます 。 [UNK] 所得 制限 額 の 詳細 は こちら ( 自治体 HP 内 関連 ページ の UR L ) [UNK] お 問い合わせ ( 自治体 の 担当 課 等 の 名称 ) ( 電話 番号 )/( 開 庁 時間 )
#
# 雨 の 日 に 子ども と 遊 べ る 場所 は どこ か あり ます か ?
# 雨 の 日 に 子ども と 遊ぶ なら 、 AAA ( 参考 UR L )、 BB B ( 参考 UR L ) 等 は いか が です か ? 詳しく は 各 施設 の ホームページ で ご 確認 ください 。
#
# 保育 利用 料 軽減 の 申請 期限 は ?
# ( 保育 利用 料 軽減 に かかる 申請 書 名 ) は 下記 ホームページ から ダウンロード が でき ます 。 PD F を 印刷 し て 記載 し て ください 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# 採用 の 手続き について 教え て ください 。
# 採用 に関して は こちら を ご [UNK] ください 。 ( 自治体 HP 内 関連 ページ の UR L )
#
# 日本 脳 炎 の 予防 接種 は いつ 受け れ ば いい です か ?
# 定期 予防 接種 の 通知 は 接種 時期 ごと に 対象 者 に 通知 さ れ ます 。 接種 時期 は 予防 接種 の 種類 によって 異なり ます ので 、 詳しく は こちら を ご [UNK] ください 。 ( 自治体 HP 内 関連 ページ の UR L )
#
# ( 自治体 の 粗 大 ご み 受付 を 教え て ください 。
# ( 自治体 の 粗 大 ご み 受付 センター 等 ) は 、 ( 電話 や ホームページ 等 の 申し込み 方法 ) から 申し込み が でき ます 。 [UNK] 自治体 の 粗 大 ご み 受付 センター 等 ) ( 電話 番号 ) ( 受付 日時 ) ( 当該 センター 等 の UR L )
#
# 児童 手当 の 手続き は 公務員 後 から 児童 手当 の 手続き を 教え て ください 。
# 公務員 退職 後 は お 住み の 自治体 で の 手続き と なり ます 。 ○ ○ 市 に お 住み の 人 は 、 退職 日 から 15 日 以内 に ○ ○ 市 に 児童 手当 の 申請 を し て ください 。 必要 書類 等 詳しく は 、 お 問い合わせ ください 。 [UNK] お 問い合わせ ( 自治体 の 担当 課 等 の 名称 ) ( 電話 番号 )/( 開 庁 時間 )
#
# 放課後 学習 クラブ の クラブ について 教え て ください 。
# ( 放課後 学習 クラブ の 説明 を 記載 し て ください 。 ) [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# 養子 縁組 の 届出 手続 を 教え て ください 。
# 養子 縁組 は 届出 によって 法的 に 嫡 出 親子 関係 が 成立 し ます 。 養子 縁組 届 に は 成人 の 方 の 証人 が 2 名 必要 な ので 、 あらかじめ 養子 縁組 届 の 用紙 を 取り に 来 て ください 。 自己 または 配偶 者 の 直系 卑 属 を 養子 と する 場合 を 除き 、 未成年 者 を 養子 と する 場合 は 家庭 裁判所 の 許可 が 必要 です 。 本 籍 の 変動 等 注意 事項 が あり ます ので 用紙 の 受け取り の 際 、 担当 職員 に ご 確認 ください 。 本 籍 地 以外 に お 届け に なる 場合 は 戸籍 [UNK] が 必要 と なり ます 。 [UNK] お 問い合わせ ( 自治体 の 担当 課 等 の 名称 ) ( 電話 番号 )/( 開 庁 時間 )
#
# 本 科 の 病院 を 教え て ください 。
# ( 都道府県 や 医師 会 が 提供 する 医療 機関 案内 等 の 名称 ) で ご 確認 ください 。 [UNK] 詳しく は こちら ( 当該 医療 機関 案内 等 の UR L )
#
# 氏名 が 変わっ た とき の 乳 幼 児 ・ 子ども 医療 証 の 手続き を 教え て ください 。
# 乳 幼 児 ・ 子ども 医療 証 を お 持ち で 保険 が 変わっ た とき は 、 子ども 医療 費 助成 申請 事項 変更 届 を 下記 窓口 まで ご 提出 ください 。 申請 後 、 新しい 医療 証 を 郵 送 い た し ます 。 なお 、 新しい 医療 証 が 届く まで の 間 は そのまま 古い 医療 証 を お 使い ください 。 【 提出 先 】 ( 自治体 の 担当 課 等 の 名称 、 場所 、 郵 送 する 場合 の 宛 名 及び 住所 等 ) [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# ひとり 親 手当 の 助成 制度 について 教え て ください 。
# ひとり 親 家庭 へ の 手当 ・ 助成 として は 、 児童 扶養 手当 、 児童 育成 手当 、 ひとり 親 医療 費 助成 制度 が あり ます 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# 児童 扶養 手当 受給 者 へ の 優遇 制度 を 教え て ください 。
# ( 優遇 制度 が あれ ば 記載 し て ください 。 ) 例 「 児童 扶養 手当 受給 者 へ の 優遇 制度 に は 、 JR 通勤 定期 券 の 割引 、 水道 料金 の 減 免 、 ・ ・ ・ が あり ます 。 」
#
# 児童 扶養 手当 の 第 2 2 子 3 子 子 の 手当 について 教え て ください 。
# 児童 扶養 手当 の 第 2 子 、 第 3 子 の 手当 額 は 以下 の とおり です 。 第 2 子 : 全部 支給 の 場合 ... 9 , 99 0 円 一部 支給 の 場合 ... 9 , 98 0 ~ 5 , 000 円 を 加算 第 3 子 : 全部 支給 の 場合 ... 5 , 99 0 円 一部 支給 の 場合 ... 5 , 98 0 ~ 3 , 000 円 を 加算
#
# 住民 票 の 受け取り の 決まり 取 せ 住民 票 の 受け取り は でき ます か ?
# 住民 票 の 写し について は 、 ( 請求 ・ 受け取り が できる 場所 ) で 請求 ・ 受け取り が でき ます 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# 通学 する 時 の 学区 について 教え て ください 。
# お 子 さん が 通学 する 学校 は 、 住所 により 以下 の よう に 指定 さ れ て い ます 。 詳しく は こちら を ご [UNK] ください 。 [UNK] 住所 別 通学 区域 一覧 ( 自治体 HP 内 関連 ページ の UR L )
#
# ○ ○ 市 の 電話 番号 を 教え て ください 。
# ○ ○ 税務 署 の 電話 番号 は 、 ( 電話 番号 ) です 。 ( 当該 税務 署 の ホームページ 等 の UR L )
#
# ○ ○ 市 の 施設 で スポーツ 保 後 の 新入 園 児 募集 について 教え て ください 。
# ○ ○ 市 の スポーツ 施設 について は こちら を ご [UNK] ください 。 ( 自治体 HP 内 関連 ページ の UR L ) < 募集 > < 幼 保 一元 化 > < 園 児 > < 新入 > 現在 行っ て いる 幼 保 一元 化 施設 の 新 入 園 児 の 募集 について は こちら を ご [UNK] ください 。 ( 自治体 HP 内 関連 ページ の UR L ) < 名称 > < 保養 > ( 市 の 保養 施設 の 名称 ) と は 、 ( 所在 場所 ) に ある ○ ○ 市 の 保養 施設 です 。 詳しく は こちら を ご [UNK] ください 。 ( 自治体 HP 内 関連 ページ の UR L )
#
# 保育園 入 園 の 申し込み の 必要 な 書類 を 教え て ください 。
# 保育園 入 園 の 申し込み に は 、 保護 者 の 方 全員 分 の 就 労 証明 書 が 必要 に なり ます 。 また 、 65 歳 未満 の 祖父 母 が 同居 ( 同 一 敷地 含む 。 ) し て いる 場合 は 、 その 方 の 就 労 証明 書 など の 保育 が でき ない こと を 確認 する 書類 も 必要 に なり ます 。
#
# 保育園 の 空き 状況 は どこ に あり ます か ?
# 各 保育園 等 の 空き 状況 は ( 時期 ( 例 「 毎月 上旬 」 )) に こちら で 公表 し て い ます 。 ( 自治体 HP 内 関連 ページ の UR L ) 空き 状況 は 、 退 園 など により 随時 変化 する ので 、 この ページ の 空き 状況 に かかわら ず 「 入り たい 順番 」 や 「 毎日 通 える 範囲 」 を 検討 し た 上 で 希望 する 保育園 を 選ん で ください 。
#
# 保育園 の 申 込 時 の 予約 を 行い て い ます か ?
# ( 予約 の 有無 の 説明 を 記載 し て ください 。 ) 例 「 保育園 入 園 の 申 込 時 の 予約 は 原則 として 必要 あり ませ ん が 、 窓口 の 混雑 を 緩和 する ため に 予約 制 を 一部 導入 し て い ます 。 事前 に 電話 で ご 来 庁 の 日時 を 予約 し て い た だ く こと で 、 お 申し込み の 際 に お 待 ち い た だ く 時間 が 短く なり ます ので 、 ぜ ひ ご 利用 ください 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )」
#
# 認可 保育園 保育 料 の 口座 振 替 が 資金 不足 により 引き 落と せ なかっ た 場合 は 、 どの よう に 支払 え ば よい です か ?
# ( 引き 落とし でき なかっ た 場合 の 取り扱い を 記載 し て ください 。 ) 例 「 認可 保育園 保育 料 の 口座 振 替 が でき なかっ た 方 について は 、 市 から その 旨 を 通知 し ます 。 納付 書 を 同 封 し ます ので 、 金融 機関 等 で お 支払い ください 。 再 引き 落とし は 行っ て い ませ ん 。 」
#
# 認可 保育園 の 認可 保育園 の 保育 料 は どの よう な 認可 でき ます か ?
# ( 公立 ・ 私立 の 認可 保育園 の 基本 保育 料 について 記載 し て ください 。 ) 例 「 認可 保育園 の 場合 、 基本 保育 料 の 決定 について は 、 市立 ・ 私立 による 違い は あり ませ ん 。 ただし 、 延長 保育 料 に関する こと は 、 市立 と 私立 で 異なり ます 。 」
#
# 病 児 ・ 病 後 児 利用 料金 助成 は 誰 が 上限 でき ます か ?
# ( 病 児 ・ 病 後 児 利用 料金 助成 等 の サービス が ある 場合 は 記載 し て ください 。 ) 例 「 病 児 ・ 病 後 児 利用 料金 助成 は 、 ベビー シ ッター など を 利用 し た 初日 から 連続 し た 7 日 以内 の 期間 で 、 実際 に 利用 し た 日 の 利用 に 要し た 費用 について 、 1 時間 につき 1 , 000 円 を 助成 し ます 。 1 日 の 利用 助成 時間 は 10 時間 まで で 、 年間 上限 額 は 、 平成 29 年 4 月 1 日 利用 分 から は 、 1 人 の お 子 様 につき 100 , 000 円 です 。 (※ 平成 28 年度 利用 分 まで は 上限 50 , 000 円 と なり ます 。 ) [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )」
#
# 保育 利用 料 軽減 を 受け られる 条件 は い つ です か ?
# ( 保育 利用 料 軽減 について 記載 し て ください 。 ) 例 「 保育 利用 料 軽減 を 受け られる 条件 は 、 対象 施設 により 異なり ます 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )」
#
# マイ コプ ラ ズマ に かかっ た 場合 、 何 科 に 受 診 すれ ば いい です か ?
# 昨年 度 と 今年 度 で 私立 幼稚園 が 異なる 場合 は 、 新しい 私立 幼稚園 で 改めて 、 補助 金 の 申請 を し て い た だ き ます 。
#
# ○ ○ 市外 で も 同じ 私立 幼稚園 に 通っ て い ます 。
# 父 の 住所 が ○ ○ 市外 で あり 世帯 も 分け て いる 場合 、 私立 幼稚園 の 補助 金 の 申請 書 に は 、 父親 も 記入 し て い た だ き ます 。 また 、 申請 書 の 右 の 欄 に 「 園 児 の 父 、 母 で 市外 ( 国外 ) に 住所 が ある 方 は 、 以下 に ご 記入 ください 。 」 へ の ご 記入 を お願い し ます 。
#
# 妊 婦 健 診 受 診 票 の 余り を 換 金 し て もらえ ます か ?
# 妊 婦 健 診 の 受 診 票 は 、 受 診 票 を 受け取っ た 日 より 後 で 、 病院 が 妊 婦 健 診 と 規定 し た 日 に 利用 でき ます 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L ) < 余り > < 換 金 > 妊 婦 健 診 に対する 助成 制度 で あり 、 金 券 で は あり ませ ん 。 その ため 換 金 等 は でき ませ ん 。
#
# 乳 幼 児 の 相談 について 教え て ください 。
# 乳 幼 児 の ブラ ッシング や 、 む し 歯 、 かみ 合わせ の 相談 について は ( 自治体 の 担当 課 等 の 名称 ) へ お 問い合わせ ください 。 [UNK] お 問い合わせ ( 自治体 の 担当 課 等 の 名称 ) ( 電話 番号 )/( 開 庁 時間 )
#
# 肺炎 球菌 定期 予防 接種 について 教え て ください 。
# 「 定期 予防 接種 」 は 法律 で 区 市町村 が 接種 を 行う こと が 定め られ て いる 予防 接種 の こと で あり 、 それ 以外 の もの は 「 任意 予防 接種 」 です 。 ○ ○ 市 で は 、 定期 予防 接種 を 実施 する とともに 、 一部 の 任意 予防 接種 について 、 助成 制度 を 設け て い ます 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# 副 市長 の 名前 を 教え て ください 。
# 現在 の ○ ○ 市長 は ○ ○ ○ ○ です 。 ( 自治体 HP 内 関連 ページ の UR L )
#
# ( 子育て 支援 に対する 支援 センター 等 の 名称 ) の 利用 に 家庭 家庭 を 手伝っ て い ます か ?
# ( 子育て 家庭 に対する 支援 を 行う センター 等 ) について は こちら を ご [UNK] ください 。 ( 自治体 HP 内 関連 ページ の UR L )
#
# 休日 保育 制度 について 教え て ください 。
# ( 休日 保育 等 を 行っ て いる 場合 は 記載 し て ください 。 ) 例 「 休日 保育 制度 と は 、 市内 の 認可 保育園 に 通っ て いる 子ども について 、 保護 者 が 休日 の 就 労 など で 保育 を 必要 と する 場合 に 無料 で お 預かり する 制度 です 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )」
#
# ファミリー ・ ファミリー ・ 子育て 支援 センター 等 の 名称 ) の 利用 に サポート センター は あり ます か ?
# ファミリー ・ サポート ・ センター と は 、 子育て の 援助 が 必要 な 人 ( ファミリー 会員 ) と 子育て の 援助 が できる 人 ( サポート 会員 ) が 登録 し 、 会員 相互 の 子育て 支援 活動 を 行っ て いる ところ です 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# どんな アカウント が あり ます か ?
# ( アカウント の 発信 内容 を 記載 し て ください 。 ) 例 「 この アカウント で は 、 お 子 様 の 年齢 に 合わせ て 健 診 や 予防 接種 の 情報 を 配信 し たり 、 妊 婦 の 方 向け の サービス の 情報 や 保育園 の 入 園 に関する 情報 、 子ども に関する イベント 情報 等 を 配信 し て い ます 。 また 子育て に関する お 問い合わせ に対する 自動 応答 サービス も 行っ て い ます 。 」
#
# ( 支所 ・ 出張所 、 市民 サービス センター 等 ) の 電話 番号 を 教え て ください 。
# ( 支所 ・ 出張所 、 市民 サービス センター 等 ) の 電話 番号 は ( 電話 番号 ) です 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# 婚姻 届 の 届出 場所 を 教え て ください 。
# 婚姻 届 は 、 夫 に なる 人 ・ 妻 に なる 人 どちら か の 本 籍 地 または 所在地 の 市区 町村 役所 ・ 役場 に 届出 し て ください 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# 雨 の 日 に 子ども と 遊 べ る 場所 は どこ か あり ます か ?
# 雨 の 日 に 子ども と 遊ぶ なら 、 AAA ( 参考 UR L )、 BB B ( 参考 UR L ) 等 は いか が です か ? 詳しく は 各 施設 の ホームページ で ご 確認 ください 。
#
# マイ ナ ポー ポー と マイ げ し い の です が 。
# マイ ナ ポー タル と は 、 政府 が 運営 する オンライン サービス で 、 一 人 ひ とり に 専用 の 個人 ポータル サイト を 設定 し ます 。
#
# ハチ 幼 です が 、 ハチ 虫 の 病院 を 教え て ください 。
# ハチ は 自然 界 で 樹木 に つく ケ ムシ など を 食べる 益 虫 です 。 ハチ は 、 む や み に 人 を 刺 す ため に 生き て いる わけ で は あり ませ ん 。 人 が 巣 に 近づい たり 、 触れ たり する と ハチ は 巣 を 守 ろ う として 人 を 刺し ます 。 生活 に 支障 が ない 場所 に ある ハチ の 巣 は 刺激 せ ず 、 静か に 様子 を 見 ましょ う 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# ○ ○ 市 の 小学校 について 教え て ください 。
# ○ ○ 小学校 の 住所 は ( 小学校 の 住所 ) です 。 ( 自治体 HP 内 関連 ページ の UR L ) 行き 方 は こちら を ご [UNK] ください 。 ( 自治体 HP 内 関連 ページ の UR L )
#
# おし め の 予防 相談 について 教え て ください 。
# 保健 師 に ご 相談 ください 。 AAA 保健 相談 所 :( 電話 番号 )(○ 時 ○ 分 から ○ 時 ○ 分 ) BB B 保健 相談 所 :( 電話 番号 )(○ 時 ○ 分 から ○ 時 ○ 分 )
#
# 赤ちゃん が 泣き 止 ま ない 。
# ご 心配 です ね 。 赤ちゃん が 泣き やま ない とき は ミルク や お む つ 、 抱 っ こ 等 欲 し がっ て いる と 思う もの を いろいろ 確かめ て み ましょ う 。 生後 1 ~ 2 か月 頃 を ピーク に 何 を し て も 泣き やま ない 時期 が あり ます が 、 それ は 正常 な こと です 。 決して 赤ちゃん の 口 を 塞 い だり 、 激しく 揺 さ ぶ っ たり し て は いけ ませ ん 。 高 熱 が 出 て い たり 、 ご 心配 で あれ ば 医療 機関 を 受 診 し ましょ う 。
#
# 子ども の 体重 の 増え が 悪く なっ て い ます 。
# ご 心配 です ね 。 お 子 さん の 成長 について は 、 保健 師 に ご 相談 ください 。 AAA 保健 相談 所 :( 電話 番号 )(○ 時 ○ 分 から ○ 時 ○ 分 ) BB B 保健 相談 所 :( 電話 番号 )(○ 時 ○ 分 から ○ 時 ○ 分 )
#
# LGBT と は 何 です か ?
# LGBT と は セク シャル ・ マイ ノ リティ 、 性的 少数 者 を 表す 総称 です 。 L ( レズビアン ) は 同性 を 好き に なる 女性 G ( ゲイ ) は 同性 を 好き に なる 男性 B ( バイ セク シュア ル ) は 性別 に かかわら ず 恋愛 対象 に なる 人 T ( トランス ジェン ダー ) は 身体 的 な 性別 と 自 認 する 性 が 一致 し ない ( 性 別 違和 ) 人 。 性 同一 性 障害 の 人 が 含ま れ ます 。 性 分化 疾患 ( DS D ) など も あり 、 実は から だ の 性 も 単純 に は 二 分 でき ませ ん 。 SO G I ( ソ ギ ) と 略さ れる 場合 が 増え て い ます 。 SO = Se x ual Or ient ation ( 性 的 指向 ) GI = Gen der I de n t ity ( 性 自 認 )
#
# ( 子育て 支援 センター 等 の 名称 ) の 名称 ) の 名称 を 教え て ください 。
# ( 子育て 支援 センター 等 の 名称 ) で は 、 ( 実施 し て いる 事業 の 内容 等 を 記載 し て ください ) し て い ます 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# 市 の 保育園 ・ 数 を 教え て ください 。
# 市 の 保育園 ・ 幼 保 一元 化 施設 の 一覧 は こちら を ご [UNK] ください 。 ( 自治体 HP 内 関連 ページ の UR L )
#
# アート スクール について 教え て ください 。
# ( アート スクール について 記載 し て ください 。 ) 例 「 ○ ○ 子育て 支援 センター の アート スクール で は 、 食 ・ もの づくり ・ 体操 ・ 音楽 ・ 写真 など 、 さまざま な 分野 で 活躍 する クリ エー ター を 講師 に 迎え 、 多彩 な テーマ で 講座 を 開催 し て い ます 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )」
#
# ( 当地 当地 グルメ 等 ) について 教え て ください 。
# ( ご 当地 グルメ 等 の 説明 を 記載 し て ください 。 )
#
# 保健 所 ( 保健 相談 所 ) について 教え て ください 。
# 保健 所 (○○ 市 中央 保健 相談 所 ) は ( 所在 場所 ) に あり ます 。 また 、 その他 の 保健 相談 所 が ( 所在 場所 ) と ( 所在 場所 ) に それぞれ あり ます 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# ロ タウ スス の 接種 を 受け なけれ ば なら ない の です か ?
# ロ タウ イルス は 乳 幼 児 の 胃 腸 炎 の 原因 として 上位 を 占め 、 どの お 子 さま で も 5 歳 まで に 1 回 以上 は かかる 感染 症 です 。 嘔 吐 ・ 下痢 が 続き 、 ほとんど の 場合 は 自然 に 回復 し ます が 、 まれ に 脱水 症 で 入院 が 必要 に なっ たり 、 脳 炎 など の 重い 合併症 を 引き起こし たり する こと が あり ます 。 ( 助成 が ある 場合 、 助成 内容 を 記載 し て ください 。 例 「 ○ ○ 市 で は 、 市内 在住 の 生後 6 週 から 32 週 まで の お 子 さま を 対象 として 、 ロ タウ イルス ワ クチン 任意 接種 費用 の 一部 助成 を 実施 し て い ます 。 1 回 8 , 500 円 を 上限 として 2 回 まで 助成 を 行い ます 。 」 ) [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# ○ 年 ○ 月 入 園 の 保育園 の 募集 結果 は い つ です か ?
# ○ 年 4 月 入 園 申 込 の 一 次 募集 の 利用 調整 結果 は ○ 年 ○ 月 ○ 日 (○) を 予定 し て い ます 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# インフルエンザ と お た ふく かぜ の 予防 接種 記録 票 が 送ら れ て き ませ ん 。
# ○ ○ 市 で は 市内 に 住民 登録 の ある お 子 様 へ 予防 接種 す べき 時期 が 近づい たら 予防 接種 記録 票 を お 送り し て い ます 。 送付 時期 は 予防 接種 により 異なり ます ので 、 詳しく は こちら を ご [UNK] ください 。 ( 自治体 HP 内 関連 ページ の UR L )
#
# 乳児 健 診 の 乳児 乳児 の 場所 を 教え て ください 。
# 乳児 健 診 の 実施 場所 は 、 3 から 4 か月 健 診 は AAA 保健 相談 所 で 実施 し て い ます 。 6 から 7 か月 健 診 、 9 から 10 か月 健 診 は 契約 医療 機関 にて 実施 し て い ます 。 [UNK] 契約 医療 機関 について は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# ( 保育 担当 課 ) の 電話 番号 を 教え て ください
# ( 保育 担当 課 ) の 電話 番号 は こちら を ご 確認 ください 。 ( 自治体 HP 内 関連 ページ の UR L )
#
# 児童 扶養 手当 受給 者 へ の 優遇 制度 を 教え て ください 。
# 児童 扶養 手当 の 資格 は 、 お 子 さま の 出生 から 18 歳 に 達し た 日 以降 の 最初 の 3 月 31 日 まで です 。 ( 児童 に 中 度 以上 の 障害 が ある 場合 は 20 歳 未満 まで ) [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# ボタン 電池 について 教え て ください 。
# 万 が 一 お 子 さん が コイン 電池 ・ ボタン 電池 を 誤 飲 、 もしくは その 疑い が ある 場合 は すぐ 医師 等 に 相談 し て ください 。 [UNK] 71 1 9 等 の 救急 相談 センター の 名称 ) ( 電話 番号 )
#
# 禁煙 の 禁煙 公園 について 教え て ください 。
# ○ ○ 市 で は 園内 の 受動 喫煙 防止 対策 として 分 煙 環境 を 整備 する ため 、 市立 公園 ○ か 所 を 、 禁煙 公園 または 分 煙 公園 に 指定 し て い ます 。 [UNK] 禁煙 公園 ・ 分 園 公園 一覧 ( 自治体 HP 内 関連 ページ の UR L )

# %%
ret = evaluate(dataset, predictions)
bleu = eval_qg(res_dict, qg_results)

# %%
ret
# Out:
# {'exact_match': 73.13432835820896, 'f1': 85.23131281829728}

# %%
bleu*100
# Out:
# 34.229906335444866

# %% [markdown]
# ## trainデータで検証

# %%
train_loader, train_examples, train_features = train_data

# %%
all_results = []
qa_results = []
qg_results = {}
res_dict = {}
example_index = -1
qa_posterior_pair = []
qa_prior_pair = []

# %%
for batch in tqdm(train_loader, desc="Eval iter", leave=False, position=4):
    c_ids, q_ids, a_ids, start, end = batch_to_device(batch, args.device)
    batch_size = c_ids.size(0)
    batch_c_ids = c_ids.cpu().tolist()
    batch_q_ids = q_ids.cpu().tolist()
    batch_start = start.cpu().tolist()
    batch_end = end.cpu().tolist()

    batch_posterior_q_ids, \
    batch_posterior_start, batch_posterior_end, \
    posterior_z_prob = trainer.generate_posterior(c_ids, q_ids, a_ids)

    batch_start_logits, batch_end_logits \
    = trainer.generate_answer_logits(c_ids, q_ids, a_ids)

    batch_posterior_q_ids, \
    batch_posterior_start, batch_posterior_end = \
    batch_posterior_q_ids.cpu().tolist(), \
    batch_posterior_start.cpu().tolist(), batch_posterior_end.cpu().tolist()
    posterior_z_prob = posterior_z_prob.cpu()

    batch_prior_q_ids, \
    batch_prior_start, batch_prior_end, \
    prior_z_prob = trainer.generate_prior(c_ids)

    batch_prior_q_ids, \
    batch_prior_start, batch_prior_end = \
    batch_prior_q_ids.cpu().tolist(), \
    batch_prior_start.cpu().tolist(), batch_prior_end.cpu().tolist()
    prior_z_prob = prior_z_prob.cpu()
    
    for i in range(batch_size):
        example_index += 1
        start_logits = batch_start_logits[i].detach().cpu().tolist()
        end_logits = batch_end_logits[i].detach().cpu().tolist()
        train_feature = train_features[example_index]
        unique_id = int(train_feature.unique_id)

        context = to_string(batch_c_ids[i], tokenizer)

        real_question = to_string(batch_q_ids[i], tokenizer)
        posterior_question = to_string(batch_posterior_q_ids[i], tokenizer)
        prior_question = to_string(batch_prior_q_ids[i], tokenizer)

        real_answer = to_string(batch_c_ids[i][batch_start[i]:(batch_end[i] + 1)], tokenizer)
        posterior_answer = to_string(batch_c_ids[i][batch_posterior_start[i]:(batch_posterior_end[i] + 1)], tokenizer)
        prior_answer = to_string(batch_c_ids[i][batch_prior_start[i]:(batch_prior_end[i] + 1)], tokenizer)

        all_results.append(Result(context=context,
                                  real_question=real_question,
                                  posterior_question=posterior_question,
                                  prior_question=prior_question,
                                  real_answer=real_answer,
                                  posterior_answer=posterior_answer,
                                  prior_answer=prior_answer,
                                  posterior_z_prob=posterior_z_prob[i],
                                  prior_z_prob=prior_z_prob[i]))
        
        qa_prior_pair.append([prior_question, prior_answer])
        qa_posterior_pair.append([posterior_question, posterior_answer])

        qg_results[unique_id] = posterior_question
        res_dict[unique_id] = real_question
        qa_results.append(RawResult(unique_id=unique_id,
                                    start_logits=start_logits,
                                    end_logits=end_logits))
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Eval iter', max=19.0, style=ProgressStyle(description_wid…

# %%
output_prediction_file = os.path.join(args.model_dir, "pred.json")
write_predictions(train_examples, train_features, qa_results, n_best_size=20,
                  max_answer_length=100, do_lower_case=True, 
                  output_prediction_file=output_prediction_file,
                  verbose_logging=False,
                  version_2_with_negative=False,
                  null_score_diff_threshold=0,
                  noq_position=True)

# %%
with open(args.train_dir, "r", encoding='utf-8') as f:
    dataset_json = json.load(f)
    dataset = dataset_json["data"]
with open(os.path.join(args.model_dir, "pred.json")) as prediction_file:
    predictions = json.load(prediction_file)

# %%
for pair in qa_prior_pair:
    print(pair[0])
    print(pair[1], '\n')
# Out:
# 母子 手帳 の 受け取り 場所 は どこ です か ?
# 母子 手帳 は 、 ○ ○ 市役所 本庁 舎 △ △ 階 × × 課 窓口 、 [UNK] [UNK] 出張所 、 .........( その他 の 受け取り 場所 を 適 宜 記載 )......... で 受け 取 れ ます 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# 母子 手帳 は すぐ に 発行 し て もらえ ます か ?
# 母子 手帳 は 、 妊娠 届 の 内容 を 確認 さ せ て い た だ き 、 その 場 で お 渡し し ます 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# ● ● 県内 で 引っ越し たら 、 妊 婦 健 診 の 受 診 票 は ?
# 妊 婦 健 診 受 診 票 を お 渡し し て から の 助成 に なり ます 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L ) < 県内 > 受 診 票 の 妊 婦 歯科 健 診 は 、 ○ ○ 市内 のみ で の ご 利用 に なり ます 。 それ 以外 の 受 診 票 は 、 ● ● 県内 共通 に なり ます ので 、 そのまま お 使い い た だ け ます 。 各 自治体 独自 の サービス が 受け られる 場合 が ある ので 、 引っ越し 先 の 自治体 に お 問い合わせ ください 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# ○ ○ 市外 で も 6 ・ 7 か月 健 診 の 受 診 票 は 使え ます か ?
# 受 診 票 は ○ ○ 市外 でも ● ● 県内 の 契約 医療 機関 で あれ ば お 使い い た だ け ます 。 受 診 希望 の 病院 に お 問い合わせ ください 。 契約 医療 機関 について は こちら を ご [UNK] ください 。 ( 自治体 HP 内 関連 ページ の UR L )
#
# ● ● 県内 で 引っ越し たら 、 妊 婦 健 診 の 受 診 票 は ?
# 妊 婦 健 診 受 診 票 を お 渡し し て から の 助成 に なり ます 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L ) < 県内 > 受 診 票 の 妊 婦 歯科 健 診 は 、 ○ ○ 市内 のみ で の ご 利用 に なり ます 。 それ 以外 の 受 診 票 は 、 ● ● 県内 共通 に なり ます ので 、 そのまま お 使い い た だ け ます 。 各 自治体 独自 の サービス が 受け られる 場合 が ある ので 、 引っ越し 先 の 自治体 に お 問い合わせ ください 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# ● ● 県内 で 引っ越し たら 、 妊 婦 健 診 の 受 診 票 は ?
# 受 診 票 の 妊 婦 歯科 健 診 は 、 ○ ○ 市内 のみ で の ご 利用 に なり ます 。 それ 以外 の 受 診 票 は 、 ● ● 県内 共通 に なり ます ので 、 そのまま お 使い い た だ け ます 。 各 自治体 独自 の サービス が 受け られる 場合 が ある ので 、 引っ越し 先 の 自治体 に お 問い合わせ ください 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L ) < 県 外 > 受 診 票 は ご 利用 い た だ け なく なり ます 。 引っ越し 先 の 自治体 に お 問い合わせ ください 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# 妊 婦 健 診 が 14 回 以上 かかり まし た が 、 追加 で 助成 し て もらえ ます か ?
# 妊 婦 健 診 費用 の 助成 は 14 回 まで に なり ます 。 それ 以降 は 自費 で の 対応 を お願い し ます 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# 妊 婦 健 診 受 診 票 の 余り を 換 金 し て もらえ ます か ?
# 妊 婦 健 診 に対する 助成 制度 で あり 、 金 券 で は あり ませ ん 。 その ため 換 金 等 は でき ませ ん 。 < 病院 > < た 分 > < 受 取 > < 還 付 > 妊 婦 健 診 受 診 票 を お 渡し し て から の 助成 に なり ます 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L ) < 県内 > 受 診 票 の 妊 婦 歯科 健 診 は 、 ○ ○ 市内 のみ で の ご 利用 に なり ます 。 それ 以外 の 受 診 票 は 、 ● ● 県内 共通 に なり ます ので 、 そのまま お 使い い た だ け ます 。 各 自治体 独自 の サービス が 受け られる 場合 が ある ので 、 引っ越し 先 の 自治体 に お 問い合わせ ください 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# ● ● 県内 で 引っ越し たら 、 妊 婦 健 診 の 受 診 票 は ?
# 受 診 票 の 妊 婦 歯科 健 診 は 、 ○ ○ 市内 のみ で の ご 利用 に なり ます 。 それ 以外 の 受 診 票 は 、 ● ● 県内 共通 に なり ます ので 、 そのまま お 使い い た だ け ます 。 各 自治体 独自 の サービス が 受け られる 場合 が ある ので 、 引っ越し 先 の 自治体 に お 問い合わせ ください 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# ● ● 県内 で 引っ越し たら 、 子ども の 受 診 票 は ?
# 1 歳 6 か月 健 診 の 受 診 券 は 、 ○ ○ 市内 のみ で の ご 利用 に なり ます 。 それ 以外 の 受 診 票 は 、 ● ● 県内 共通 に なり ます ので 、 そのまま お 使い い た だ け ます 。 各 自治体 独自 の サービス が 受け られる 場合 が ある ので 、 引っ越し 先 の 自治体 に お 問い合わせ ください 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# ● ● 県内 で 引っ越し たら 、 妊 婦 健 診 の 受 診 票 は ?
# 受 診 票 の 妊 婦 歯科 健 診 は 、 ○ ○ 市内 のみ で の ご 利用 に なり ます 。 それ 以外 の 受 診 票 は 、 ● ● 県内 共通 に なり ます ので 、 そのまま お 使い い た だ け ます 。 各 自治体 独自 の サービス が 受け られる 場合 が ある ので 、 引っ越し 先 の 自治体 に お 問い合わせ ください 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# 妊 婦 健 診 受 診 票 の 余り を 換 金 し て もらえ ます か ?
# 妊 婦 健 診 に対する 助成 制度 で あり 、 金 券 で は あり ませ ん 。 その ため 換 金 等 は でき ませ ん 。
#
# 里 帰り 出産 の 際 、 受 診 票 は 使え ます か ?
# ● ● 県 以外 で は 受 診 票 の 利用 は でき ませ ん 。 ご 出産 後 「 里 帰り 等 の 妊 婦 健 診 費用 の 助成 」 として 、 受 診 1 回 あたり の 限度 額 範囲 で 、 母子 手帳 、 領 収 書 、 未 使用 受 診 票 の 枚数 に 応じ て 、 助成 金 を 支給 し ます 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# 子ども が 生まれ たら 、 どんな 手続き が 必要 です か 。
# 出産 後 に 必要 な 手続き は 出生 届 ・ 出生 通知 票 の 提出 、 児童 手当 、 子ども 医療 費 助成 の 申請 等 が あり ます 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# ( 乳 房 ケア に対する 助成 ) について 教え て ください 。
# ( 乳 房 ケア に対する 助成 を 行っ て いる 場合 は 、 申し込み 方法 等 を 記載 し て ください 。 ) 例 「 こん に ち は 赤ちゃん 訪問 の 際 に お 渡し し た ケア 券 に 記載 の 宛 先 ( 助 産 師 会 ) に お 申し込み ください 。 乳 房 ケア 券 が まだ お 手元 に 届い て い ない 場合 は 、 母子 保健 ・ 産 前 産 後 ケア センター へ お 問い合わせ ください 。 [UNK] お 問い合わせ ( 自治体 の 担当 課 等 の 名称 ) ( 電話 番号 )/( 開 庁 時間 )
#
# 赤ちゃん 訪問 の 案内 が き まし た が 、 日時 を 変更 でき ます か ?
# 赤ちゃん 訪問 の 日時 の 変更 は 可能 です 。 変更 に関して は 、 ( 自治体 の 担当 課 や 子育て センター 等 の 名称 ) へ お 問い合わせ ください 。 [UNK] お 問い合わせ ( 自治体 の 担当 課 や 子育て センター 等 の 名称 ) ( 電話 番号 )/( 開 庁 時間 )
#
# 1 か月 健 診 の 助成 は あり ます か ?
# 1 か月 健 診 の 助成 は 実施 し て い ませ ん 。 ○ ○ 市 で は 、 3 ・ 4 か月 健 診 、 1 歳 6 か月 歯科 健 診 、 3 歳 児 健 診 を 、 無料 で 行っ て い ます 。 また 、 6 ・ 7 か月 健 診 、 9 ・ 10 か月 健 診 、 1 歳 6 か月 内科 健 診 について は 、 受 診 票 を 郵 送 し て い ます 。 ● ● 県内 ( 1 歳 6 か月 健 診 は ○ ○ 市内 のみ ) の 契約 医療 機関 に 受 診 票 を お 持ち ください 。 契約 医療 機関 について は こちら を ご [UNK] ください 。 ( 自治体 HP 内 関連 ページ の UR L )
#
# 子ども の 健 診 の 案内 が 来 まし た が 、 指定 さ れ た 日 に 行け ませ ん 。
# 子ども の 健 診 の 指定 日 について 、 ご 都合 が 悪い 場合 は 、 受 診 可能 な 日程 を ご 案内 し ます 。 ( 自治体 の 担当 課 や 子育て センター 等 の 名称 ) へ お 問い合わせ ください 。 [UNK] お 問い合わせ ( 自治体 の 担当 課 や 子育て センター 等 の 名称 ) ( 電話 番号 )/( 開 庁 時間 )
#
# 子ども の 健 診 の 時間 は 、 どの くらい かかり ます か ?
# 健 診 の 時間 は 通常 1 時間 程度 です 。 混 み 具合 や お 子 さん の 健康 状態 により 、 2 時間 から 3 時間 かかる こと も あり ます 。
#
# 乳児 ・ 1 歳 6 か月 歯科 ・ 3 歳 児 健 診 は 、 指定 の 保健 所 ( 保健 相談 所 ) 以外 の 保健 所 ( 保健 相談 所 ) で 受 診 でき ます か ?
# 乳児 ・ 1 歳 6 か月 歯科 ・ 3 歳 児 健 診 は 、 指定 の 保健 所 もしくは 保健 相談 所 を ご 利用 ください 。 日程 が 合 わ ない 等 、 ご 事情 が ござい まし たら 、 指定 の 保健 所 もしくは 保健 相談 所 へ お 電話 ください 。 [UNK] 連絡 先 AAA 保健 相談 所 :( 電話 番号 )/( 開 庁 時間 ) BB B 保健 相談 所 :( 電話 番号 )/( 開 庁 時間 ) CC C 保健 相談 所 :( 電話 番号 )/( 開 庁 時間 )
#
# 9 ・ 10 か月 健 診 の 券 を 失 くし て しまい まし た 。
# 受 診 票 を 再 発行 し ます 。 ( 自治体 の 担当 課 や 子育て センター 等 の 名称 ) へ お 問い合わせ ください 。 [UNK] お 問い合わせ ( 自治体 の 担当 課 や 子育て センター 等 の 名称 ) ( 電話 番号 )/( 開 庁 時間 )
#
# 6 ・ 7 か月 健 診 の 期間 内 に 受 診 でき ませ ん 。
# 健 診 の 期間 を 過ぎる と 助成 を 受ける こと が でき ませ ん 。 受 診 票 は 6 ・ 7 か月 健 診 は お 子 さん が 8 か月 に なる 前日 まで お 使い い た だ け ます 。
#
# 9 ・ 10 か月 健 診 の 期間 内 に 受 診 でき ませ ん 。
# 健 診 の 期間 を 過ぎる と 助成 を 受ける こと が でき ませ ん 。 受 診 票 は 9 ・ 10 か月 健 診 は お 子 さん が 11 か月 に なる 前日 まで お 使い い た だ け ます 。
#
# ○ ○ 市外 で も 6 ・ 7 か月 健 診 の 受 診 票 は 使え ます か ?
# 受 診 票 は ○ ○ 市外 でも ● ● 県内 の 契約 医療 機関 で あれ ば お 使い い た だ け ます 。 受 診 希望 の 病院 に お 問い合わせ ください 。 契約 医療 機関 について は こちら を ご [UNK] ください 。 ( 自治体 HP 内 関連 ページ の UR L )
#
# ○ ○ 市外 で も 1 歳 6 か月 健 診 の 受 診 票 は 使え ます か ?
# 1 歳 6 か月 健 診 の 受 診 票 は ○ ○ 市外 で は ご 利用 でき ませ ん 。 ○ ○ 市内 の 契約 医療 機関 のみ の ご 利用 に なり ます 。 受 診 場所 について は こちら を ご [UNK] ください 。 ( 自治体 HP 内 関連 ページ の UR L )
#
# ○ ○ 市外 で も 6 ・ 7 か月 健 診 の 受 診 票 は 使え ます か ?
# 受 診 票 は ○ ○ 市外 でも ● ● 県内 の 契約 医療 機関 で あれ ば お 使い い た だ け ます 。 受 診 希望 の 病院 に お 問い合わせ ください 。 契約 医療 機関 について は こちら を ご [UNK] ください 。 ( 自治体 HP 内 関連 ページ の UR L )
#
# 1 歳 6 か月 児 健 診 について 教え て ください 。
# 1 歳 6 か月 児 健 診 は 母子 保健 法 に 定め られ た 子ども の 定期 健 診 の 一つ です 。 子ども の 発達 の 状況 を 確認 する とともに 、 歯 の 健 診 も 行い ます 。 対象 の 方 に は 1 歳 ○ か月 に 達する 月 の ( 上旬 / 中旬 / 下旬 ) に 通知 さ れ ます 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# 3 歳 児 健 診 で 尿 が 取れ ませ ん 。
# 3 歳 児 健 診 で 尿 が 取れ ない 場合 でも 、 健 診 後 、 4 歳 に なる 前日 まで に 健 診 受付 時間 内 に 、 尿 を お 持ち い た だ けれ ば 追加 で 検査 でき ます 。 お 子 さん の 成長 に 合わせ て お 持ち ください 。 また 、 健 診 の 朝 の 尿 が 難しい 場合 は 、 健 診 会場 で お 取り い た だ く こと も でき ます 。
#
# 予防 接種 記録 票 の 再 発行 は でき ます か ?
# 予防 接種 記録 票 は 、 対象 の 年齢 で あれ ば 、 再 発行 が 可能 です 。 予防 接種 の 種類 によって 様々 です ので 、 母子 手帳 を ご 用意 の 上 、 お 電話 または 窓口 で お 問い合わせ ください 。 [UNK] お 問い合わせ ( 自治体 の 担当 課 や 子育て センター 等 の 名称 ) ( 電話 番号 )/( 開 庁 時間 )
#
# 里 帰り 先 で 予防 接種 を 受け たい 。
# ● ● 県内 の 指定 医療 機関 で あれ ば 引き続き 、 お 手持ち の 予防 接種 記録 票 ( 予 診 票 ) が 使用 でき ます 。 ● ● 県 外 で の 接種 を 希望 する 場合 は 別途 申請 が 必要 と なり ます 。 [UNK] お 問い合わせ ( 自治体 の 担当 課 や 子育て センター 等 の 名称 ) ( 電話 番号 )/( 開 庁 時間 )
#
# 予防 接種 を 打つ べき 時期 ( 法定 接種 期間 ) を 過ぎ て しまい まし た 。
# 法定 接種 期間 が 過ぎ て しまっ た 場合 は 、 原則 、 自己 負担 ( 自費 ) に なり ます 。 ただし 、 一部 例外 も あり ます ので 、 お 問い合わせ ください 。 [UNK] お 問い合わせ ( 自治体 の 担当 課 や 子育て センター 等 の 名称 ) ( 電話 番号 )/( 開 庁 時間 )
#
# 四 種 混合 の 4 回 目 の 予防 接種 記録 票 の 送付 は あり ます か ?
# 四 種 混合 予防 接種 の 1 期 追加 分 ( 4 回 目 ) は 初回 3 回 接種 後 6 か月 以上 の 間隔 を あ け て 接種 し ます 。 予防 接種 記録 票 は 生後 ○ か月 に 達し た 月末 に 郵 送 い た し ます 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# 産 前 ・ 産 後 の こと について 教え て ください 。
# ○ ○ 市 の 産 前 産 後 の サービス は 、 ( 東京 都 における 「 母子 保健 バッグ 」 等 、 自治体 が 妊 婦 等 に対して 交付 し て いる もの ) を ご [UNK] ください 。 出産 休暇 について は お 勤め 先 に お 問い合わせ ください 。 出産 一 時 金 について は 、 加入 し て いる 健康 保険 組合 等 に お 問い合わせ ください 。
#
# 母子 手帳 の 他 に 産 前 に 市役所 で やる べき 手続き は あり ます か ?
# 産 前 は 母子 手帳 以外 の 手続き は 特に あり ませ ん 。 産 後 に 、 出生 の 届出 や 出生 通知 書 の 提出 、 ( 自治体 が 行う 出産 助成 等 ) の 申請 を お願い し ます 。
#
# 母子 手帳 の 申請 に は 医師 の 診断 書 が 必要 です か ?
# 母子 手帳 の 申請 に は 診断 書 は いり ませ ん が 、 妊娠 届 に 診断 を 受け た 病院 名 ・ 医師 名 を 記入 し て い た だ き ます 。
#
# 子ども が 受 診 票 を 使っ て 妊 婦 健 診 を 受け まし た が 、 もう 上 乗 せ で 毎回 2000 円 支払っ て い まし た 。 その 分 について は 助成 は ない の です か ?
# 病院 によって は 、 受 診 票 の 妊 婦 健 診 に 独自 の 検査 等 を 組み合わせ て いる 場合 が あり ます 。 病院 独自 の 上 乗 せ 部分 について は 、 助成 は あり ませ ん 。
#
# 子ども が 1 歳 6 か月 健 診 を 受け ず に 2 歳 に なり まし た が 、 もう 歯科 の 健 診 は ない の です か ?
# 次 は 3 歳 児 健 診 に なり ます が 、 それ まで に 歯 について 気 に なる こと が あれ ば 、 歯科 専門 相談 を ご 利用 ください 。
#
# 療 育 医療 は どんな 時 に 申請 できる の です か ?
# 18 歳 未満 の 方 で 、 結核 の 治療 の ため 医師 が 指定 医療 機関 に 長期 入院 が 必要 と 認め た 場合 に 、 入院 医療 費 の 助成 と 日 用品 ・ 学 用 品 の 給付 申請 が でき ます 。
#
# 療 育 医療 の 申請 に 必要 な もの は 何 です か ?
# 療 育 医療 の 申請 に は 、 1 療 育 医療 申請 書 、 2 療 育 給付 意見 書 、 3 自己 負担 金 措置 申請 書 、 4 世帯 調 書 、 5 お 子 さん の 健康 保険 証 、 6 乳 幼 児 ( 子ども ) 医療 証 、 7 マイ ナンバー の 記載 に 必要 な 書類 、 8 所得 税 額 証明 書 ( 収入 の ある 方 全員 ) など を 提出 し て ください 。 申請 者 以外 の 方 が 代理 で 申請 する 場合 は 、 委任 状 と 代理人 の 方 の 身元 確認 書類 が 必要 です 。
#
# 養育 医療 の 申請 手続 は いつ まで に すれ ば いい です か ?
# 養育 医療 の 申請 は 退院 ( 清算 ) 後 の 申請 が でき ませ ん 。 入院 中 に できる だけ 早く 申請 し て ください 。 既に 退院 し て いる 場合 は 、 指定 自立 医療 機関 が さかのぼ っ て 養育 医療 の 取扱い を 認め た 場合 に 限り 申請 でき ます 。
#
# 療 育 医療 は どんな 時 に 申請 できる の です か ?
# 18 歳 未満 の 方 で 、 結核 の 治療 の ため 医師 が 指定 医療 機関 に 長期 入院 が 必要 と 認め た 場合 に 、 入院 医療 費 の 助成 と 日 用品 ・ 学 用 品 の 給付 申請 が でき ます 。
#
# 育成 医療 の 申請 場所 を 教え て ください 。
# 育成 医療 の 申請 窓口 は 、 ( 自治体 の 担当 課 等 の 名称 ) です 。
#
# 療 育 医療 の 申請 は 市役所 に 直接 申請 に いか なけれ ば いけ ない の です か ?
# 療 育 医療 の 申請 は 郵 送 ( 簡易 書 留 ) で も でき ます 。
#
# 育成 医療 は どんな 時 に 申請 できる の です か ?
# 身体 に 機能 障害 が ある 18 歳 未満 の 方 で 、 主 に 「 手術 を 伴う 入院 治療 」 など により 機能 回復 が 見込ま れる 場合 に 、 医療 費 の 支給 認定 申請 が でき ます 。 指定 自立 医療 機関 ・ 薬局 で の 保険 内 診療 分 が 対象 です 。
#
# 育成 医療 の 申請 手続 を 教え て ください 。
# 育成 医療 の 申請 は 保護 者 の 住所 地 の 保健 所 に 申請 し ます 。 1 自立 支援 医療 ( 育成 医療 ) 支給 認定 申請 書 、 2 自立 支援 医療 ( 育成 医療 ) 意見 書 、 3 世帯 調 書 、 4 健康 保険 証 、 5 住民 税 額 課税 証明 書 、 6 乳 幼 児 ( 子ども ) 医療 証 、 7 マイ ナンバー の 記載 に 必要 な 書類 、 8 人工 透 [UNK] を 受け て いる 場合 は 、 特定 疾病 療養 受領 証 、 9 免疫 機能 障害 の 方 は 、 免疫 機能 障害 意見 書 など を 提出 し て ください 。 申請 者 以外 の 方 が 代理 で 申請 する 場合 は 、 委任 状 と 代理人 の 方 の 身元 確認 書類 が 必要 です 。 詳しく は お 問い合わせ ください 。 [UNK] お 問い合わせ ( 自治体 の 担当 課 等 の 名称 ) ( 電話 番号 )/( 開 庁 時間 )
#
# 育成 医療 の 申請 に 必要 な もの は 何 です か ?
# 育成 医療 の 申請 に は 、 1 自立 支援 医療 ( 育成 医療 ) 支給 認定 申請 書 、 2 自立 支援 医療 ( 育成 医療 ) 意見 書 、 3 世帯 調 書 、 4 健康 保険 証 、 5 住民 税 額 課税 証明 書 、 6 乳 幼 児 ( 子ども ) 医療 証 、 7 マイ ナンバー の 記載 に 必要 な 書類 、 8 人工 透 [UNK] を 受け て いる 場合 は 、 特定 疾病 療養 受領 証 、 9 免疫 機能 障害 の 方 は 、 免疫 機能 障害 意見 書 など を 提出 し て ください 。 申請 者 以外 の 方 が 代理 で 申請 する 場合 は 、 委任 状 と 代理人 の 方 の 身元 確認 書類 が 必要 です 。 詳しく は お 問い合わせ ください 。 [UNK] お 問い合わせ ( 自治体 の 担当 課 等 の 名称 ) ( 電話 番号 )/( 開 庁 時間 )
#
# 育成 医療 の 申請 手続 は いつ まで に すれ ば いい です か ?
# 育成 医療 の 申請 は 事前 申請 が 原則 です 。 入院 ・ 手術 ・ 通 院 の 予定 が 決まっ たら 、 できるだけ 早く 申請 し て ください 。 治療 が 終了 し て いる 場合 、 指定 自立 医療 機関 が さかのぼ っ て 育成 医療 の 取扱い を 認め ない 場合 は 申請 でき ませ ん 。 また 、 申請 時 に 満 18 歳 に 達し て いる 場合 や 手術 日 が 満 18 歳 に 達し た 日 以降 の 場合 は 対象 外 です 。
#
# 養育 医療 の 申請 場所 を 教え て ください 。
# 養育 医療 の 申請 窓口 は 、 ( 自治体 の 担当 課 等 の 名称 ) です 。
#
# 育成 医療 の 申請 は 市役所 に いか なけれ ば いけ ない の です か ?
# 育成 医療 の 申請 は 郵 送 ( 簡易 書 留 ) で も でき ます 。
#
# 養育 医療 の 申請 手続 は いつ まで に すれ ば いい です か ?
# 養育 医療 の 申請 は 、 保護 者 が 、 お 子 さん の 住所 地 の 保健 所 に 申請 し ます 。
#
# 養育 医療 の 申請 手続 を 教え て ください 。
# 養育 医療 の 申請 は 、 お 子 さん の 住所 地 の 保健 所 に 申請 し ます 。 1 養育 医療 給付 申請 書 、 2 養育 医療 意見 書 、 3 世帯 調 書 、 4 健康 保険 証 ( または 資格 証明 書 )、 5 所得 税 額 証明 書 、 6 乳 幼 児 医療 証 、 7 マイ ナンバー の 記載 に 必要 な 書類 など を 提出 し て ください 。 申請 者 以外 の 方 が 代理 で 申請 する 場合 は 、 委任 状 と 代理人 の 方 の 身元 確認 書類 が 必要 です 。 詳しく は お 問い合わせ ください 。 [UNK] お 問い合わせ ( 自治体 の 担当 課 等 の 名称 ) ( 電話 番号 )/( 開 庁 時間 )
#
# 養育 医療 の 申請 に 必要 な もの は 何 です か ?
# 養育 医療 の 申請 に は 、 1 養育 医療 給付 申請 書 、 2 養育 医療 意見 書 、 3 世帯 調 書 、 4 健康 保険 証 ( または 資格 証明 書 )、 5 所得 税 額 証明 書 、 6 乳 幼 児 医療 証 、 7 マイ ナンバー の 記載 に 必要 な 書類 など の 提出 が 必要 です 。 申請 者 以外 の 方 が 代理 で 申請 する 場合 は 、 委任 状 と 代理人 の 方 の 身元 確認 書類 が 必要 です 。 詳しく は お 問い合わせ ください 。 [UNK] お 問い合わせ ( 自治体 の 担当 課 等 の 名称 ) ( 電話 番号 )/( 開 庁 時間 )
#
# 育成 医療 の 申請 手続 は いつ まで に すれ ば いい です か ?
# 育成 医療 の 申請 は 事前 申請 が 原則 です 。 入院 ・ 手術 ・ 通 院 の 予定 が 決まっ たら 、 できるだけ 早く 申請 し て ください 。 治療 が 終了 し て いる 場合 、 指定 自立 医療 機関 が さかのぼ っ て 育成 医療 の 取扱い を 認め ない 場合 は 申請 でき ませ ん 。 また 、 申請 時 に 満 18 歳 に 達し て いる 場合 や 手術 日 が 満 18 歳 に 達し た 日 以降 の 場合 は 対象 外 です 。
#
# 養育 医療 の 申請 手続 は いつ まで に すれ ば いい です か ?
# 養育 医療 の 申請 は 、 保護 者 が 、 お 子 さん の 住所 地 の 保健 所 に 申請 し ます 。
#
# 育成 医療 の 申請 場所 を 教え て ください 。
# 育成 医療 の 申請 窓口 は 、 ( 自治体 の 担当 課 等 の 名称 ) です 。
#
# 療 育 医療 の 申請 は 市役所 に 直接 申請 に いか なけれ ば いけ ない の です か ?
# 療 育 医療 の 申請 は 郵 送 ( 簡易 書 留 ) で も でき ます 。
#
# 小児 慢性 特定 疾病 の 申請 手続 を 教え て ください 。
# 小児 慢性 特定 疾病 の 申請 は 、 保護 者 の 住所 地 の 保健 所 に 申請 し ます 。 1 小児 慢性 特定 疾病 医療 費 支給 認定 申請 書 兼 同意 書 、 2 小児 慢性 特定 疾病 医療 意見 書 、 3 受 診 医療 機関 申請 書 、 4 世帯 調 書 、 [UNK] 住民 票 、 6 お 子 さん の 健康 保険 証 、 [UNK] 乳 幼 児 ( 子ども ) 医療 証 、 [UNK] マイ ナンバー の 記載 に 必要 な 書類 、 [UNK] 住民 税 課税 ( 非 ) 証明 書 、 10 保険 者 から の 情報 提供 に かかる 同意 書 など を 提出 し て ください 。 申請 者 以外 の 方 が 代理 で 申請 する 場合 は 、 委任 状 と 代理人 の 方 の 身元 確認 書類 が 必要 です 。 詳しく は お 問い合わせ ください 。 [UNK] お 問い合わせ ( 自治体 の 担当 課 等 の 名称 ) ( 電話 番号 )/( 開 庁 時間 )
#
# 小児 慢性 特定 疾病 の 申請 に 必要 な もの は 何 です か ?
# 小児 慢性 特定 疾病 の 申請 に は 、 1 小児 慢性 特定 疾病 医療 費 支給 認定 申請 書 兼 同意 書 、 2 小児 慢性 特定 疾病 医療 意見 書 、 3 受 診 医療 機関 申請 書 、 4 世帯 調 書 、 [UNK] 住民 票 、 6 お 子 さん の 健康 保険 証 、 [UNK] 乳 幼 児 ( 子ども ) 医療 証 、 [UNK] マイ ナンバー の 記載 に 必要 な 書類 、 [UNK] 住民 税 課税 ( 非 ) 証明 書 、 10 保険 者 から の 情報 提供 に かかる 同意 書 など を 提出 し て ください 。 申請 者 以外 の 方 が 代理 で 申請 する 場合 は 、 委任 状 と 代理人 の 方 の 身元 確認 書類 が 必要 です 。 詳しく は お 問い合わせ ください 。 [UNK] お 問い合わせ ( 自治体 の 担当 課 等 の 名称 ) ( 電話 番号 )/( 開 庁 時間 )
#
# 小児 慢性 特定 疾病 の 申請 手続 は いつ まで に すれ ば いい です か ?
# 小児 慢性 特定 疾病 の 申請 は 、 お 子 さん が 18 歳 に なる 前 まで に 申請 し て ください 。
#
# 小児 慢性 特定 疾病 の 申請 手続 は いつ まで に すれ ば いい です か ?
# 小児 慢性 特定 疾病 の 申請 者 と なる 方 は 、 お 子 さん の 健康 保険 の 被 保険 者 です 。 例 ) 父 ( 母 ) の 加入 し て いる 健康 保険 の 被 扶養 者 [UNK] 父 ( 母 ) が 申請 者
#
# 小児 慢性 特定 疾病 の 申請 手続 を 教え て ください 。
# 小児 慢性 特定 疾病 の 申請 窓口 は 、 ( 自治体 の 担当 課 等 の 名称 ) です 。
#
# 小児 慢性 特定 疾病 は 市役所 に 直接 申請 に いか なけれ ば いけ ない の です か ?
# 小児 慢性 特定 疾病 の 申請 は 郵 送 ( 簡易 書 留 ) で も でき ます 。
#
# 児童 手当 の 申請 に 必要 な もの を 教え て ください 。
# 児童 手当 の 申請 に 必要 な もの は 下記 の とおり です 。 1 請求 者 名義 の 金融 機関 の 口座 番号 が わかる もの 2 請求 者 と 配偶 者 の 「 住民 税 課税 ( 非 課 税 ) 証明 書 」 3 印 鑑 ( 朱 肉 を 使う もの ) 4 請求 者 が 厚生 年金 加入 者 ( 被 用 者 ) の 場合 は 、 「 厚生 年金 加入 証明 書 」 (「 健康 保険 証 の コピー 」 で 代え る こと も でき ます 。 ) * 状況 によって は その他 の 書類 が 必要 に なる 場合 が あり ます 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# 児童 手当 の 申請 方法 を 教え て ください 。
# 児童 手当 を 受ける に は 、 認定 請求 が 必要 です 。 まず 、 ○ ○ 市 の ホームページ より 「 児童 手当 ・ 特例 給付 認定 請求 書 」 を ダウンロード し て ご 記入 ください 。 必要 書類 を 添付 し 、 ( 自治体 の 担当 課 等 の 名称 ) へ 郵 送 又は ご 持参 ください 。 【 提出 先 】 ( 自治体 の 担当 課 等 の 名称 、 場所 、 郵 送 する 場合 の 宛 名 及び 住所 等 ) 必要 書類 等 は 以下 の とおり です 。 1 請求 者 名義 の 金融 機関 の 口座 番号 が わかる もの 2 請求 者 と 配偶 者 の 「 住民 税 課税 ( 非 課 税 ) 証明 書 」 3 印 鑑 ( 朱 肉 を 使う もの ) 4 請求 者 が 厚生 年金 加入 者 ( 被 用 者 ) の 場合 は 、 「 厚生 年金 加入 証明 書 」 (「 健康 保険 証 の コピー 」 で 代え る こと も でき ます 。 ) * 状況 によって は その他 の 書類 が 必要 に なる 場合 が あり ます 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L ) [UNK] お 問い合わせ ( 自治体 の 担当 課 等 の 名称 ) ( 電話 番号 )/( 開 庁 時間 )
#
# 第 2 子 出生 後 の 児童 手当 の 手続き を 教え て ください 。
# 「 児童 手当 ・ 特例 給付 額 改定 認定 請求 書 」 を ○ ○ 市 の ホームページ より ダウンロード し て い た だ き 、 必要 事項 を 記入 の 上 、 ( 自治体 の 担当 課 等 の 名称 ) へ 郵 送 又は ご 持参 ください 。 【 提出 先 】 ( 自治体 の 担当 課 等 の 名称 、 場所 、 郵 送 する 場合 の 宛 名 及び 住所 等 ) [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L ) [UNK] お 問い合わせ ( 自治体 の 担当 課 等 の 名称 ) ( 電話 番号 )/( 開 庁 時間 )
#
# 転出 し た 時 の 児童 手当 の 手続き を 教え て ください 。
# 1 .○○ 市 に 転出 届 を 提出 2 .( 自治体 の 担当 課 等 の 名称 ) へ 「 児童 手当 ・ 特例 給付 受給 事由 消滅 届 」 を 提出 3 . 転出 先 で 、 児童 手当 の 申請 を 行う 。 転出 予定 日 の 翌日 から 15 日 以内 に 申請 を 行なっ て ください 。 申請 の 際 に は 「 所得 証明 書 」 が 必要 と なる 場合 が あり ます 。 * 期限 を 経過 する と 手当 を 受け られ ない 月 が 発生 する 場合 が あり ます 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L ) [UNK] お 問い合わせ ( 自治体 の 担当 課 等 の 名称 ) ( 電話 番号 )/( 開 庁 時間 )
#
# 市内 で 引っ越し し た 時 の 児童 手当 の 手続き を 教え て ください 。
# 1 .○○ 市 に 転居 届 を 提出 2 .( 自治体 の 担当 課 等 の 名称 ) へ 「 児童 手当 ・ 特例 給付 住所 等 変更 届 」 を 提出 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L ) [UNK] お 問い合わせ ( 自治体 の 担当 課 等 の 名称 ) ( 電話 番号 )/( 開 庁 時間 )
#
# 児童 手当 の 厚生 年金 加入 証明 書 と は 何 です か ?
# 申請 者 が 被 用 者 ( 厚生 年金 等 加入 者 ) で ある 場合 に 必要 と なる 証明 書 です 。 勤務 先 で 証明 を 受け て ください 。 ただし 、 ご 加入 の 健康 保険 によって は 、 健康 保険 証 の コピー で 代え る こと が でき ます 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L ) [UNK] お 問い合わせ ( 自治体 の 担当 課 等 の 名称 ) ( 電話 番号 )/( 開 庁 時間 )
#
# 夫婦 別 居 する 時 の 児童 手当 の 手続き を 教え て ください 。
# ● 必要 書類 として 「 監 護 事実 の 申 立 書 」 と 「 お 子 様 の 世帯 全員 の 住民 票 ( 続 柄 あり )」 を 提出 する 必要 が あり ます 。 * 受給 者 と お 子 さま の 属する 世帯 の 世帯 主 の 自 署 ・ 押 印 が それぞれ 必要 です 。 ● 離婚 前提 の 別 居 で 受給 者 を 変更 し たい 場合 「 児童 手当 等 の 受給 資格 に 係る 申 立 書 」 と 離婚 協議 中 で ある こと を 明らか に できる 書類 を 提出 する 必要 が あり ます 。 * 状況 によって 、 必要 書類 等 変わる 場合 が あり ます ので 、 詳しく は お 問い合わせ ください 。 [UNK] お 問い合わせ ( 自治体 の 担当 課 等 の 名称 ) ( 電話 番号 )/( 開 庁 時間 )
#
# 離婚 し た 時 の 児童 手当 の 手続き を 教え て ください 。
# # 受給 者 を 変更 する 場合 1 . 離婚 届 を 提出 2 . 現 受給 者 の 「 児童 手当 ・ 特例 給付 受給 事由 消滅 届 」 を 提出 3 . 新しい 受給 者 で 新規 申請 し て い た だ く ため に 「 児童 手当 ・ 特例 給付 認定 請求 書 」 を 提出 4 . 必要 書類 : 離婚 受理 証明 書 又は 戸籍 [UNK] ほか * 状況 によって 、 必要 書類 等 が 変わる 場合 が あり ます ので 、 詳しく は お 問い合わせ ください 。 [UNK] お 問い合わせ ( 自治体 の 担当 課 等 の 名称 ) ( 電話 番号 )/( 開 庁 時間 )
#
# 留学 する 時 の 児童 手当 の 手続き を 教え て ください 。
# お 子 さま が 海外 留学 する 場合 、 「 児童 手当 等 に 係る 海外 留学 に関する 申 立 書 」 と 在学 証明 書 等 留学 の 事実 を 証明 する 書類 〔 書類 が 外国 語 の もの は 、 親族 以外 の 第三者 の 方 が 訳し た 翻訳 書 ( 訳 者 の 署名 ・ 押 印 あり )〕 が 必要 です 。 [UNK] お 問い合わせ ( 自治体 の 担当 課 等 の 名称 ) ( 電話 番号 )/( 開 庁 時間 )
#
# 子ども が 海外 に 住ん で いる 場合 、 児童 手当 は 支給 さ れ ます か ?
# 日本 に 居住 し て い ない と 児童 手当 は 受け 取 れ ませ ん 。 ( 留学 の 場合 は 除く ) [UNK] お 問い合わせ ( 自治体 の 担当 課 等 の 名称 ) ( 電話 番号 )/( 開 庁 時間 )
#
# 子ども が 海外 に 住ん で いる 場合 、 児童 手当 は 支給 さ れ ます か ?
# 戸籍 の 死亡 届 を 出 さ れ て いれ ば 、 児童 手当 の 手続き は 不要 です 。 亡 く なら れ た お 子 さま の 児童 手当 は 、 亡 く なら れ た 月 の 分 まで 支給 さ れ ます 。 * お 子 さま が 複数 人 い て 、 まだ 児童 手当 支給 対象 者 が いる 場合 に は 減 額 の 額 改定 届 が 必要 です 。 [UNK] お 問い合わせ ( 自治体 の 担当 課 等 の 名称 ) ( 電話 番号 )/( 開 庁 時間 )
#
# 親 が 亡くなっ た 時 の 児童 手当 の 手続き を 教え て ください 。
# 児童 手当 の 受給 者 が 亡くなっ た 場合 、 亡くなっ た 日 で 受給 資格 が 消滅 し ます 。 亡 く なら れ た 人 に 代わっ て お 子 さま を 養育 する 保護 者 は 手続き が 必要 です 。 詳しく は お 問い合わせ ください 。 [UNK] お 問い合わせ ( 自治体 の 担当 課 等 の 名称 ) ( 電話 番号 )/( 開 庁 時間 )
#
# 児童 手当 は い つ 振り 込ま れ ます か ?
# 児童 手当 の 支払 月 は 、 2 月 ( 10 ~ 1 月 分 ) ・ 6 月 ( 2 ~ 5 月 分 ) ・ 10 月 ( 6 ~ 9 月 分 ) の 年 3 回 です 。 支払 月 の 前 の 月 まで の 4 か月 分 が まとめ て 支給 さ れ ます 。 また 、 毎回 ○ 日 (○ 日 が 休日 の 場合 の 取り扱い を 記載 し て ください 。 例 「 ○ 日 が 休日 の とき は その 前 営業 日 」 ) に 支払い の 手続き を し ます 。 手続き から ○~○ 日 後 に 振り 込ま れ ます 。 ご 確認 ください 。 [UNK] お 問い合わせ ( 自治体 の 担当 課 等 の 名称 ) ( 電話 番号 )/( 開 庁 時間 )
#
# 児童 手当 が もらえる 月 を 教え て ください
# 児童 手当 の 支払 月 は 、 2 月 ( 10 ~ 1 月 分 ) ・ 6 月 ( 2 ~ 5 月 分 ) ・ 10 月 ( 6 ~ 9 月 分 ) の 年 3 回 です 。 支払 月 の 前 の 月 まで の 4 か月 分 が まとめ て 保護 者 の 口座 に 支給 さ れ ます 。 また 、 毎回 ○ 日 (○ 日 が 休日 の 場合 の 取り扱い を 記載 し て ください 。 例 「 ○ 日 が 休日 の とき は その 前 営業 日 」 ) に 支払い の 手続き を し ます 。 手続き から ○~○ 日 後 に 振り 込ま れ ます 。 ご 確認 下さい 。 上記 内容 を ご 確認 の 上 、 尚 振り 込み が 確認 でき ない 場合 は お 手 数 です が 下記 担当 係 まで ご 連絡 ください 。 [UNK] お 問い合わせ ( 自治体 の 担当 課 等 の 名称 ) ( 電話 番号 )/( 開 庁 時間 )
#
# 児童 手当 の 振 込 口座 を 変更 し たい 。
# # 口座 変更 方法 * 変更 口座 は 、 児童 手当 認定 請求 者 ( 受給 者 ) 本人 の 銀行 口座 に 限り ます 。 「 児童 手当 口座 振 替 依頼 書 」 を ○ ○ 市 の ホームページ より ダウンロード し て い た だ き 、 下記 窓口 まで 郵 送 又は ご 持参 ください 。 【 提出 先 】 ( 自治体 の 担当 課 等 の 名称 、 場所 、 郵 送 する 場合 の 宛 名 及び 住所 等 ) [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L ) [UNK] お 問い合わせ ( 自治体 の 担当 課 等 の 名称 ) ( 電話 番号 )/( 開 庁 時間 )
#
# 児童 手当 の 支給 額 を 教え て ください 。
# [UNK] 0 歳 ~ 3 歳 未満 の お 子 さま は すべて 一 人 につき 15 , 000 円 [UNK] 3 歳 ~ 小学校 修了 前 の 出生 順位 第 1 子 、 第 2 子 の 児童 一 人 につき 10 , 000 円 [UNK] 3 歳 ~ 小学校 修了 前 の 出生 順位 第 3 子 以降 の 児童 一 人 につき 15 , 000 円 [UNK] 中学生 の 子 は すべて 一 人 につき 10 , 000 円 [UNK] 所得 制限 の 限度 額 以上 の 人 は 一律 児童 一 人 につき 5 , 000 円 ( 特例 給付 ) ( 注 ) 出生 順位 は 手当 の 支給 対象 で は ない 18 歳 未満 の 児童 を 含め て 数え ます 。 [UNK] 所得 制限 額 の 詳細 は こちら ( 自治体 HP 内 関連 ページ の UR L ) [UNK] お 問い合わせ ( 自治体 の 担当 課 等 の 名称 ) ( 電話 番号 )/( 開 庁 時間 )
#
# 児童 手当 は い つ 振り 込ま れ ます か ?
# 児童 手当 の 支払 月 は 、 2 月 ( 10 ~ 1 月 分 ) ・ 6 月 ( 2 ~ 5 月 分 ) ・ 10 月 ( 6 ~ 9 月 分 ) の 年 3 回 です 。 支払 月 の 前 の 月 まで の 4 か月 分 が まとめ て 支給 さ れ ます 。 また 、 毎回 ○ 日 (○ 日 が 休日 の 場合 の 取り扱い を 記載 し て ください 。 例 「 ○ 日 が 休日 の とき は その 前 営業 日 」 ) に 支払い の 手続き を し ます 。 手続き から ○~○ 日 後 に 振り 込ま れ ます 。 ご 確認 ください 。 [UNK] お 問い合わせ ( 自治体 の 担当 課 等 の 名称 ) ( 電話 番号 )/( 開 庁 時間 )
#
# 児童 手当 の 更新 について 教え て ください 。
# 児童 手当 は 、 毎年 6 月 1 日 時点 の ご 家族 や 所得 の 状況 について 、 現 [UNK] 届 を 提出 し て い た だ く こと で 更新 と なり ます 。 対象 者 に は ○ 月 中 に 書類 を お 送り し ます 。 現 [UNK] 届 が お 手元 に 届き まし たら 、 現 [UNK] 届 に 必要 事項 を 記入 の 上 、 ご 提出 ください 。 現 [UNK] 届 の 提出 が ない 場合 、 6 月 分 以降 の 児童 手当 が 受給 でき なく なり ます 。 [UNK] 必要 書類 等 、 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L ) [UNK] お 問い合わせ ( 自治体 の 担当 課 等 の 名称 ) ( 電話 番号 )/( 開 庁 時間 )
#
# 児童 手当 現 [UNK] 届 の 提出 を し なかっ たら どう なり ます か ?
# 児童 手当 現 [UNK] 届 の 提出 が ない 場合 、 今後 の 手当 の 支給 が でき なく なり ます 。 期限 が 過ぎ て も 必ず 提出 し て ください 。 なお 、 期日 まで に 提出 が ない 場合 、 次回 の 手当 の 支払い が 遅れる こと が あり ます ので ご 注意 ください 。 さらに 、 2 年間 提出 が ない と 、 受給 権 が 時効 で 消滅 し ます 。 [UNK] お 問い合わせ ( 自治体 の 担当 課 等 の 名称 ) ( 電話 番号 )/( 開 庁 時間 )
#
# 児童 手当 現 [UNK] 届 の 提出 を し なかっ たら どう なり ます か ?
# 児童 手当 現 [UNK] 届 の 提出 が ない 場合 、 今後 の 手当 の 支給 が でき なく なり ます 。 期限 が 過ぎ て も 必ず 提出 し て ください 。 なお 、 期日 まで に 提出 が ない 場合 、 次回 の 手当 の 支払い が 遅れる こと が あり ます ので ご 注意 ください 。 さらに 、 2 年間 提出 が ない と 、 受給 権 が 時効 で 消滅 し ます 。 [UNK] お 問い合わせ ( 自治体 の 担当 課 等 の 名称 ) ( 電話 番号 )/( 開 庁 時間 )
#
# 児童 手当 所得 制限 を 超え たら どう なり ます か ?
# 児童 手当 の 所得 制限 額 を 超 え ます と 、 「 特例 給付 」 と なり まし て 、 当面 の 間 、 中学校 修了 まで の お 子 さま 一 人 につき 月額 一律 5 , 000 円 が 支給 さ れ ます 。 [UNK] 所得 制限 額 の 詳細 は こちら ( 自治体 HP 内 関連 ページ の UR L ) [UNK] お 問い合わせ ( 自治体 の 担当 課 等 の 名称 ) ( 電話 番号 )/( 開 庁 時間 )
#
# 里 帰り 出産 し た 時 の 児童 手当 の 申請 について 教え て ください 。
# 里 帰り 出産 し た 場合 でも 、 ○ ○ 市 に 児童 手当 の 申請 を し て ください 。 申請 期限 は 出生 日 の 翌日 から 数え て 15 日 以内 です 。 郵 送 で も 受け付け て いる ので 、 必ず ご 提出 ください 。 * 児童 手当 請求 者 と 、 子ども の 住民 票 が 異なる 場合 は 、 担当 係 まで お 問い合わせ ください 。 [UNK] お 問い合わせ ( 自治体 の 担当 課 等 の 名称 ) ( 電話 番号 )/( 開 庁 時間 )
#
# 児童 手当 の 申請 期限 を 教え て ください 。
# お 子 さま の 出生 日 ・ ○ ○ 市 に 転入 し た 日 の 翌日 から 15 日 以内 に 申請 し て い た だ く 必要 が あり ます 。 期限 を 過ぎ て しまっ た 場合 に は 、 支給 開始 が 遅れ て し まい ます が 、 申請 の 翌月 分 から 支給 でき ます ので 、 できるだけ 早め に ご 申請 ください 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L ) [UNK] お 問い合わせ ( 自治体 の 担当 課 等 の 名称 ) ( 電話 番号 )/( 開 庁 時間 )
#
# 児童 手当 の 申請 手続 を 教え て ください 。
# お 子 さま の 父 又は 母 の うち 、 主たる 生計 維持 者 ( 所得 の 高い 人 ) が 請求 者 に なり ます 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L ) [UNK] お 問い合わせ ( 自治体 の 担当 課 等 の 名称 ) ( 電話 番号 )/( 開 庁 時間 )
#
# 児童 手当 の 制度 について 教え て ください 。
# 児童 手当 は 、 中学 3 年 生 まで の 児童 を 養育 し て いる 人 に 一定 の 額 を 支給 する 手当 です 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L ) [UNK] お 問い合わせ ( 自治体 の 担当 課 等 の 名称 ) ( 電話 番号 )/( 開 庁 時間 )
#
# 児童 手当 の 手続き は ( 自治体 の 支所 ・ 出張所 等 ) で でき ます か ?
# ( 自治体 の 支所 ・ 出張所 等 で の 取り扱い を 記載 し て ください 。 ) 例 「 出張所 で は 、 出生 届 又は 転入 届 を 提出 さ れ た 時 のみ 、 同時に 児童 手当 の 手続き を する こと が でき ます 。 」 [UNK] お 問い合わせ ( 自治体 の 担当 課 等 の 名称 ) ( 電話 番号 )/( 開 庁 時間 )
#
# 児童 手当 の 手続き は 郵 送 で でき ます か ?
# 郵 送 で の 手続き も 可能 です 。 ただし 、 ( 自治体 の 担当 課 等 の 名称 ) に 認定 請求 書 等 が 到着 し た 日 が 受付 日 と なり ます ので 、 出生 日 ・ 転出 予定 日 の 翌日 から 数え て 15 日 以内 に ( 自治体 の 担当 課 等 の 名称 ) へ 到着 する よう に 送付 し て ください 。 【 提出 先 】 ( 自治体 の 担当 課 等 の 名称 、 場所 、 郵 送 する 場合 の 宛 名 及び 住所 等 ) [UNK] お 問い合わせ ( 自治体 の 担当 課 等 の 名称 ) ( 電話 番号 )/( 開 庁 時間 )
#
# 施設 など に 入所 し た 時 の 児童 手当 の 手続き を 教え て ください 。
# 児童 養護 施設 等 に 入所 し て いる お 子 さま は 、 施設 の 設置 者 等 が 児童 手当 を 受給 し ます 。 既に ○ ○ 市 から 手当 受給 中 の お 子 さま が 施設 に 入所 する 場合 に は 、 「 児童 手当 ・ 特例 給付 受給 事由 消滅 届 」 が 必要 です 。 [UNK] お 問い合わせ ( 自治体 の 担当 課 等 の 名称 ) ( 電話 番号 )/( 開 庁 時間 )
#
# 児童 手当 で 必要 な 所得 証明 書 について 教え て ください 。
# 児童 手当 で 必要 な 所得 証明 書 と は 「 住民 税 課税 ( 非 課 税 ) 証明 書 」 の こと です 。 必要 な 年度 の 証明 書 は 前年度 の 1 月 1 日 に 在住 し て い た 市区 町村 の 住民 税 担当 課 で 発行 し ます 。 例 ) 平成 29 年度 住民 税 課税 ( 非 課 税 ) 証明 書 は 、 29 年 1 月 1 日 に 在住 し て い た 市区 町村 で 発行 。 * 勤務 先 で 発行 さ れる 源泉 徴収 票 、 住民 税 決定 通知 書 等 で は 代用 でき ませ ん 。 [UNK] お 問い合わせ ( 自治体 の 担当 課 等 の 名称 ) ( 電話 番号 )/( 開 庁 時間 )
#
# 転出 先 で 必要 な 所得 証明 書 の 請求 方法 を 教え て ください 。
# 所得 証明 書 ( 住民 税 課税 ( 非 課 税 ) 証明 書 ) は 住民 税 担当 課 で 請求 が でき ます 。 転出 先 で 必要 と なる 証明 書 の 年度 を ご 確認 の う え 、 必要 年度 の 前年度 の 1 月 1 日 に 在住 し て い た 市区 町村 の 住民 税 担当 課 で 請求 し て ください 。 例 ) 平成 29 年度 住民 税 課税 ( 非 課 税 ) 証明 書 は 、 29 年 1 月 1 日 に 在住 し て い た 市区 町村 で 請求 。 [UNK] ○ ○ 市 で の お 問い合わせ ( 自治体 の 担当 課 等 の 名称 ) ( 電話 番号 )/( 開 庁 時間 )
#
# 食 育 について の イベント を 教え て ください 。
# ( 食 育 について の イベント について 記載 し て ください 。 ) ( 自治体 HP 内 関連 ページ の UR L )
#
# ( 自治体 の 施設 内 で 開催 さ れる 子ども ・ 保護 者 向け プログラム や イベント 等 ) について 教え て ください 。
# ( 自治体 の 施設 内 で 開催 さ れる 子ども ・ 保護 者 向け プログラム や イベント 等 の 説明 を 記載 し て ください 。 ) [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# 保育 室 と は 何 です か ?
# 保育 室 と は 、 ● ● 県 の 定める 設置 基準 を 満たし た 、 産 休 明け から 2 歳 まで の お 子 さん を 預 かる 小規模 な 保育 施設 です 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# AAA 保育園 について 教え て ください 。
# AAA 保育園 は 、 ( 住所 ) に ある 市立 ( 保育園 / 幼 保 一元 化 施設 ) です 。 詳しく は こちら を ご [UNK] ください 。 ( 自治体 HP 内 関連 ページ の UR L )
#
# 児童 手当 受給 者 の 所得 が 逆転 し た 時 は ?
# 所得 が 逆転 し た 場合 は 、 受給 者 を 変更 し て い た だ き ます 。 現 受給 者 による 「 児童 手当 ・ 特例 給付 受給 事由 消滅 届 」 の 提出 と 新 受給 者 による 新規 申請 手続き が 必要 です 。 [UNK] お 問い合わせ ( 自治体 の 担当 課 等 の 名称 ) ( 電話 番号 )/( 開 庁 時間 )
#
# 児童 手当 保留 通知 が 届き まし た 。
# 児童 手当 の 申請 について 、 不足 書類 の ある 人 に 保留 通知 を お 送り し て い ます 。 保留 通知 に 記載 さ れ て いる 書類 の 提出 を お願い し ます 。 [UNK] お 問い合わせ ( 自治体 の 担当 課 等 の 名称 ) ( 電話 番号 )/( 開 庁 時間 )
#
# 母子 手帳 を なくし た 場合 は 再 発行 でき ます か ?
# 母子 手帳 を なくし た とき は 、 再 交付 を 受け て ください 。 お 子 さん が 出生 前 の 母子 手帳 について は 、 ( 再 交付 を 受け られる 場所 ) で 再 交付 を 受け られ ます 。 お 子 さん が 出生 後 の 母子 手帳 について は 、 ( 再 交付 を 受け られる 場所 ) で 受け られ ます 。 申請 の 際 は ご 本人 確認 できる もの を お 持ち ください 。 [UNK] お 問い合わせ ( 自治体 の 担当 課 等 の 名称 ) ( 電話 番号 )/( 開 庁 時間 )
#
# スポーツ センター について 教え て ください 。
# スポーツ センター は ご 利用 に なる 施設 により 利用 時間 が 異なり ます 。 詳しく は こちら を ご [UNK] ください 。 ( 自治体 HP 内 関連 ページ の UR L )
#
# ひとり 親 手当 の 所得 制限 を 教え て ください 。
# ひとり 親 家庭 へ の 手当 の 所得 制限 は 、 それぞれ の 制度 によって 異なり ます 。 詳しく は 下記 を ご [UNK] ください 。 [UNK] 各 手当 所得 制限 限度 額 ( 自治体 HP 内 関連 ページ の UR L )
#
# 予防 接種 の 問い合わせ 窓口 を 教え て ください 。
# 予防 接種 について は 下記 に お 問い合わせ ください 。 [UNK] お 問い合わせ ( 自治体 の 担当 課 等 の 名称 ) ( 電話 番号 )/( 開 庁 時間 )
#
# 出産 の 不安 を 相談 できる ところ は あり ます か ?
# ○ ○ 市 で は 、 妊娠 し た 人 と パートナー を 対象 に 、 これから の 子育て や 、 地域 で 子育て を する ため の 仲間 づくり に 役立つ よう に 、 ( 母親 学級 等 の イベント ) を 開催 し て い ます 。 ( イベント の 内容 等 を 記載 し て ください 。 ) [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# 児童 手当 の 申請 を 忘れ て しまい まし た 。
# 出生 日 ・ 転入 し た 日 の 翌日 から 15 日 を 過ぎ て しまっ た 場合 に は 、 支払い が 遅れ て しまう 可能 性 が あり ます が 、 児童 手当 は 、 申請 の 翌月 分 から 支給 でき ます ので 、 できるだけ 早め に 申請 し て ください 。 [UNK] お 問い合わせ ( 自治体 の 担当 課 等 の 名称 ) ( 電話 番号 )/( 開 庁 時間 )
#
# ○ ○ 市立 保育園 の 定員 を 教え て ください 。
# ○ ○ 市立 ( 保育園 / 幼 保 一元 化 施設 ) の 定員 は こちら を ご [UNK] ください 。 ( 自治体 HP 内 関連 ページ の UR L )
#
# 市立 、 私立 保育園 の 違い は 何 です か ?
# 市立 保育園 は 、 市 が 設置 ・ 運営 し て い ます 。 私立 保育園 は 、 社会 福祉 法人 等 が 設置 ・ 運営 し て おり 、 保育 方針 や 施設 の 雰囲気 など に それぞれ 特色 が あり ます 。 保育 料 は 市立 ・ 私立 による 違い は あり ませ ん が 、 延長 保育 料 は 、 施設 により 異なり ます 。
#
# どんな 書類 を 教え て ください 。
# 転 園 申 込 書 は 下記 ホームページ から ダウンロード が でき ます 。 PD F を 印刷 し て 記載 し て ください 。 その他 の 必要 書類 について は 入 園 の 申し込み と 同様 、 下記 を ご [UNK] ください 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# ( 自治体 が 行う 出産 助成 等 ) は いくら もらえ ます か ?
# ( 自治体 が 行う 出産 助成 等 ) は ( 助成 額 等 の 内容 を 記載 し て ください 。 ) と なり ます 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# 市役所 は いつ まで 開い て ます か ?
# ○ ○ 市役所 の 開 庁 時間 は ○ 時 ○ 分 から ○ 時 ○ 分 ( 土曜日 ・ 日曜日 、 祝 ・ 休日 および 12 月 29 日 ~ 1 月 3 日 を 除く ) です 。
#
# ○ ○ 子育て 支援 センター で やっ て いる イベント を 教え て ください 。
# ○ ○ 子育て 支援 センター で 行っ て いる 催し 物 は こちら を ご [UNK] ください 。 ( 自治体 HP 内 関連 ページ の UR L )
#
# 市内 の 認定 こども 園 の 場所 を 教え て ください 。
# ○ ○ 市内 の 認定 こども 園 について は こちら を ご [UNK] ください 。 ( 自治体 HP 内 関連 ページ の UR L )
#
# 戸籍 の 届出 について 教え て ください 。
# 戸籍 の 平日 夜間 や 休日 の 届出 は 、 ( 受付 場所 ) で 行っ て い ます 。 夜間 ・ 休日 窓口 で は 、 届 書 の 受領 ( 預かり ) のみ 行っ て い ます 。 翌 開 庁 日 以降 に 戸籍 事務 担当 職員 が 届 書 の 記載 内容 ・ 添付 書類 など の 審査 を 行う ため 、 来 庁 を お願い する 場合 が あり ます 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# 本 日 営業 し て いる 病院 を 教え て ください 。
# ( 都道府県 や 医師 会 が 提供 する 医療 機関 案内 等 の 名称 ) で ご 確認 い た だ け ます 。 [UNK] 詳しく は こちら ( 当該 医療 機関 案内 等 の UR L )
#
# 氏名 が 変わっ た 時 の 児童 手当 は ?
# 「 児童 手当 ・ 特例 給付 氏名 変更 届 」 を 提出 し て い た だ き ます 。 氏名 変更 の 理由 によって は ( 例 . 婚姻 )、 別途 書類 の 提出 を お願い する 場合 が あり ます 。 [UNK] お 問い合わせ ( 自治体 の 担当 課 等 の 名称 ) ( 電話 番号 )/( 開 庁 時間 )
#
# ( 子育て 支援 情報 を まとめ た リーフ レット 等 ) について 教え て ください 。
# ( 子育て 支援 情報 を まとめ た リーフ レット 等 を 作成 し て いる 場合 は 、 説明 を 記載 し て ください 。 ) [UNK] 配布 場所 は こちら ・ AAA ・ BB B
#
# 子ども ・ 子育て 支援 新 制度 について 教え て ください 。
# 子ども ・ 子育て 支援 新 制度 と は 、 平成 24 年 8 月 に 成立 し た 「 子ども ・ 子育て 支援 法 」 、 「 認定 こども 園 法 の 一部 改正 」 、 「 子ども ・ 子育て 支援 法 及び 認定 こども 園 法 の 一部 改正 法 の 施行 に 伴う 関係 法律 の 整備 等 に関する 法律 」 の 子ども ・ 子育て 関連 3 法 に 基づく 制度 の こと を いい ます 。
#
# 市 の 奨学 資金 制度 について 教え て ください 。
# 市 の 奨学 資金 制度 は 、 経済 的 理由 により 高校 など へ の 進学 や 修学 が 困難 な 人 に 、 奨学 資金 を お 貸し する 制度 です 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# 戸籍 の 届出 は 何 時 まで 受け付け て い ます か ?
# 戸籍 の 平日 夜間 や 休日 の 届出 は 、 ( 受付 場所 ) で 行っ て い ます 。 夜間 ・ 休日 窓口 で は 、 届 書 の 受領 ( 預かり ) のみ 行っ て い ます 。 翌 開 庁 日 以降 に 戸籍 事務 担当 職員 が 届 書 の 記載 内容 ・ 添付 書類 など の 審査 を 行う ため 、 来 庁 を お願い する 場合 が あり ます 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# 創業 支援 について 教え て ください 。
# ○ ○ 市 の 創業 支援 事業 について は こちら を ご [UNK] ください 。 ( 自治体 HP 内 関連 ページ の UR L )
#
# 保育 士 の 募集 は し て い ます か ?
# ○ ○ 市 の 保育 士 の 募集 について は こちら を ご 確認 ください 。 ( 自治体 HP 内 関連 ページ の UR L )
#
# ( 住民 票 ・ 戸籍 担当 課 ) の 窓口 の 混雑 状況 を 教え て ください
# ( 混雑 状況 等 の お 知 ら せ システム が ある 場合 は 、 説明 を 記載 し て ください 。 ) 例 「 ( 住民 票 ・ 戸籍 担当 課 ) 窓口 の 混雑 状況 は こちら を ご 確認 ください 。 ( 自治体 HP 内 関連 ページ の UR L )」
#
# AAA 保健 相談 所 の 電話 番号 を 教え て ください
# AAA 保健 相談 所 の 電話 番号 は 、 ( 電話 番号 ) です 。 ( 自治体 HP 内 関連 ページ の UR L )
#
# 単身 赴任 ( 国内 ) し た 時 の 児童 手当 は ?
# # 児童 手当 の 受給 者 が 単身 赴任 で ○ ○ 市外 に 引っ 越 さ れる 場合 ( 国内 ) 1 .○○ 市 に 転出 届 を 提出 2 .( 自治体 の 担当 課 等 の 名称 ) に 「 児童 手当 ・ 特例 給付 受給 事由 消滅 届 」 を 提出 3 . 転出 先 で 、 児童 手当 の 申請 を 行う [UNK] お 問い合わせ ( 自治体 の 担当 課 等 の 名称 ) ( 電話 番号 )/( 開 庁 時間 )
#
# ( 自治体 が 開催 する 親子 教室 等 ) について 教え て ください 。
# ( 自治体 が 開催 する 親子 教室 等 の 説明 を 記載 し て ください 。 ) [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# 入院 助 産 ( 転校 の 手続き を 教え て ください 。
# ○ ○ 市 に お 住まい で 、 かつ 私立 等 の 小中学校 から 市立 の 小中学校 へ の 転校 を ご 希望 の 方 は 、 市役所 △ 階 ( 自治体 の 担当 課 等 の 名称 ) に 申し出 て ください 。 編入 学 について は 学区 域 の 学校 へ の 就学 と なり ます 。 [UNK] お 問い合わせ ( 自治体 の 担当 課 等 の 名称 ) ( 電話 番号 )/( 開 庁 時間 )
#
# 住民 票 は 代理人 も 受け 取 れ ます か ?
# 住民 票 の 写し の 請求 など を 本人 の 代理人 が 行う 場合 は 、 代理人 の 本人 確認 書類 や 委任 状 等 が 必要 に なり ます 。 [UNK] 必要 な 書類 等 、 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# 市 の 就学 援助 について 教え て ください 。
# ○ ○ 市 で は 、 国 公 立 の 小中学校 に 通う 児童 ・ 生徒 の 保護 者 の 方 に 、 ご 家庭 の 事情 に 応じ て 学校 で かかる 費用 を 補助 し て い ます 。 詳しい こと は 、 学校 を通じて お 知 ら せ し ます 。 ○ ○ 市立 以外 の 国 公 立 小 ・ 中学校 へ 通っ て いる 場合 は 、 下記 まで お 問い合わせ ください 。 [UNK] お 問い合わせ ( 自治体 の 担当 課 等 の 名称 ) ( 電話 番号 )/( 開 庁 時間 )
#
# 一時 保育 は 当日 キャンセル でき ます か ?
# ( キャンセル の 場合 の 対応 を 記載 し て ください 。 ) 例 「 一時 保育 を キャンセル さ れる 場合 は 、 各 施設 へ お 早め に ご 連絡 ください 。 当日 キャンセル の 場合 、 キャンセル 料 が 発生 する 場合 が あり ます 。 詳しく は 各 施設 へ お 問い合わせ ください 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# 転入 し た とき 、 小学校 の 手続き は どう し たら いい です か ?
# 転入 の 際 、 小学校 の 手続き として は 、 転入 手続 の 際 に 、 就学 通知 書 を お 渡し し て い ます 。 前 の 学校 の 在学 証明 書 など とともに 、 指定 の 学校 に 提出 し て 入学 し て ください 。 なお 、 転 入学 さ れる 方 について も 、 学校 選択 希望 制 による 学校 選択 が 可能 です 。 受 入 人数 や 学年 によって 状況 が 異なり ます ので 詳しく は お 問い合わせ ください 。 [UNK] お 問い合わせ ( 自治体 の 担当 課 等 の 名称 ) ( 電話 番号 )/( 開 庁 時間 )
#
# 子ども が 低 体重 で 心配 です 。
# 出生 通知 票 は 、 低 体重 児 届 を かね て い ます 。 出生 通知 書 に ご 記入 の 上 提出 し て ください 。 低 体重 、 授 乳 の 方法 や 体重 の 増え 方 など 、 心配 ごと が ある 人 に は 「 新生 児 訪問 事業 」 として 、 助 産 師 や 地区 担当 保健 師 が 早め の 訪問 を さ せ て い た だ く 場合 が あり ます 。 入院 中 の 人 は 、 電話 連絡 で も 結 構 です 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# 居 宅 訪問 型 保育 事業 と は 何 です か ?
# 居 宅 訪問 型 保育 事業 と は 、 お 子 様 を ご 自宅 で 1 対 1 で 保育 する 事業 です 。 障害 児 を 対象 と する 事業 と 待機 児童 を 対象 と する 事業 が あり ます 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# 単身 赴任 ( 国外 ) し た 時 の 児童 手当 は ?
# # 児童 手当 の 受給 者 が 単身 赴任 で 国外 へ 引っ 越 さ れる 場合 1 .○○ 市 に 転出 届 を 提出 2 .( 自治体 の 担当 課 等 の 名称 ) に 「 児童 手当 ・ 特例 給付 受給 事由 消滅 届 」 を 提出 3 . 配偶 者 の 方 で 児童 手当 の 新規 申請 を 行う [UNK] お 問い合わせ ( 自治体 の 担当 課 等 の 名称 ) ( 電話 番号 )/( 開 庁 時間 )
#
# AAA 保育園 の 一時 保育 について 教え て ください 。
# AAA 保育園 で 実施 し て いる 一時 保育 について は こちら を ご [UNK] ください 。 ( 自治体 HP 内 関連 ページ の UR L )
#
# パスポート の 申請 に 必要 な 書類 を 教え て ください 。
# パスポート を 新規 に 発給 する 際 に 必要 な 書類 について は こちら を ご [UNK] ください 。 http s :// www . m of a . go . jp / m of aj / to ko / p ass port / p ass _ 5 . h t m l # 01 ( この ほか 、 都道府県 パスポート センター の UR L ・ 電話 番号 等 を 記載 する こと も 考え られ ます 。 )
#
# 妊娠 届 について 教え て ください 。
# 妊娠 し た 人 は 、 ( 市役所 ○ ○ 課 、 保健 所 、 保健 相談 所 等 の 妊娠 届 を 出せる 場所 を 記載 し て ください 。 ) で 妊娠 届 を 出し て ください 。 ( 母子 手帳 や 妊 婦 健 診 の 受 診 票 など 、 妊娠 し た 人 に お 渡し する もの ) を さし あげ ます 。 なるべく 早め の 届出 を お願い し ます 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# 子ども の 補助 金 の 申請 手続き を 教え て ください 。
# 幼稚園 など で 配布 し て いる 申請 書 「 ( 補助 金 申請 書 の タイトル )」 に 必要 事項 を 明記 し 、 幼稚園 へ 提出 し て ください 。 当該 年度 に ○ ○ 市 の 住民 税 が 課税 さ れ て い ない 人 は 、 当該 年度 の 「 市区 町 村民 税 納税 ( 税 額 ) 通知 書 」 または 当該 年度 の 「 課税 ( 非 課 税 ) 証明 書 」 を 提出 し て ください 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# ○ ○ 市立 幼稚園 の 抽選 は 、 幼稚園 が 行う の です か 。
# ○ ○ 市立 幼稚園 の 入 園 の 選考 は 、 ○ ○ 市 教育 委員 会 が 行い ます 。
#
# ( 自治体 の 古 着 など の 拠点 回収 ) について 教え て ください 。
# 家庭 で 不 用 に なっ た 、 再 使用 できる 衣類 等 を 拠点 回収 し て い ます 。 回収 さ れ た もの は 、 国内 や 国外 で 再 使用 ( リ ユース ) さ れ ます 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# 出生 届 は 誰 が 届出 すれ ば いい です か ?
# 出生 届 は 父 または 母 が 届出 人 と なり ます 。 届 書 を 父母 以外 の 人 が 持参 する 場合 でも 、 父 ・ 母 が 届出 人 として 署名 押 印 が 必要 です 。 ただし 、 父母 が 法律 上 婚姻 し て い ない 場合 、 母 が 届出 人 と なり ます 。 父 または 母 が 届出 でき ない 場合 、 同居 者 または 出産 に 立ち 会 っ た 医師 ・ 助 産 師 が 届出 を する 必要 が あり ます 。 詳しく は ( 自治体 の 担当 課 等 の 名称 ) まで お 問い合わせ ください 。 [UNK] お 問い合わせ ( 自治体 の 担当 課 等 の 名称 ) ( 電話 番号 )/( 開 庁 時間 )
#
# ごみ の 分 別 について 教え て ください 。
# ごみ の 分 別 について 、 よく 質問 さ れる 品目 の 一覧 は こちら を ご [UNK] ください 。 ( 自治体 HP 内 関連 ページ の UR L ) 特定 の 品目 について お 知り に なり たい 場合 は 品目 名 を 教え て ください 。
#
# ( 自治体 が 開催 する 幼児 食 講習 会 等 ) について 教え て ください 。
# ( 自治体 が 開催 する 幼児 食 講習 会 等 ) は 、 ○ 月 ○ 日 (○) に 行わ れ ます 。 時間 :○:○~○:○ 場所 :○○○○○ 持ち 物 :○○○○○ [UNK] 申し込み は こちら ( 電話 番号 )/( 開 庁 時間 )
#
# いじめ の 相談 は どこ に すれ ば いい です か ?
# いじめ や ひき こ も り 等 に関する 相談 は 「 ( 自治体 が 設置 する 相談 窓口 等 )」 に ご 相談 ください 。 ( 相談 窓口 等 の 説明 を 記載 し て ください 。 ) [UNK] お 問い合わせ ( 自治体 が 設置 する 相談 窓口 等 の 名称 ) ( 電話 番号 )/( 相談 受付 日時 )
#
# ○ ○ 市 に 幼稚園 は いくつ あり ます か ?
# ○ ○ 市 の 幼稚園 について は こちら を ご 確認 ください 。 [UNK] 市立 幼稚園 一覧 ( 自治体 HP 内 関連 ページ の UR L ) ○ ○ 市 で は 、 市立 幼稚園 に 入 園 できる の は ○ 歳 児 (○ 年 保育 ) と ○ 歳 児 (○ 年 保育 ) です 。 [UNK] 私立 幼稚園 一覧 ( 自治体 HP 内 関連 ページ の UR L ) 私立 幼稚園 の 場合 、 原則 として 3 歳 児 から 最長 3 年 保育 が 可能 です 。 詳しく は 入 園 を 希望 する 幼稚園 へ お 問い合わせ ください 。
#
# 子ども の 予防 接種 について 教え て ください 。
# 子ども の 予防 接種 に は 法律 で 市区 町村 が 接種 を 行う こと が 定め られ て いる 「 定期 予防 接種 」 と 、 それ 以外 の 任意 で 受け られる 「 任意 予防 接種 」 が あり ます 。 ○ ○ 市 で は 、 定期 予防 接種 と 一部 の 任意 予防 接種 について 、 助成 制度 を 設け て い ます 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# ○ ○ 市 の 面積 を 教え て ください 。
# ○ ○ 市 の 面積 は ○ ○ 平方キロメートル です 。 ( この ほか 、 ○ ○ 市 の 面積 について の 特徴 等 が あれ ば 、 適 宜 記載 し て ください )
#
# 子ども 医療 費 助成 について 教え て ください 。
# 乳 幼 児 ( 子ども ) 医療 費 助成 制度 は 、 医療 費 に かかる 保護 者 の 負担 を 軽減 する こと を 目的 として 、 ○ ○ 市 が 医療 費 の 一部 を 助成 する 制度 です 。 乳 幼 児 医療 証 は 小学校 就学 前 の 乳 幼 児 、 子ども 医療 証 は 小学 1 年 生 から 中学 3 年 生 まで の 児童 を 対象 に 発行 し て い ます 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# 3 歳 児 健 診 の 次 の 健 診 は い つ です か ?
# 健 診 の 日時 や 場所 は お 住まい の 地域 により 異なり ます 。 次 の 健 診 の 日時 等 は 電話 で お 問い合わせ ください 。 [UNK] お 問い合わせ ( 自治体 の 担当 課 等 の 名称 ) ( 電話 番号 )/( 開 庁 時間 )
#
# 子育て の イベント は あり ます か ?
# ( 自治体 の 担当 課 や 子育て センター 等 の 名称 ) で は 、 毎月 定期 的 に 催し 物 を 行っ て い ます 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# 母子 手帳 は 転出 し て も そのまま 持っ て い て よい です か ?
# 母子 手帳 は 住所 が 変わっ て も そのまま お 使い い た だ け ます 。 再 発行 等 の 手続 は 必要 あり ませ ん 。 [UNK] お 問い合わせ ( 自治体 の 担当 課 や 子育て センター 等 の 名称 ) ( 電話 番号 )/( 開 庁 時間 )
#
# 自転車 放置 禁止 区域 について 教え て ください 。
# 自転車 放置 禁止 区域 について は こちら で ご 確認 ください 。 ( 自治体 HP 内 関連 ページ の UR L )
#
# 保育園 の 募集 時期 は い つ です か ?
# 翌年 4 月 入 園 の 申し込み は 毎年 ○ 月頃 から 受け付け て い ます 。 4 月 以外 の 入 園 について も 申し込み は 受け付け て い ます 。 入 園 申 込 の 締 切 日 等 は 、 以下 の ページ より ご 確認 ください 。 ( 自治体 HP 内 関連 ページ の UR L )
#
# 国民 健康 保険 証 を 紛失 し まし た 。
# 国民 健康 保険 証 を 紛失 し た 場合 は 、 窓口 で 再 発行 し ます ので 、 本人 確認 が できる もの を 持っ て 、 ( 申請 場所 ( 自治体 の 担当 課 、 支所 ・ 出張所 等 )) の 窓口 まで お 越し ください 。
#
# 就 園 奨励 費 の 手続き について 教え て ください 。
# 就 園 奨励 費 の 申請 は 、 幼稚園 など で 配布 し て いる 申請 書 「 ( 申請 書 の タイトル )」 に 必要 事項 を 明記 し 、 幼稚園 へ 提出 し て ください 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# 乳 幼 児 ・ 子ども 医療 証 の 発行 申請 は 郵 送 で も でき ます か ?
# 申請 期限 は あり ませ ん が 、 助成 を 受け られる の は 申請 の 日 から です 。 ただし 、 出生 ・ 転入 から 14 日 以内 に 申請 する と 、 出生 ・ 転入 の 日 から 有効 です 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# 離婚 の 手続き を 教え て ください 。
# 離婚 する 場合 は 届出 が 必要 と なり ます 。 [UNK] 離婚 届 について は こちら を ご [UNK] ください ( 自治体 HP 内 関連 ページ の UR L )
#
# 市役所 の 開 庁 時間 を 教え て ください 。
# ○ ○ 市役所 内 の 駐車 場 ・ 駐 輪 場 について は こちら を ご [UNK] ください 。 ( 自治体 HP 内 関連 ページ の UR L )
#
# 家事 を 手伝っ て くれる サービス は あり ます か 。
# ( 家事 支援 等 を 行っ て いる 場合 は 記載 し て ください 。 ) 例 「 中学生 以下 の 児童 を 扶養 し て いる ひとり 親 家庭 を 対象 に 家事 援助 者 派遣 事業 を 実施 し て い ます 。 家事 など 日常 生活 に 支障 が ある とき 、 保護 者 が 在 宅 し て いる 時間 帯 に 家事 援助 者 を 派遣 し ます 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )」
#
# 子ども の 不 登校 を 相談 できる ところ は あり ます か ?
# ( 自治体 の 担当 課 等 の 名称 ) で は 、 子ども に関する 様々 な 悩み や 問題 について 相談 に 応じ たり 、 学校 に 行け ない 児童 ・ 生徒 の 元気 回復 や 学習 の 支援 を 行っ て い ます 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# 乳 幼 児 ・ 子ども 医療 証 の 発行 申請 に 必要 な もの を 教え て ください 。
# 乳 幼 児 ・ 子ども 医療 証 の 発行 を 受ける に は 、 お 子 さん の 健康 保険 証 の コピー を 添え て 、 乳 幼 児 ・ 子ども 医療 証 交付 申請 書 を 下記 窓口 まで ご 提出 ください 。 ( 郵 送 受付 可 ) ただし 、 ○ ○ 市 国民 健康 保険 に ご 加入 の 場合 は 、 健康 保険 証 の コピー は 不要 です 。 ※ 出生 し た ばかり で お 子 さん の 健康 保険 証 が 手元 に ない 場合 は 、 父母 の 健康 保険 証 など 、 ご 加入 予定 の 健康 保険 の 保険 証 の コピー を 添え て ください 。 後日 、 お 子 さん の 健康 保険 証 の コピー を ご 提出 い た だ く よう お願い い た し ます 。 【 提出 先 】 ( 自治体 の 担当 課 等 の 名称 、 場所 、 郵 送 する 場合 の 宛 名 及び 住所 等 ) [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# 印 鑑 登録 の 手続き について 教え て ください 。
# 印 鑑 登録 申請 ( 本人 による 申請 ) の 手続き について は こちら を ご [UNK] ください 。 ( 自治体 HP 内 関連 ページ の UR L ) 代理人 による 申請 手続き について は こちら を ご [UNK] ください 。 ( 自治体 HP 内 関連 ページ の UR L )
#
# 妊 婦 健 診 や 乳児 健 診 等 が 受け られる 契約 医療 機関 は どこ です か ?
# 妊 婦 健 診 や 乳児 健 診 等 が 受け られる 市内 の 契約 医療 機関 について は こちら を ご [UNK] ください 。 ( 自治体 HP 内 関連 ページ の UR L )
#
# 資源 ごみ について 教え て ください 。
# 資源 ごみ と は 、 蛍光 管 類 、 スプ レー 缶 ・ カセット ボン ベ 、 古 紙 、 びん 、 缶 、 ペット ボ トル など です 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# 市役所 の 開 庁 時間 を 教え て ください 。
# ○ ○ 市役所 の 開 庁 時間 は ○ 時 ○ 分 から ○ 時 ○ 分 ( 土曜日 ・ 日曜日 、 祝 ・ 休日 および 12 月 29 日 ~ 1 月 3 日 を 除く ) です 。
#
# 近く の 公園 を 教え て ください 。
# ( 位置 情報 を 利用 し て 近隣 の 施設 を 検索 する 機能 が ある 場合 は 、 検索 方法 を 記載 し て ください 。 ) 例 「 お 近く の 公園 は 、 メニュー の 周辺 施設 検索 より 探す こと が でき ます 。 周辺 施設 検索 を タップ し て 位置 情報 を 送っ て ください 。 」
#
# 乳 幼 児 ・ 子ども 医療 証 の 発行 申請 は 郵 送 で も でき ます か ?
# 乳 幼 児 ・ 子ども 医療 証 の 発行 は 郵 送 で も 申請 が でき ます 。 お 子 さん の 健康 保険 証 の コピー を 添え て 、 乳 幼 児 ・ 子ども 医療 証 交付 申請 書 を 下記 窓口 まで 郵 送 し て ください 。 【 提出 先 】 ( 自治体 の 担当 課 等 の 名称 、 場所 、 郵 送 する 場合 の 宛 名 及び 住所 等 ) [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# 子ども の 保険 証 の 手続き について 教え て ください 。
# 出生 し た ばかり で お 子 さん の 健康 保険 証 が 手元 に ない 場合 は 、 父母 の 健康 保険 証 など 、 ご 加入 予定 の 健康 保険 の 保険 証 の コピー を 添え て ください 。 後日 、 お 子 さん の 健康 保険 証 の コピー を ご 提出 い た だ く よう お願い い た し ます 。 ただし 、 ○ ○ 市 国民 健康 保険 に ご 加入 の 場合 は 、 健康 保険 証 の コピー は 不要 です 。 【 提出 先 】 ( 自治体 の 担当 課 等 の 名称 、 場所 、 郵 送 する 場合 の 宛 名 及び 住所 等 ) [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# 子ども の 医療 証 は 市外 の 病院 で も 使え ます か ?
# 乳 幼 児 ・ 子ども 医療 証 は ● ● 県内 で あれ ば 使え ます 。 健康 保険 証 と 一緒 に 医療 機関 の 窓口 で 医療 証 を ご 提示 ください 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# 子ども の 医療 証 は ● ● 県 外 の 病院 で も 使え ます か ?
# 乳 幼 児 ・ 子ども 医療 証 は ● ● 県 外 の 医療 機関 で は 使え ませ ん 。 健康 保険 証 のみ を 使っ て い た だ き 、 自己 負担 し た 残り の 分 は 、 ○ ○ 市 へ 払い 戻し の 申請 を し て ください 。 ※ ただし 、 県内 ・ 県 外 を 問わ ず 、 健康 保険 証 を 使わ ず に 全額 自己 負担 し た 場合 、 コル セット や 弱 視 用 眼鏡 など 医療 用 の 補 装 具 を 購入 し た 場合 、 または 入院 し て 医療 費 が 高額 に なっ た 場合 に は 、 この 支給 申請 前 に 加入 さ れ て いる 健康 保険 へ の 手続き が 必要 と なり ます 。 [UNK] 支給 申請 は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# 子ども の 医療 証 の 再 発行 は でき ます か ?
# 乳 幼 児 ・ 子ども 医療 証 は 再 発行 が でき ます 。 「 乳 幼 児 ・ 子ども 医療 証 再 交付 申請 書 」 を 下記 窓口 まで ご 提出 ください 。 ( 郵 送 受付 可 ) 申請 後 、 再 発行 し た 医療 証 を 郵 送 い た し ます 。 【 提出 先 】 ( 自治体 の 担当 課 等 の 名称 、 場所 、 郵 送 する 場合 の 宛 名 及び 住所 等 ) [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# 市内 で 引っ越し し た とき の 乳 幼 児 ・ 子ども 医療 証 の 手続き を 教え て ください 。
# 乳 幼 児 ・ 子ども 医療 証 の 住所 が 変わっ た とき は 、 子ども 医療 費 助成 申請 事項 変更 届 を 下記 窓口 まで ご 提出 ください 。 申請 後 、 新しい 医療 証 を 郵 送 い た し ます 。 なお 、 新しい 医療 証 が 届く まで の 間 は そのまま 古い 医療 証 を お 使い ください 。 【 提出 先 】 ( 自治体 の 担当 課 等 の 名称 、 場所 、 郵 送 する 場合 の 宛 名 及び 住所 等 ) [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# 氏名 が 変わっ た とき の 乳 幼 児 ・ 子ども 医療 証 の 手続き を 教え て ください 。
# 乳 幼 児 ・ 子ども 医療 証 の 氏名 が 変わっ た とき は 、 子ども 医療 費 助成 申請 事項 変更 届 を 下記 窓口 まで ご 提出 ください 。 申請 後 、 新しい 医療 証 を 郵 送 い た し ます 。 なお 、 新しい 医療 証 が 届く まで の 間 は そのまま 古い 医療 証 を お 使い ください 。 【 提出 先 】 ( 自治体 の 担当 課 等 の 名称 、 場所 、 郵 送 する 場合 の 宛 名 及び 住所 等 ) [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# 子ども の 医療 証 の 保護 者 の 変更 は でき ます か ?
# 子ども の 医療 証 の 保護 者 の 変更 を する 場合 は 、 子ども 医療 費 助成 申請 事項 変更 届 を 下記 窓口 まで ご 提出 ください 。 申請 後 、 新しい 医療 証 を 郵 送 い た し ます 。 なお 、 新しい 医療 証 が 届く まで の 間 は そのまま 古い 医療 証 を お 使い ください 。 【 提出 先 】 ( 自治体 の 担当 課 等 の 名称 、 場所 、 郵 送 する 場合 の 宛 名 及び 住所 等 ) [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# 子ども の 医療 証 を 使わ ず に 病院 を 受 診 し て しまっ た の です が 。
# 医療 機関 で 自己 負担 し た 分 は 、 ○ ○ 市 へ 払い 戻し の 申請 を し て ください 。 ※ ただし 、 県内 ・ 県 外 を 問わ ず 、 健康 保険 証 を 使わ ず に 全額 自己 負担 し た 場合 、 コル セット や 弱 視 用 眼鏡 など 医療 用 の 補 装 具 を 購入 し た 場合 、 または 入院 し て 医療 費 が 高額 に なっ た 場合 に は 、 この 支給 申請 前 に 加入 さ れ て いる 健康 保険 へ の 手続き が 必要 と なり ます 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# 子ども の 医療 証 は 健康 診断 で も 使え ます か ?
# 健康 診断 に 乳 幼 児 ・ 子ども 医療 証 は 使え ませ ん 。
#
# 子ども の 医療 証 は 予防 接種 で も 使え ます か ?
# 予防 接種 に 乳 幼 児 ・ 子ども 医療 証 は 使え ませ ん 。
#
# 入院 時 の 食事 療養 費 を 払っ た とき は 払い 戻し でき ます か ?
# 入院 時 の 食事 療養 費 の 自己 負担 分 ( 子ども の 医療 費 ) は 、 ○ ○ 市 へ 払い 戻し の 申請 を し て ください 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# 子ども の 医療 証 は 補 装 具 の 助成 対象 です か ?
# 補 装 具 を 購入 し た 場合 は 、 加入 し て いる 健康 保険 組合 等 に 医療 費 申請 を し た う え で 、 ○ ○ 市 へ 払い 戻し の 申請 を し て ください 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# 子ども の 医療 証 の 払 戻 ( 現金 給付 ) の 申請 期限 は ?
# 子ども の 医療 証 の 払 戻 の 申請 期限 は 、 原則 領 収 印 の 日付 から 5 年間 です 。 ただし 、 健康 保険 証 を 使わ ず に 全額 自己 負担 し た 場合 、 コル セット や 弱 視 用 眼鏡 など 医療 用 の 補 装 具 を 購入 し た 場合 は 別途 ご 相談 ください 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# 子ども の 医療 証 の 払 戻 ( 現金 給付 ) の 申請 は 郵 送 で も でき ます か ?
# 子ども の 医療 証 の 払 戻 申請 は 郵 送 で も でき ます 。 領 収 書 の 原本 と お 子 様 の 健康 保険 証 の コピー を 添え て 、 子ども 医療 助成 費 支給 申請 書 を 下記 まで ご 提出 ください 。 【 提出 先 】 ( 自治体 の 担当 課 等 の 名称 、 場所 、 郵 送 する 場合 の 宛 名 及び 住所 等 ) [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# 子ども の 医療 証 は 更新 が あり ます か ?
# ( 更新 時 の 取り扱い について 記載 し て ください 。 ) 医療 証 は 毎年 更新 さ れ 、 有効 期限 は 毎年 9 月 30 日 まで です 。 10 月 1 日 以降 の 新しい 医療 証 は 、 自動的 に ご 自宅 へ 郵 送 い た し ます 。 この ほか 、 小学校 へ 入学 する お 子 さん は 3 月 31 日 に 乳 幼 児 医療 証 の 有効 期限 が 切れ る ので 、 4 月 1 日 以降 の 子ども 医療 証 を 自動的 に ご 自宅 へ 郵 送 い た し ます 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# 児童 扶養 手当 は いつ まで 支給 さ れ ます か ?
# 児童 扶養 手当 の 資格 は 、 お 子 さま の 出生 から 18 歳 に 達し た 日 以降 の 最初 の 3 月 31 日 まで です 。 ( 児童 に 中 度 以上 の 障害 が ある 場合 は 20 歳 未満 まで ) [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# ひとり 親 手当 の 所得 制限 を 教え て ください 。
# ひとり 親 家庭 へ の 手当 の 所得 制限 は 、 それぞれ の 制度 によって 異なり ます 。 詳しく は 下記 を ご [UNK] ください 。 [UNK] 各 手当 所得 制限 限度 額 ( 自治体 HP 内 関連 ページ の UR L )
#
# 児童 扶養 手当 の 申請 に 必要 な もの を 教え て ください 。
# 児童 扶養 手当 の 申請 に 必要 な もの は 下記 の とおり です 。 1 申請 者 と 児童 の 戸籍 [UNK] 2 申請 者 名義 の 銀行 口座 の わかる もの 3 所得 証明 書 ( 公 簿 により 確認 できる 場合 は 、 必要 あり ませ ん ) 4 申請 者 と 児童 が 加入 し て いる 健康 保険 証 5 印 鑑 他 状況 によって 必要 な 書類 が 異なり ます 。 詳しく は 、 ( 自治体 の 担当 課 等 の 名称 ) まで お 問い合わせ ください 。 [UNK] お 問い合わせ ( 自治体 の 担当 課 等 の 名称 ) ( 電話 番号 )/( 開 庁 時間 )
#
# 児童 扶養 手当 ( ひとり 親 手当 ) は 郵 送 で も 申請 でき ます か ?
# 児童 扶養 手当 ( ひとり 親 手当 ) の 申請 は 、 窓口 で の 面 談 が 必要 に なり ます 。 ( 自治体 の 担当 課 等 の 名称 ) まで お 越し ください 。
#
# 児童 扶養 手当 ( ひとり 親 手当 ) は ( 自治体 の 支所 ・ 出張所 等 ) で 申請 でき ます か ?
# 児童 扶養 手当 ( ひとり 親 手当 ) の 申請 は 、 窓口 で の 面 談 が 必要 に なり ます 。 ( 自治体 の 支所 ・ 出張所 等 ) で は 申請 でき ませ ん 。 ( 自治体 の 担当 課 等 の 名称 ) まで お 越し ください 。
#
# 児童 扶養 手当 ( ひとり 親 手当 ) は 未婚 でも 受け られ ます か ?
# ひとり 親 手当 は 未婚 で も 受給 でき ます が 、 その ほか 受給 条件 が あり ます 。 詳しく は 以下 の ページ を ご [UNK] い た だ く か 、 または ( 自治体 の 担当 課 等 の 名称 ) まで お 問い合わせ ください 。 ( 自治体 HP 内 関連 ページ の UR L ) [UNK] お 問い合わせ ( 自治体 の 担当 課 等 の 名称 ) ( 電話 番号 )/( 開 庁 時間 )
#
# 児童 扶養 手当 ( ひとり 親 手当 ) 受給 者 が 市内 で 住所 が 変わっ た 時 の 手続き を 教え て ください 。
# 児童 扶養 手当 ( ひとり 親 手当 ) 受給 者 が 市内 で 転居 さ れ た 場合 は 、 ( 自治体 の 担当 課 等 の 名称 ) にて 住所 変更 の 手続き が 必要 です 。
#
# 児童 扶養 手当 ( ひとり 親 手当 ) 受給 者 が 市外 から 転出 する 際 の 手続き を 教え て ください 。
# 児童 扶養 手当 ( ひとり 親 手当 ) 受給 者 が 市外 へ 転出 する 場合 は 、 ( 自治体 の 担当 課 等 の 名称 ) にて 住所 変更 の 手続き が 必要 です 。
#
# 児童 扶養 手当 ( ひとり 親 手当 ) 受給 者 が 市外 から 転出 する 際 の 手続き を 教え て ください 。
# 児童 扶養 手当 ( ひとり 親 手当 ) 受給 者 が 市外 へ 転出 する 場合 は 、 ( 自治体 の 担当 課 等 の 名称 ) にて 住所 変更 の 手続き が 必要 です 。
#
# ( 自治体 で 実施 さ れ て いる 病院 を 教え て ください 。
# ( 申請 方法 、 有効 期限 、 更新 等 の 手続き について 記載 し て ください 。 )
#
# 児童 扶養 手当 は 離婚 調停 中 でも 申請 でき ます か ?
# 離婚 調停 中 は 児童 扶養 手当 の 申請 は でき ませ ん 。 離婚 が 成立 し て から 申請 し て ください 。
#
# 児童 扶養 手当 が 認定 さ れる まで の 期間 は 。
# 児童 扶養 手当 は 、 必要 書類 が 揃っ て から 、 認定 まで 約 ○ か月 程 かかり ます 。
#
# 児童 扶養 手当 ( ひとり 親 手当 ) は 郵 送 で も 申請 でき ます か ?
# 児童 扶養 手当 ( ひとり 親 手当 ) の 申請 は 、 窓口 で の 面 談 が 必要 に なり ます 。 ( 自治体 の 担当 課 等 の 名称 ) まで お 越し ください 。
#
# 子ども が 生まれ たら 、 どの よう な 手当 が あり ます か 。
# 子ども の 手当 ・ 助成 として は 、 児童 手当 と 子ども 医療 費 助成 制度 が あり ます 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L ) [UNK] お 問い合わせ ( 自治体 の 担当 課 等 の 名称 ) ( 電話 番号 )/( 開 庁 時間 )
#
# 入院 時 の 食事 療養 費 を 払っ た とき は 払い 戻し でき ます か ?
# 入院 時 の 食事 療養 費 の 自己 負担 分 ( 子ども の 医療 費 ) は 、 ○ ○ 市 へ 払い 戻し の 申請 を し て ください 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# 児童 扶養 手当 受給 者 で 子ども が 死亡 し た 場合 は ?
# 児童 扶養 手当 受給 者 で 子ども が 死亡 し た 場合 、 児童 扶養 手当 受給 資格 が 喪失 し ます 。 ( 自治体 の 担当 課 等 の 名称 ) にて 資格 喪失 届 を 提出 し て ください 。
#
# 児童 扶養 手当 の 現 [UNK] 届 の 時期 は ?
# 児童 扶養 手当 の 現 [UNK] 届 は 、 毎年 8 月 です 。 8 月 中 の 提出 が ない と 今後 の 手当 の 支給 が 遅れる こと が あり ます 。 また 必要 書類 によって は 、 提出 が 遅れる こと で 支給 額 が 減 額 さ れる こと が あり ます 。
#
# 児童 扶養 手当 の 現 [UNK] 届 を 出さ ない と どう なり ます か ?
# 児童 扶養 手当 の 現 [UNK] 届 の 提出 が ない 場合 、 現 [UNK] 届 が 提出 さ れる まで の 期間 、 手当 の 支給 が 停止 し ます 。 現 [UNK] 届 未 提出 者 は 、 未 提出 状況 が 2 年間 継続 する と 、 自動的 に 資格 喪失 と なり ます 。
#
# 再婚 ( 事実 婚 ) し たら 児童 扶養 手当 は どう なり ます か ?
# 再婚 ( 事実 婚 含む ) さ れ た 場合 、 児童 扶養 手当 の 受給 資格 は 喪失 し ます 。 ( 自治体 の 担当 課 等 の 名称 ) にて 速やか に 資格 喪失 届 を 提出 し て ください 。 申請 が 遅れる と 、 再婚 ( 事実 婚 ) 後 に も 手当 が 支給 さ れ て し まい ます 。 その 場合 は 支給 さ れ た 手当 を 返還 する 必要 が あり ます ので ご 注意 ください 。
#
# 児童 扶養 手当 額 は 収入 が 変化 し たら 変わり ます か ?
# 児童 扶養 手当 の 手当 額 は 、 1 年間 の 所得 額 に 応じ て 決定 し ます 。 毎年 8 月 の 現 [UNK] 届 提出 時 に 、 前年 の 所得 を 確認 し て その 年度 の 手当 額 を 決定 し ます 。
#
# 児童 扶養 手当 ( ひとり 親 手当 ) は 郵 送 で も 申請 でき ます か ?
# 児童 扶養 手当 ( ひとり 親 手当 ) の 申請 は 、 窓口 で の 面 談 が 必要 に なり ます 。 ( 自治体 の 担当 課 等 の 名称 ) まで お 越し ください 。
#
# ひとり 親 手当 の 所得 制限 を 教え て ください 。
# ひとり 親 家庭 へ の 手当 の 所得 制限 は 、 それぞれ の 制度 によって 異なり ます 。 詳しく は 下記 を ご [UNK] ください 。 [UNK] 各 手当 所得 制限 限度 額 ( 自治体 HP 内 関連 ページ の UR L )
#
# ( 自治体 の 子育て 支援 センター 等 の 名称 ) の 利用 日 や 利用 時間 について 教え て ください 。
# ( 自治体 の 子育て 支援 センター 等 の 名称 ) の 利用 時間 は ( 利用 可能 日時 を 記載 し て ください 。 例 「 月 火 木 土 の 9 : 30 ~ 16 : 30 と 水 9 : 00 ~ 12 : 00 」) です 。 ただし 、 ( 年末年始 等 の 休 館 日 を 記載 し て ください 。 例 「 日 ・ 祝日 及び 12 / 29 ~ 1 / 3 」) は お 休み です 。
#
# ( 自治体 の 子育て 支援 センター 等 の 名称 ) の 利用 日 や 利用 時間 について 教え て ください 。
# ( 自治体 の 子育て 支援 センター 等 の 名称 ) の 利用 時間 は ( 利用 可能 日時 を 記載 し て ください 。 例 「 月 火 木 土 の 9 : 30 ~ 16 : 30 と 水 9 : 00 ~ 12 : 00 」) です 。 ただし 、 ( 年末年始 等 の 休 館 日 を 記載 し て ください 。 例 「 日 ・ 祝日 及び 12 / 29 ~ 1 / 3 」) は お 休み です 。
#
# ( 自治体 の 子育て 支援 センター 等 の 名称 ) の 利用 に 予約 は 必要 です か 。
# ( 予約 の 必要 の 有無 について 記載 し て ください 。 )
#
# ( 子育て 支援 施設 において 実施 する 支援 事業 等 ) の 利用 日 や 時間 について 教え て ください 。
# ( 子育て 支援 施設 において 実施 する 支援 事業 等 ) の 利用 は ( 利用 可能 日時 を 記載 し て ください ) です 。 ただし 日 ・ 祝日 及び 12 / 29 ~ 1 / 3 は お 休み です 。 施設 ごと の 休 館 日 も あり ます 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# ( 子育て 支援 施設 において 実施 する 支援 事業 等 ) の 利用 日 や 時間 について 教え て ください 。
# ( 子育て 支援 施設 において 実施 する 支援 事業 等 ) の 利用 は ( 利用 可能 日時 を 記載 し て ください ) です 。 ただし 日 ・ 祝日 及び 12 / 29 ~ 1 / 3 は お 休み です 。 施設 ごと の 休 館 日 も あり ます 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# ( 支所 ・ 出張所 、 市民 サービス センター 等 ) の 開設 時間 を 教え て ください 。
# ( 支所 ・ 出張所 、 市民 サービス センター 等 ) の 開設 時間 は 平日 ( 月曜日 ~ 金曜日 )○ 時 ~○ 時 土曜日 ○ 時 ~○ 時 (※) に なり ます 。 (※) × 時 ~ × 時 の 入口 は 限ら れ ます 。 取扱 業務 を 確認 の 上 ご 利用 ください 。 日曜日 、 祝 ・ 休日 、 年末年始 は 閉 設 し ます 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# 保育園 は 何 か所 まで 希望 でき ます か ?
# 認可 保育園 、 市立 幼 保 一元 化 施設 及び 小規模 保育 事業 は あわせ て 最大 ○ 園 まで 、 市立 保育 室 及び 居 宅 訪問 型 保育 事業 は 最大 あわせ て ○ 園 まで 希望 の 申し込み が でき ます 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# セク ハラ について 相談 する 場所 を 教え て ください 。
# セク ハラ 、 DV など の 相談 は ( 自治体 の 担当 課 や 女性 相談 センター 等 の 名称 ) で 受け付け て い ます 。 ( 事前 予約 の 必要 性 、 相談 方法 ( 面 談 、 電話 等 ) 等 の 説明 を 記載 し て ください 。 ) [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# ( スポーツ センター 等 において 実施 さ れる 子ども 向け スポーツ 教室 等 ) について 教え て ください 。
# ( スポーツ センター 等 において 実施 さ れる 子ども 向け スポーツ 教室 等 ) は 、 ( 対象 年齢 ) を 対象 と し た 子ども 向け ○ ○ 教室 です 。 ( 教室 等 の 内容 、 特徴 を 記載 し て ください 。 ) [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# 課税 証明 書 の 申請 について 教え て ください 。
# 住民 税 課税 ( 非 課 税 ) 証明 書 は 、 ( 申請 場所 ( 自治体 の 担当 課 、 支所 ・ 出張所 等 )) で 申請 でき ます 。 申請 に は 本人 確認 の ため の 身分 証明 書 が 必要 です 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# がん 検 診 について 教え て ください 。
# がん 検 診 に は 「 がん 一 次 検 診 」 と 「 新た な ステージ に 入っ た がん 検 診 の 総合 支援 事業 」 の 2 種類 が あり ます 。 対象 者 に は クー ポン 券 ・ 検 診 の お 知 ら せ など を 送付 し ます 。 40 歳 以上 の 対象 者 に は 複数 の クー ポン 券 が 届く こと が あり ます 。 [UNK] がん 一 次 検 診 ( 自治体 HP 内 関連 ページ の UR L ) [UNK] 新た な ステージ に 入っ た がん 検 診 の 総合 支援 事業 ( 自治体 HP 内 関連 ページ の UR L )
#
# 子宮 がん 検 診 について 教え て ください 。
# ...
#
# 肺炎 球菌 定期 予防 接種 について 教え て ください 。
# 肺炎 球菌 予防 接種 は 、 平成 26 年 10 月 1 日 より 、 定期 予防 接種 に なり まし た 。 過去 に 肺炎 球菌 ワクチン を 接種 し た こと の ない 、 初めて 接種 する 人 が 対象 と なり ます 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# 学校 施設 の 開放 について 教え て ください 。
# 地域 の スポーツ 交流 、 コミュニケーション を 図る 場 として 、 学校 教育 に 支障 の ない 範囲 で 学校 施設 を 開放 し て い ます 。 使用 できる 施設 は 体育館 ・ 校 庭 、 会議 室 等 です 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# 子ども が 遊 べ る 公園 を 教え て ください 。
# ○ ○ 公園 に は ドッグ ラン が あり ます 。 ( 利用 方法 を 記載 し て ください 。 例 「 ご 利用 に は 公園 管理 センター で の 登録 が 必要 です 。 」 ) [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# 動物 の 死体 処理 について 教え て ください 。
# 飼っ て い た 動物 の 死体 が 処理 でき ない とき 、 または 公道 上 に 放置 さ れ て いる とき について は こちら を ご [UNK] ください 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# ○ ○ 市 清掃 事務所 の 場所 を 教え て ください 。
# ○ ○ 市 清掃 事務所 の 場所 について は こちら を ご 確認 ください 。 ( 自治体 HP 内 関連 ページ の UR L )
#
# ( 保育園 等 に 在籍 する 保護 者 向け 緊急 メール 等 ) について 教え て ください 。
# ( 保育園 等 に 在籍 する 保護 者 向け 緊急 メール 等 ) と は 、 ( システム の 説明 を 記載 ください 。 ) です 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# 保育園 の ポイント 計算 方法 を 教え て ください 。
# ( 利用 調整 基準 表 の 計算 方法 を 記載 し て ください 。 ) 例 「 利用 調整 基準 表 の 基本 指数 に 調整 指数 を 加算 又は 減 算 し 、 指数 が 高い 方 から 入 園 できる よう 調整 し ます 。 指数 が 同じ 場合 は 、 「 同一 指数 と なっ た 場合 の 優先 順位 」 により 判断 し ます 。 なお 、 原則 として ○ ○ 市民 ( 転入 予定 を 含む 。 ) を 優先 し ます 。 [UNK] 利用 調整 基準 表 ( 自治体 HP 内 関連 ページ の UR L ) [UNK] 同 一 指数 と なっ た 場合 の 優先 順位 ( 自治体 HP 内 関連 ページ の UR L )」
#
# AD HD について 教え て ください 。
# AD HD は At te n t ion Def ic it Hy per act iv ity Dis ord er の 略 で 、 発達 段階 に 不 釣り 合い な 注意 力 や 衝動 性 、 多 動 性 を 特徴 と する 神経 発達 症 もしくは 行動 障害 です 。 お 子 さん の 成長 や 性格 、 生活 環境 や 事情 によって 解決 策 が 違い ます 。 まずは 保健 師 に ご 相談 ください 。 AAA 保健 相談 所 :( 電話 番号 )(○ 時 ○ 分 から ○ 時 ○ 分 ) BB B 保健 相談 所 :( 電話 番号 )(○ 時 ○ 分 から ○ 時 ○ 分 )
#
# ( 子育て 支援 センター 等 ) の 年末年始 の 開館 日 を 教え て ください 。
# ( 子育て 支援 センター 等 ) は 12 月 29 日 から 1 月 3 日 まで 休 館 と なり ます 。 新年 は 1 月 4 日 から の 開館 と なり ます 。
#
# 市役所 は 年内 いつ まで やっ て ます か ?
# ○ ○ 市役所 は 12 月 28 日 まで 開 庁 し て い ます 。 新年 は 1 月 4 日 から の 開 庁 と なり ます 。
#
# どう し たら 早く ね て くれる の でしょ う か ?
# 赤ちゃん の 成長 や 性格 、 生活 環境 や 事情 によって 解決 策 が 違い ます 。 保健 師 に ご 相談 ください 。 お 話 を 伺 っ て 一緒 に 考え ましょ う 。 AAA 保健 相談 所 :( 電話 番号 )(○ 時 ○ 分 から ○ 時 ○ 分 ) BB B 保健 相談 所 :( 電話 番号 )(○ 時 ○ 分 から ○ 時 ○ 分 )
#
# 子ども が 遊 べ る 公園 を 教え て ください 。
# ○ ○ 公園 が ( 地域 名 ) × 丁 目 に あり ます 。 ( 公園 の 特徴 等 を 記載 し て ください 。 ) [UNK] ○ ○ 公園 ( 自治体 HP 内 関連 ページ の UR L )
#
# Q R コード を 教え て ください 。
# ○ ○ 市 LINE 公式 アカウント の Q R コード は こちら に なり ます 。 ( Q R コード を 表示 する UR L )
#
# 野 良 犬 について どこ に 相談 すれ ば いい です か ?
# 野 良 犬 の 相談 は こちら に ご 相談 ください 。 ( 自治体 ・ 保健 所 等 の HP 内 関連 ページ の UR L )
#
# い の し し について どこ に 相談 すれ ば いい です か ?
# い の し し の 相談 は こちら に ご 相談 ください 。 ( 自治体 ・ 保健 所 等 の HP 内 関連 ページ の UR L )
#
# 市民 向け の プール は あり ます か ?
# ○ ○ 市 の 温 水 プール について は こちら を ご [UNK] ください 。 ( 自治体 HP 内 関連 ページ の UR L )
#
# 子ども が 遊 べ る 公園 を 教え て ください 。
# ○ ○ 公園 に は ドッグ ラン が あり ます 。 ( 利用 方法 を 記載 し て ください 。 例 「 ご 利用 に は 公園 管理 センター で の 登録 が 必要 です 。 」 ) [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# ( ペット を 飼 う にあたって 役 に 立つ 情報 を まとめ た リーフ レット 等 ) について 教え て ください 。
# ( ペット を 飼 う にあたって 役 に 立つ 情報 を まとめ た リーフ レット 等 を 作成 し て いる 場合 は 、 記載 し て ください 。 ) 例 「 ペット 便利 帳 で は 飼い 主 が 守る 大事 な ルール や 市 の 協力 獣 医師 施設 の 紹介 を し て い ます 。 市役所 2 階 ○ ○ 課 、 市民 サービス センター で 配布 し て い ます 。 [UNK] こちら から ダウンロード も でき ます ( 自治体 HP 内 関連 ページ の UR L )」
#
# 妊 婦 の 食事 について 教え て ください 。
# 妊 婦 が 望ましい 食 生活 を 実践 する ため に 、 1 日 に 何 を どれ だけ 食べ たら よい か について 厚生 労働省 から 指針 が 公表 さ れ て い ます 。 詳しく は こちら を ご [UNK] ください 。 [UNK] 妊 産 婦 の ため の 食 生活 指針 ( 厚生 労働省 )【 PD F 】 http :// www . m h l w . go . jp / h oud ou / 2006 / 02 / d l / h 02 01 - 3 b 01 . p d f http :// www . m h l w . go . jp / h oud ou / 2006 / 02 / d l / h 02 01 - 3 b 02 . p d f
#
# 乳 腺 炎 に なっ たら どこ の 病院 に 行け ば いい です か ?
# 診療 について は 、 ( 都道府県 や 医師 会 が 提供 する 医療 機関 案内 等 ) にて 病院 を 探す こと が でき ます 。 [UNK] 詳しく は こちら ( 当該 医療 機関 案内 等 の UR L )
#
# ○ ○ 市 の 未来 像 について 教え て ください 。
# ( 目指し て いる 未来 像 や 掲げ て いる スローガン 等 について の 説明 を 記載 し て ください 。 ) [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# スズメ バチ の 巣 を 見つけ た の です が 、 対処 方法 を 教え て ください 。
# スズメ バチ の 巣 を 軒 下 や 樹 木 の 間 に 見つけ た 場合 は 、 保健 所 に 相談 し て ください 。 巣 に 触れ たり 、 刺激 を 与え なけれ ば 、 人 を 刺 す こと は あり ませ ん 。 刺激 せ ず 、 そ っと し て おき ましょ う 。 [UNK] お 問い合わせ ( 自治体 の 担当 課 等 の 名称 ) ( 電話 番号 )/( 開 庁 時間 )
#
# 近く の 病院 を 教え て ください 。
# ( 都道府県 や 医師 会 が 提供 する 医療 機関 案内 等 の 名称 ) で 、 県内 の 医療 機関 の 場所 や 診療 の 内容 など の 情報 を 提供 し て い ます 。 [UNK] 詳しく は こちら ( 当該 医療 機関 案内 等 の UR L )
#
# 放課後 クラブ の 利用 方法 について 教え て ください 。
# ( 利用 方法 を 記載 し て ください 。 ) 例 「 放課後 クラブ を 利用 する に は 毎年 度 、 事前 に 会員 登録 が 必要 です 。 登録 申請 は 、 随時 各 放課後 クラブ 室 で 受付 け て い ます 。 毎月 20 日 ( 3 月 を 除く ) まで に 登録 申請 を し て い た だ く と 、 翌月 から 利用 可能 と なり ます 。 また 、 必ず スポーツ 安全 保険 に 加入 し て い た だ き ます 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )」
#
# ( 犯罪 等 の 発生 お 知 ら せ サービス 等 ) について 教え て ください 。
# ( 犯罪 等 の 発生 お 知 ら せ サービス 等 の 説明 を 記載 し て ください 。 ) 例 「 「 ○ ○ 市 安全 ・ 安心 メール 」 は 、 市内 で 発生 し た 犯罪 や 安全 ・ 安心 に関する 情報 、 および 市内 外 の 災害 情報 や 各種 防災 情報 を 、 携帯 電話 、 スマート フォン または パソコン に メール で 配信 する サービス です 。 配信 を 希望 する 情報 、 受信 する 時間 を 任意 に 設定 する こと が でき ます 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )」
#
# ○ ○ 市 の 地図 は あり ます か ?
# ○ ○ 市 の 案内 図 について は こちら を ご [UNK] ください 。 ( 自治体 HP 内 関連 ページ の UR L )
#
# どんな 質問 が でき ます か ?
# ( 回答 可能 な 分野 ・ 範囲 を 記載 し て ください 。 ) 例 「 今 は 子育て 分野 が 中心 です が 、 話し か け て い た だ けれ ば 、 できるだけ お 答 え し たい と 思っ て い ます 。 今 は 答え ら え ない ご 質問 も 、 学習 し て 答え られる よう に なり ます ので 、 たくさん 話し か け て ください ね ♪」
#
# 保育園 は 何 時 から 預け られ ます か ?
# ( 預け られる 時間 を 記載 し て ください 。 ) 例 「 お 子 さん の 保育 時間 は 、 各 保育園 の 開園 時間 内 で 、 家庭 の 状況 等 を 考慮 し ながら 、 保護 者 と 相談 の 上 で 園 が 決定 し ます 。 支給 認定 証 の 保育 必要 量 ( 保育 標準 時間 ・ 保育 短時間 ) の 範囲 内 で 必要 最低限 の 時間 と なり ます 。 開園 時間 について は 保育園 によって 異なり ます ので 、 各 園 の 開園 時間 を ご 確認 ください 。 」
#
# 転入 し た 後 の 手続き について 教え て ください 。
# ○ ○ 市 に 転入 する とき に 必要 な 手続き や 届出 について は こちら を ご [UNK] ください 。 ( 自治体 HP 内 関連 ページ の UR L )
#
# インフルエンザ と お た ふく かぜ の 予防 接種 記録 票 が 送ら れ て き ませ ん 。
# インフルエンザ と お た ふく かぜ の 予防 接種 記録 票 は 、 ○ ○ 市 から は お 送り し ませ ん 。 希望 する 市内 指定 医療 機関 に 、 直接 ご 予約 ください 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# ( 観光 名所 等 ) について 教え て ください 。
# ( 観光 名所 等 の 説明 を 記載 し て ください 。 ) 例 「 渋谷 駅 ハチ 公 口 に は ハチ 公 の 銅像 が 飾ら れ て い ます 。 ハチ 公 は 大正 時代 、 飼い 主 が 亡くなっ た の を 知ら ず 、 毎日 渋谷 駅前 で 帰り を 待っ て い た そう です 。 」
#
# 自転車 に は 何 人 まで 子ども を 乗せ られ ます か ?
# 自転車 の 乗車 人員 は ( 都道府県 の 定める 道路 交通 規則 ) にて 制限 さ れ て い ます 。 ( 所在 する 都道府県 の 道路 交通 規則 の 内容 を 記載 し て ください 。 ) 東京 都 の 例 「 原則 二 人 乗り は 禁止 です が 、 運転 者 が 16 歳 以上 で あっ て 、 幼児 用 の 座席 を 取り付け た 自転車 に 6 歳 未満 の 幼児 を 乗せる 場合 や 、 運転 者 が 16 歳 以上 で あっ て 、 幼児 二 人 同 乗 用 自転車 として 認め られ た 自転車 に 6 歳 未満 の 幼児 を 1 〜 2 人 乗せる 場合 等 は 、 それぞれ 2 人 、 3 人 乗り が 許容 さ れ て い ます 。 」 )
#
# 子ども の 手当 に は どんな もの が あり ます か ?
# 子ども の 手当 について は こちら を ご [UNK] ください 。 ( 自治体 HP 内 関連 ページ の UR L )
#
# 転 園 届 の 提出 場所 を 教え て ください 。
# ( 転 園 届 の 提出 について 記載 し て ください 。 ) 例 「 保育園 の 転 園 届 は ○ ○ 課 へ 届出 の 手続き を し て ください 。 郵 送 や 保育園 等 で の 受付 は し て い ませ ん 。 」
#
# 水道 管 が 凍結 し たら どう すれ ば いい です か ?
# 水道 管 の 凍結 ・ 断 水 に ご 注意 ください 。 [UNK] 詳しく は ( 自治体 の 水道 局 等 ) ホームページ を ご [UNK] ください 。 ( 自治体 の 水道 局 等 の HP 内 関連 ページ の UR L 等 )
#
# 固定 資産 税 の 納税 証明 書 は どこ で 取れ ます か ?
# ○ ○ 市 で は 、 ( 申請 場所 ( 自治体 の 担当 課 、 支所 ・ 出張所 等 )) で 申請 でき ます 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# パスポート の 申請 窓口 を 教え て ください 。
# パスポート の 窓口 について は こちら を ご [UNK] ください 。 ( 自治体 HP 内 関連 ページ の UR L ) ( この ほか 、 都道府県 パスポート センター の UR L ・ 電話 番号 等 を 記載 する こと も 考え られ ます 。 )
#
# がん の 検 診 は あり ます か ?
# 各種 がん 一 次 検 診 を 実施 し て い ます 。 対象 者 は 、 無料 クー ポン 券 を 使っ て 、 市 の 指定 医療 機関 で 検 診 を 受け られ ます 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# 延長 保育 を やっ て いる ところ を 教え て ください 。
# ○ ○ 市 で 延長 保育 を 実施 し て いる 保育園 について は こちら を ご [UNK] ください 。 ( 自治体 HP 内 関連 ページ の UR L )
#
# 児童 手当 が もらえる 月 を 教え て ください
# 児童 手当 の 支払 月 は 、 2 月 ( 10 ~ 1 月 分 ) ・ 6 月 ( 2 ~ 5 月 分 ) ・ 10 月 ( 6 ~ 9 月 分 ) の 年 3 回 です 。 支払 月 の 前 の 月 まで の 4 か月 分 が まとめ て 保護 者 の 口座 に 支給 さ れ ます 。 また 、 毎回 ○ 日 (○ 日 が 休日 の 場合 の 取り扱い を 記載 し て ください 。 例 「 ○ 日 が 休日 の とき は その 前 営業 日 」 ) に 支払い の 手続き を し ます 。 手続き から ○~○ 日 後 に 振り 込ま れ ます 。 ご 確認 下さい 。 上記 内容 を ご 確認 の 上 、 尚 振り 込み が 確認 でき ない 場合 は お 手 数 です が 下記 担当 係 まで ご 連絡 ください 。 [UNK] お 問い合わせ ( 自治体 の 担当 課 等 の 名称 ) ( 電話 番号 )/( 開 庁 時間 )
#
# 児童 手当 が もらえる 月 を 教え て ください
# 児童 手当 は 、 認定 請求 を し た 月 の 翌月 分 から 支給 を 開始 し 、 原則 として 、 毎年 2 ・ 6 ・ 10 月 に それぞれ 前 月 分 まで が 支払わ れ ます 。
#
# マイ ナン バー カード の 申請 方法 を 教え て ください 。
# マイ ナン バー カード の 申請 方法 について は こちら を ご 確認 ください 。 ( 自治体 HP 内 関連 ページ の UR L ) 現在 、 ○ ○ 市 で は 申請 い た だ い て から 交付 通知 書 を 送付 する まで に 、 約 ○ ヵ月 程度 の 期間 を 要する 見込み です 。
#
# 転居 ( 市内 で 引っ越し ) する とき の 必要 な 手続き を 教え て ください 。
# 転居 ( 市内 で 引っ越し ) する とき に 必要 な 手続き や 届出 は こちら を ご 確認 ください 。 ( 自治体 HP 内 関連 ページ の UR L )
#
# 確定 申告 書 の 作成 会場 について 教え て ください 。
# 確定 申告 について は こちら を ご [UNK] ください 。 ( 自治体 HP 内 関連 ページ の UR L )
#
# 子育て は どこ に 相談 すれ ば いい です か ?
# ( 自治体 の 担当 課 や 子育て センター 等 ) で は 育児 全般 の 相談 を 実施 し て い ます 。 また 、 ( 自治体 の 担当 課 や 子育て センター 等 ) で は 子ども の 発達 や 育児 について 、 不安 や 悩み など の 相談 に 応じ て い ます 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# 生活 困窮 について どこ に 相談 すれ ば いい です か ?
# 病気 や け が など で 生活 に 困っ て いる 人 や 、 収入 が 少なく て 生活 に 困っ て いる 人 など 、 暮らし について 心配 ごと が ある 人 は ( 自治体 の 担当 課 等 ) に ご 相談 ください 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# 子ども の 発 育 に 不安 が ある の です が 、 どう すれ ば いい です か ?
# ( 子ども の 発達 について 相談 できる 場所 について 記載 し て ください 。 ) 例 「 子ども 発達 相談 センター で は 、 お 子 さん の 発達 や 育児 の 不安 、 悩み の 相談 に 応じ て い ます 。 まずは 気 軽 に 電話 で ご 相談 ください 。 [UNK] お 問い合わせ ( 自治体 の 担当 課 等 の 名称 ) ( 電話 番号 )/( 開 庁 時間 ) 詳しく は こちら を ご [UNK] ください 。 ( 自治体 HP 内 関連 ページ の UR L )
#
# 放課後 等 デイ サービス について 教え て ください 。
# 放課後 等 デイ サービス と は 、 学校 通学 中 の 児童 に 、 生活 能力 向上 の ため の 訓練 等 を 提供 し 自立 を 促進 する とともに 、 放課後 等 の 居場所 づくり を 推進 する 事業 です 。 ( 実施 場所 ・ 実施 団体 等 ) において 実施 さ れ て い ます 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# 学習 障害 の 相談 は どこ で でき ます か ?
# 子供 に かかわる 様々 な 悩み など について 電子 メール により 、 ○ ○ 市内 の 児童 ・ 生徒 または その 保護 者 を 対象 に 相談 を 受け付け て い ます 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# 1 歳 6 か月 児 健 診 について 教え て ください 。
# 1 歳 6 か月 児 健 診 は 母子 保健 法 に 定め られ た 子ども の 定期 健 診 の 一つ です 。 子ども の 発達 の 状況 を 確認 する とともに 、 歯 の 健 診 も 行い ます 。 対象 の 方 に は 1 歳 ○ か月 に 達する 月 の ( 上旬 / 中旬 / 下旬 ) に 通知 さ れ ます 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# 認可 外 保育 施設 について 教え て ください 。
# 認可 外 保育 施設 と は 認可 を 受け ず に 運営 する 保育 施設 の こと です 。 市 が 設置 し 、 民間 事業 者 に 運営 を 委託 し て いる 認可 外 保育 施設 に 市立 保育 室 が あり ます 。 市立 保育 室 は 市立 ・ 私立 保育園 に 申し込み を 行ない 、 待機 児童 と なっ た 人 のみ を 対象 と し て い ます 。 [UNK] 市立 保育 室 ( 自治体 HP 内 関連 ページ の UR L ) その他 の 認可 外 保育 施設 の 一覧 について は こちら を ご [UNK] ください 。 [UNK] 認可 外 保育 施設 一覧 表 ( 自治体 HP 内 関連 ページ の UR L )
#
# 登録 内容 の 修正 方法 を 教え て ください 。
# ( チャット ボット の 使用 にあたり アカウント に 情報 を 登録 する 場合 、 修正 方法 を 記載 し て ください 。 ) 例 「 本 アカウント に 登録 さ れ た お 住 い の 地域 や お 子 さま の 人数 等 、 登録 情報 を 変更 する 場合 は アンケート の 再 入力 が 必要 です 。 メニュー の 「 登録 内容 の 修正 」 を タップ し て 再度 アンケート に ご 回答 ください 。 」
#
# 子ども の 歯科 健 診 ( 1 歳 6 か月 健 診 ) について 教え て ください 。
# 1 歳 6 か月 を 迎える と 奥 歯 も そろ そ ろ 生え て き ます 。 歯 の トラブル 予防 に 重要 な この 時期 に 歯科 健 診 を し て 歯 医 者 さん の チェック を 行い ます 。 対象 の 方 に は 1 歳 ○ か月 に 達する 月 の ( 上旬 / 中旬 / 下旬 ) に 通知 さ れ ます 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# 精神 保健 相談 について 教え て ください 。
# 「 精神 保健 相談 」 と は 、 指定 の 日 に 、 専門 医 が 精神 障害 の 人 や その 家族 の 相談 に 応じる もの です 。 ( 事前 予約 の 有無 等 、 精神 保健 相談 の 説明 を 適 宜 記載 し て ください ) ひとり で 悩 ま ず 、 気 軽 に 相談 し て ください 。 [UNK] 相談 日 の 日程 等 、 詳しく は こちら を ご 確認 ください ( 自治体 HP 内 関連 ページ の UR L )
#
# 子ども の 身体 測定 は 行っ て い ます か ?
# ( 身体 測定 の 実施 施設 ) で は 指定 の 日 に 身体 測定 を 行っ て い ます 。 詳しく は ( 身体 測定 の 実施 施設 ) の 催し 物 一覧 を ご 確認 ください 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# 子ども の 不 登校 を 相談 できる ところ は あり ます か ?
# ( 自治体 の 担当 課 等 の 名称 ) で は 、 子ども に関する 様々 な 悩み や 問題 について 相談 に 応じ たり 、 学校 に 行け ない 児童 ・ 生徒 の 元気 回復 や 学習 の 支援 を 行っ て い ます 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# ○ 年 ○ 月 入 園 の 保育園 の 募集 人数 を 教え て ください 。
# ○ 年 ○ 月 入 園 の 各 園 の 募集 人数 は こちら を ご [UNK] ください 。 ( 自治体 HP 内 関連 ページ の UR L ) 空き 状況 について は こちら を ご 確認 ください 。 ( 自治体 HP 内 関連 ページ の UR L )
#
# ヒ ブ ワ クチン について 教え て ください 。
# ヒ ブ ワ クチン は 、 インフルエンザ 菌 b 型 ( Hi b ) による 感染 症 の 予防 ワクチン です 。 ヒ ブ は 、 髄 膜 炎 、 敗 血 症 、 肺炎 など 、 乳 幼 児 の 重 篤 な 感染 症 を 引き起こす 病原 最近 です 。 特に 、 細菌 性 髄 膜 炎 は 、 原因 の 半分 以上 が ヒ ブ と いわ れ て い ます 。 細菌 性 髄 膜 炎 は 初期 症状 が 風邪 に 似 て いる ため 早期 発見 が 難しく 、 治療 を し て も まれ に 死亡 し たり 、 後遺 症 が 残っ たり する こと が ある ので 、 ワクチン による 予防 が 非常 に 大切 です 。 予防 接種 は 生後 2 月 から 生後 60 月 に 至る まで の 間 に ある お 子 さん が 対象 と なり ます 。 ( 5 歳 の 誕生 日 の 前日 まで 接種 でき ます ) [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# 近隣 の 問題 について どこ に 相談 すれ ば いい です か ?
# 騒音 ・ 振動 ・ 悪 臭 など 生活 環境 に関する の 問題 は 近隣 の 方 どう し で の 解決 が 一番 です が 、 どうしても 我慢 の でき ない 場合 は こちら に 相談 し て ください 。 ( 自治体 HP 内 関連 ページ の UR L )
#
# ( 子育て 支援 施設 において 実施 する 支援 事業 等 ) の 場所 を 教え て ください 。
# ( 子育て 支援 施設 において 実施 する 支援 事業 等 ) は 、 ( 実施 場所 ) 等 で 実施 し て い ます 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# 小児 慢性 特定 疾病 の 医療 費 助成 制度 について 教え て ください 。
# 小児 慢性 特定 疾病 医療 費 助成 制度 と は 、 小児 慢性 特定 疾病 に かかっ て いる 児童 等 について 、 健全 育成 の 観点 から 、 患 児 家庭 の 医療 費 の 負担 軽減 を 図る ため 、 その 医療 費 の 自己 負担 分 の 一部 を 助成 する 制度 です 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# 近く の 小児 の 歯科 医 を 教え て ください 。
# ( 都道府県 や 医師 会 が 提供 する 医療 機関 案内 等 の 名称 ) で 探す こと が でき ます 。 [UNK] 詳しく は こちら ( 当該 医療 機関 案内 等 の UR L )
#
# 復 職 に関する 申 立 書 について 教え て ください 。
# ( 復 職 に関する 申 立 書 について 記載 し て ください 。 ) 例 「 保護 者 が 育児 休業 を 取得 し て いる 期間 は 、 お 子 さん を 保育園 で お 預かり する こと は でき ませ ん が 、 入 園 し た 月 ( 1 月 入 園 のみ 3 月 まで ) に 復 職 する こと を 条件 に 申し込み でき ます 。 その 際 、 就 労 証明 書 の 他 に 、 ○ ○ 市 指定 の 「 復 職 に関する 申 立 書 」 ( 保護 者 の 申 立て ) を 提出 し 、 入 園 後 に 「 復 職 証明 書 」 ( 勤務 先 の 証明 ) を 提出 する こと が 必要 です 。 復 職 に関する 申 立 書 は 以下 から ダウンロード が でき ます 。 ( 自治体 HP 内 関連 ページ の UR L )」
#
# たばこ の 問題 について 教え て ください 。
# ( たばこ の 問題 へ の 取り組み 等 の 説明 を 記載 し て ください 。 ) 例 「 ○ ○ 市 で は 、 「 歩行 喫煙 は し ない 」 「 たばこ は 決め られ た 場所 で 吸 う 」 という ルール を 平成 ○ 年 に 定め 、 喫煙 者 の モラ ル と マナー の 向上 を 図っ て い ます 。 「 歩行 喫煙 禁止 」 の 路面 表示 や 看板 、 [UNK] 旗 の 設置 、 美 化 活動 の 強化 など を通じて 、 歩き たばこ や ポ イ 捨て を し ない 環境 づくり を 推進 し 、 「 非 喫煙 者 、 喫煙 者 の 誰 も が 快適 に 過 ご せる 環境 整備 」 を 目指し て い ます 。 」
#
# ○ ○ 年度 の 住民 税 の 申告 について 教え て ください
# ○ ○ 年度 の 住民 税 の 申告 について は こちら を ご [UNK] ください 。 ( 自治体 HP 内 関連 ページ の UR L )
#
# ( 市民 体育 大会 等 ) について 教え て ください 。
# ( 市民 体育 大会 等 ) と は 、 ( 市民 体育 大会 等 の 説明 を 記載 し て ください )。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# 住民 票 の 受け取り の 予約 は でき ます か ?
# ( 電話 による 証明 書 予約 サービス が ある 場合 ) 本人 請求 の 住民 票 の 写し について は 、 窓口 が 開い て いる 時間 に 来 所 でき ない 人 も 、 電話 で の 申 込 で 休日 や 平日 の 時間 外 に 受け取る こと が でき ます 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# ( 保育 担当 課 ) の 場所 を 教え て ください 。
# ( 保育 担当 課 ) は ○ ○ 市役所 本庁 舎 の × 階 に あり ます 。 [UNK] 庁舎 案内 図 ( 自治体 HP 内 関連 ページ の UR L )
#
# 保育 の し おり が ほしい です 。
# ( 該当 する もの が あれ ば 記載 し て ください 。 ) 例 「 保育 の し おり と は 各 保育園 で 作成 し 、 入 園 時 等 に 配布 し て いる 園 の ルール 等 を 記載 し た もの です 。 通っ て いる 保育園 で 入手 でき ます ので 、 各 保育園 に お 問い合わせ ください 。 」
#
# 避難 所 は どこ です か ?
# ○ ○ 市 の 避難 所 施設 は 市立 小中学校 など ○ か 所 が 指定 さ れ て い ます 。 詳しく は こちら を ご [UNK] ください 。 [UNK] 避難 所 施設 一覧 ( 自治体 HP 内 関連 ページ の UR L )
#
# 一時 集合 場所 は どこ です か ?
# ※ ※ 一時 集合 所 を 採用 し て いる 自治体 ( 都 区 、 大阪 市 ) のみ ※ ※ ○ ○ 区 の 一時 ( いっ と き ) 集合 場所 は 区立 学校 の 校 庭 や 区立 公園 など が あて られ て い ます 。 ここ で 災害 の 状況 を 見 極 め ます 。 また 、 避難 場所 へ 避難 する ため に 集合 し ます 。 避難 場所 に 近い とき は 、 直接 避難 場所 へ 集合 し ます 。 詳しく は こちら を ご [UNK] ください 。 [UNK] 一時 ( いっ と き ) 集合 場所 一覧 ( 自治体 HP 内 関連 ページ の UR L )
#
# 避難 場所 は どこ です か ?
# ○ ○ 市 の 避難 場所 は ○ ○ 公園 など ○ か 所 が あて られ て い ます 。 詳しく は こちら を ご [UNK] ください 。 [UNK] 避難 場所 一覧 ( 自治体 HP 内 関連 ページ の UR L )
#
# ○ ○ 市 の 地図 は あり ます か ?
# ○ ○ 市 の 案内 図 について は こちら を ご [UNK] ください 。 ( 自治体 HP 内 関連 ページ の UR L )
#
# ○ ○ 市 の 施設 で ベビー スケール の ある ( 赤ちゃん の 体重 が 測 れる ) ところ は どこ が あり ます か ?
# ベビー スケール の 利用 が 常時 行える ところ は 、 ○ ○ です 。 体重 の 増え 方 に ご 心配 が ある 場合 は 、 保健 師 に ご 相談 ください 。 AAA 保健 相談 所 :( 電話 番号 )(○ 時 ○ 分 から ○ 時 ○ 分 ) BB B 保健 相談 所 :( 電話 番号 )(○ 時 ○ 分 から ○ 時 ○ 分 )
#
# 住民 税 の 納税 証明 書 を 取り たい 。
# 住民 税 の 納税 証明 書 は 、 ( 申請 場所 ( 自治体 の 担当 課 、 支所 ・ 出張所 等 )) で 発行 し て い ます 。 申請 方法 等 、 詳しく は こちら を ご [UNK] ください 。 ( 自治体 HP 内 関連 ページ の UR L )
# 軽自動車 税 の 納税 証明 書 を 取り たい 。
# 軽自動車 税 の 納税 証明 書 は 、 ( 申請 場所 ( 自治体 の 担当 課 、 支所 ・ 出張所 等 )) で 発行 し て い ます 。 申請 方法 等 、 詳しく は こちら を ご [UNK] ください 。 ( 自治体 HP 内 関連 ページ の UR L )
#
# 戸籍 [UNK] の 請求 方法 を 教え て ください 。
# ○ ○ 市 に 本 籍 が ある 人 は 、 窓口 で 交付 を 受ける こと が でき ます 。 必要 な もの 等 、 詳しく は こちら を ご [UNK] ください 。 ( 自治体 HP 内 関連 ページ の UR L )

# %%
for pair in qa_posterior_pair:
    print(pair[0])
    print(pair[1], '\n')
# Out:
# 母子 手帳 の 受け取り 場所 は どこ です か ?
# 母子 手帳 は 、 ○ ○ 市役所 本庁 舎 △ △ 階 × × 課 窓口 、 [UNK] [UNK] 出張所 、 .........( その他 の 受け取り 場所 を 適 宜 記載 )......... で 受け 取 れ ます 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# 母子 手帳 は すぐ に 発行 し て もらえ ます か ?
# 母子 手帳 は 、 妊娠 届 の 内容 を 確認 さ せ て い た だ き 、 その 場 で お 渡し し ます 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# ● ● 県内 で 引っ越し たら 、 妊 婦 健 診 の 受 診 票 は ?
# 妊 婦 健 診 の 受 診 票 は 、 受 診 票 を 受け取っ た 日 より 後 で 、 病院 が 妊 婦 健 診 と 規定 し た 日 に 利用 でき ます 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# 妊 婦 健 診 受 診 票 は ○ ○ 市外 で 使え ます か ?
# 妊 婦 健 診 の 受 診 票 は 、 ● ● 県内 の 契約 医療 機関 で お 使い い た だ け ます 。 受 診 希望 の 病院 に お 問い合わせ ください 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# 妊 婦 健 診 受 診 票 の 余り を 換 金 し て もらえ ます か ?
# 妊 婦 健 診 に対する 助成 制度 で あり 、 金 券 で は あり ませ ん 。 その ため 換 金 等 は でき ませ ん 。
#
# 妊 婦 健 診 受 診 票 受 取 前 に 病院 に かかっ た 分 は 、 還 付 さ れ ます か ?
# 妊 婦 健 診 受 診 票 を お 渡し し て から の 助成 に なり ます 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# 妊 婦 健 診 が 14 回 以上 かかり まし た が 、 追加 で 助成 し て もらえ ます か ?
# 妊 婦 健 診 費用 の 助成 は 14 回 まで に なり ます 。 それ 以降 は 自費 で の 対応 を お願い し ます 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# 妊 婦 健 診 受 診 票 受 取 前 に 病院 に かかっ た 分 は 、 還 付 さ れ ます か ?
# 妊 婦 健 診 に対する 助成 制度 で あり 、 金 券 で は あり ませ ん 。 その ため 換 金 等 は でき ませ ん 。 < 病院 > < た 分 > < 受 取 > < 還 付 > 妊 婦 健 診 受 診 票 を お 渡し し て から の 助成 に なり ます 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# ● ● 県 外 へ 引っ越し たら 、 妊 婦 健 診 の 受 診 票 は ?
# 受 診 票 は ご 利用 い た だ け なく なり ます 。 引っ越し 先 の 自治体 に お 問い合わせ ください 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# ● ● 県内 で 引っ越し たら 、 子ども の 受 診 票 は ?
# 1 歳 6 か月 健 診 の 受 診 券 は 、 ○ ○ 市内 のみ で の ご 利用 に なり ます 。 それ 以外 の 受 診 票 は 、 ● ● 県内 共通 に なり ます ので 、 そのまま お 使い い た だ け ます 。 各 自治体 独自 の サービス が 受け られる 場合 が ある ので 、 引っ越し 先 の 自治体 に お 問い合わせ ください 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# ● ● 県 外 へ 引っ越し たら 、 妊 婦 健 診 の 受 診 票 は ?
# 受 診 票 は ご 利用 い た だ け なく なり ます 。 引っ越し 先 の 自治体 に お 問い合わせ ください 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# ● ● 県内 で 引っ越し たら 、 妊 婦 健 診 の 受 診 票 は ?
# 妊 婦 健 診 の 受 診 票 は 、 受 診 票 を 受け取っ た 日 より 後 で 、 病院 が 妊 婦 健 診 と 規定 し た 日 に 利用 でき ます 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# 里 帰り 出産 の 際 、 受 診 票 は 使え ます か ?
# ● ● 県 以外 で は 受 診 票 の 利用 は でき ませ ん 。 ご 出産 後 「 里 帰り 等 の 妊 婦 健 診 費用 の 助成 」 として 、 受 診 1 回 あたり の 限度 額 範囲 で 、 母子 手帳 、 領 収 書 、 未 使用 受 診 票 の 枚数 に 応じ て 、 助成 金 を 支給 し ます 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# 子ども が 生まれ たら 、 どんな 手続き が 必要 です か 。
# 出産 後 に 必要 な 手続き は 出生 届 ・ 出生 通知 票 の 提出 、 児童 手当 、 子ども 医療 費 助成 の 申請 等 が あり ます 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# ( 乳 房 ケア に対する 助成 ) について 教え て ください 。
# ( 乳 房 ケア に対する 助成 を 行っ て いる 場合 は 、 申し込み 方法 等 を 記載 し て ください 。 ) 例 「 こん に ち は 赤ちゃん 訪問 の 際 に お 渡し し た ケア 券 に 記載 の 宛 先 ( 助 産 師 会 ) に お 申し込み ください 。 乳 房 ケア 券 が まだ お 手元 に 届い て い ない 場合 は 、 母子 保健 ・ 産 前 産 後 ケア センター へ お 問い合わせ ください 。 [UNK] お 問い合わせ ( 自治体 の 担当 課 等 の 名称 ) ( 電話 番号 )/( 開 庁 時間 )
#
# 赤ちゃん 訪問 の 案内 が き まし た が 、 日時 を 変更 でき ます か ?
# 赤ちゃん 訪問 の 日時 の 変更 は 可能 です 。 変更 に関して は 、 ( 自治体 の 担当 課 や 子育て センター 等 の 名称 ) へ お 問い合わせ ください 。 [UNK] お 問い合わせ ( 自治体 の 担当 課 や 子育て センター 等 の 名称 ) ( 電話 番号 )/( 開 庁 時間 )
#
# 1 か月 健 診 の 助成 は あり ます か ?
# 1 か月 健 診 の 助成 は 実施 し て い ませ ん 。 ○ ○ 市 で は 、 3 ・ 4 か月 健 診 、 1 歳 6 か月 歯科 健 診 、 3 歳 児 健 診 を 、 無料 で 行っ て い ます 。 また 、 6 ・ 7 か月 健 診 、 9 ・ 10 か月 健 診 、 1 歳 6 か月 内科 健 診 について は 、 受 診 票 を 郵 送 し て い ます 。 ● ● 県内 ( 1 歳 6 か月 健 診 は ○ ○ 市内 のみ ) の 契約 医療 機関 に 受 診 票 を お 持ち ください 。 契約 医療 機関 について は こちら を ご [UNK] ください 。 ( 自治体 HP 内 関連 ページ の UR L )
#
# 子ども の 健 診 の 案内 が 来 まし た が 、 指定 さ れ た 日 に 行け ませ ん 。
# 子ども の 健 診 の 指定 日 について 、 ご 都合 が 悪い 場合 は 、 受 診 可能 な 日程 を ご 案内 し ます 。 ( 自治体 の 担当 課 や 子育て センター 等 の 名称 ) へ お 問い合わせ ください 。 [UNK] お 問い合わせ ( 自治体 の 担当 課 や 子育て センター 等 の 名称 ) ( 電話 番号 )/( 開 庁 時間 )
#
# 子ども の 健 診 の 時間 は 、 どの くらい かかり ます か ?
# 健 診 の 時間 は 通常 1 時間 程度 です 。 混 み 具合 や お 子 さん の 健康 状態 により 、 2 時間 から 3 時間 かかる こと も あり ます 。
#
# 乳児 ・ 1 歳 6 か月 歯科 ・ 3 歳 児 健 診 は 、 指定 の 保健 所 ( 保健 相談 所 ) 以外 の 保健 所 ( 保健 相談 所 ) で 受 診 でき ます か ?
# 乳児 ・ 1 歳 6 か月 歯科 ・ 3 歳 児 健 診 は 、 指定 の 保健 所 もしくは 保健 相談 所 を ご 利用 ください 。 日程 が 合 わ ない 等 、 ご 事情 が ござい まし たら 、 指定 の 保健 所 もしくは 保健 相談 所 へ お 電話 ください 。 [UNK] 連絡 先 AAA 保健 相談 所 :( 電話 番号 )/( 開 庁 時間 ) BB B 保健 相談 所 :( 電話 番号 )/( 開 庁 時間 ) CC C 保健 相談 所 :( 電話 番号 )/( 開 庁 時間 )
#
# 9 ・ 10 か月 健 診 の 券 を 失 くし て しまい まし た 。
# 受 診 票 を 再 発行 し ます 。 ( 自治体 の 担当 課 や 子育て センター 等 の 名称 ) へ お 問い合わせ ください 。 [UNK] お 問い合わせ ( 自治体 の 担当 課 や 子育て センター 等 の 名称 ) ( 電話 番号 )/( 開 庁 時間 )
#
# 6 ・ 7 か月 健 診 の 期間 内 に 受 診 でき ませ ん 。
# 健 診 の 期間 を 過ぎる と 助成 を 受ける こと が でき ませ ん 。 受 診 票 は 6 ・ 7 か月 健 診 は お 子 さん が 8 か月 に なる 前日 まで お 使い い た だ け ます 。
#
# 9 ・ 10 か月 健 診 の 期間 内 に 受 診 でき ませ ん 。
# 健 診 の 期間 を 過ぎる と 助成 を 受ける こと が でき ませ ん 。 受 診 票 は 9 ・ 10 か月 健 診 は お 子 さん が 11 か月 に なる 前日 まで お 使い い た だ け ます 。
#
# ○ ○ 市外 で も 6 ・ 7 か月 健 診 の 受 診 票 は 使え ます か ?
# 受 診 票 は ○ ○ 市外 でも ● ● 県内 の 契約 医療 機関 で あれ ば お 使い い た だ け ます 。 受 診 希望 の 病院 に お 問い合わせ ください 。 契約 医療 機関 について は こちら を ご [UNK] ください 。 ( 自治体 HP 内 関連 ページ の UR L )
#
# ○ ○ 市外 で も 6 ・ 7 か月 健 診 の 受 診 票 は 使え ます か ?
# 受 診 票 は ○ ○ 市外 でも ● ● 県内 の 契約 医療 機関 で あれ ば お 使い い た だ け ます 。 受 診 希望 の 病院 に お 問い合わせ ください 。 契約 医療 機関 について は こちら を ご [UNK] ください 。 ( 自治体 HP 内 関連 ページ の UR L )
#
# ○ ○ 市外 で も 1 歳 6 か月 健 診 の 受 診 票 は 使え ます か ?
# 1 歳 6 か月 健 診 の 受 診 票 は ○ ○ 市外 で は ご 利用 でき ませ ん 。 ○ ○ 市内 の 契約 医療 機関 のみ の ご 利用 に なり ます 。 受 診 場所 について は こちら を ご [UNK] ください 。 ( 自治体 HP 内 関連 ページ の UR L )
#
# 1 歳 児 健 診 は 、 保健 所 で やっ て い ます か ?
# 1 歳 児 健 診 は 保健 所 で は 実施 し て い ませ ん 。 ○ ○ 市 で は 、 3 ・ 4 か月 健 診 、 1 歳 6 か月 歯科 健 診 、 3 歳 児 健 診 を 無料 で 行っ て い ます 。 また 、 6 ・ 7 か月 健 診 、 9 ・ 10 か月 健 診 、 1 歳 6 か月 健 診 について は 、 受 診 票 を 郵 送 し て い ます 。 ● ● 県内 ( 1 歳 6 か月 健 診 は ○ ○ 市内 のみ ) の 契約 医療 機関 に 受 診 票 を お 持ち ください 。 契約 医療 機関 について は こちら を ご [UNK] ください 。 ( 自治体 HP 内 関連 ページ の UR L )
#
# 3 歳 児 健 診 で 尿 が 取れ ませ ん 。
# 3 歳 児 健 診 で 尿 が 取れ ない 場合 でも 、 健 診 後 、 4 歳 に なる 前日 まで に 健 診 受付 時間 内 に 、 尿 を お 持ち い た だ けれ ば 追加 で 検査 でき ます 。 お 子 さん の 成長 に 合わせ て お 持ち ください 。 また 、 健 診 の 朝 の 尿 が 難しい 場合 は 、 健 診 会場 で お 取り い た だ く こと も でき ます 。
#
# 予防 接種 記録 票 の 再 発行 は でき ます か ?
# 予防 接種 記録 票 は 、 対象 の 年齢 で あれ ば 、 再 発行 が 可能 です 。 予防 接種 の 種類 によって 様々 です ので 、 母子 手帳 を ご 用意 の 上 、 お 電話 または 窓口 で お 問い合わせ ください 。 [UNK] お 問い合わせ ( 自治体 の 担当 課 や 子育て センター 等 の 名称 ) ( 電話 番号 )/( 開 庁 時間 )
#
# 里 帰り 先 で 予防 接種 を 受け たい 。
# ● ● 県内 の 指定 医療 機関 で あれ ば 引き続き 、 お 手持ち の 予防 接種 記録 票 ( 予 診 票 ) が 使用 でき ます 。 ● ● 県 外 で の 接種 を 希望 する 場合 は 別途 申請 が 必要 と なり ます 。 [UNK] お 問い合わせ ( 自治体 の 担当 課 や 子育て センター 等 の 名称 ) ( 電話 番号 )/( 開 庁 時間 )
#
# 予防 接種 を 打つ べき 時期 ( 法定 接種 期間 ) を 過ぎ て しまい まし た 。
# 法定 接種 期間 が 過ぎ て しまっ た 場合 は 、 原則 、 自己 負担 ( 自費 ) に なり ます 。 ただし 、 一部 例外 も あり ます ので 、 お 問い合わせ ください 。 [UNK] お 問い合わせ ( 自治体 の 担当 課 や 子育て センター 等 の 名称 ) ( 電話 番号 )/( 開 庁 時間 )
#
# インフルエンザ と お た ふく かぜ の 予防 接種 記録 票 が 送ら れ て き ませ ん 。
# インフルエンザ と お た ふく かぜ の 予防 接種 記録 票 は 、 ○ ○ 市 から は お 送り し ませ ん 。 希望 する 市内 指定 医療 機関 に 、 直接 ご 予約 ください 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# 産 前 ・ 産 後 の こと について 教え て ください 。
# ○ ○ 市 の 産 前 産 後 の サービス は 、 ( 東京 都 における 「 母子 保健 バッグ 」 等 、 自治体 が 妊 婦 等 に対して 交付 し て いる もの ) を ご [UNK] ください 。 出産 休暇 について は お 勤め 先 に お 問い合わせ ください 。 出産 一 時 金 について は 、 加入 し て いる 健康 保険 組合 等 に お 問い合わせ ください 。
#
# 母子 手帳 の 他 に 産 前 に 市役所 で やる べき 手続き は あり ます か ?
# 産 前 は 母子 手帳 以外 の 手続き は 特に あり ませ ん 。 産 後 に 、 出生 の 届出 や 出生 通知 書 の 提出 、 ( 自治体 が 行う 出産 助成 等 ) の 申請 を お願い し ます 。
#
# 母子 手帳 の 申請 に は 医師 の 診断 書 が 必要 です か ?
# 母子 手帳 の 申請 に は 診断 書 は いり ませ ん が 、 妊娠 届 に 診断 を 受け た 病院 名 ・ 医師 名 を 記入 し て い た だ き ます 。
#
# 子ども が 受 診 票 を 使っ て 妊 婦 健 診 を 受け まし た が 、 もう 上 乗 せ で 毎回 2000 円 支払っ て い まし た 。 その 分 について は 助成 は ない の です か ?
# 病院 によって は 、 受 診 票 の 妊 婦 健 診 に 独自 の 検査 等 を 組み合わせ て いる 場合 が あり ます 。 病院 独自 の 上 乗 せ 部分 について は 、 助成 は あり ませ ん 。
#
# 子ども が 1 歳 6 か月 健 診 を 受け ず に 2 歳 に なり まし た が 、 もう 歯科 の 健 診 は ない の です か ?
# 次 は 3 歳 児 健 診 に なり ます が 、 それ まで に 歯 について 気 に なる こと が あれ ば 、 歯科 専門 相談 を ご 利用 ください 。
#
# 療 育 医療 は どんな 時 に 申請 できる の です か ?
# 18 歳 未満 の 方 で 、 結核 の 治療 の ため 医師 が 指定 医療 機関 に 長期 入院 が 必要 と 認め た 場合 に 、 入院 医療 費 の 助成 と 日 用品 ・ 学 用 品 の 給付 申請 が でき ます 。
#
# 療 育 医療 の 申請 に 必要 な もの は 何 です か ?
# 療 育 医療 の 申請 に は 、 1 療 育 医療 申請 書 、 2 療 育 給付 意見 書 、 3 自己 負担 金 措置 申請 書 、 4 世帯 調 書 、 5 お 子 さん の 健康 保険 証 、 6 乳 幼 児 ( 子ども ) 医療 証 、 7 マイ ナンバー の 記載 に 必要 な 書類 、 8 所得 税 額 証明 書 ( 収入 の ある 方 全員 ) など を 提出 し て ください 。 申請 者 以外 の 方 が 代理 で 申請 する 場合 は 、 委任 状 と 代理人 の 方 の 身元 確認 書類 が 必要 です 。
#
# 療 育 医療 の 申請 手続 は いつ まで に すれ ば いい です か ?
# 療 育 医療 の 申請 手続 は 、 感染 症 法 の 医療 費 助成 申請 と 同時に 行い ます 。 また 、 医療 機関 が 作成 し た 療 育 医療 意見 書 の 発行 日 から 3 か月 以内 に 申請 し て ください 。 入院 初日 から 3 か月 を 超 え て いる 場合 は 、 遅延 理由 書 が 必要 です 。
#
# 療 育 医療 の 申請 は 誰 が すれ ば いい の です か ?
# 療 育 医療 の 申請 者 は お 子 さん の 健康 保険 の 被 保険 者 です 。 例 ) 父 ( 母 ) の 加入 し て いる 健康 保険 の 被 扶養 者 [UNK] 父 ( 母 ) が 申請 者
#
# 療 育 医療 の 申請 場所 を 教え て ください 。
# 療 育 医療 の 申請 窓口 は 、 ( 自治体 の 担当 課 等 の 名称 ) です 。 < 育成 > 育成 医療 の 申請 窓口 は 、 ( 自治体 の 担当 課 等 の 名称 ) です 。
#
# 育成 医療 の 申請 は 市役所 に いか なけれ ば いけ ない の です か ?
# 育成 医療 の 申請 は 郵 送 ( 簡易 書 留 ) で も でき ます 。
#
# 育成 医療 は どんな 時 に 申請 できる の です か ?
# 身体 に 機能 障害 が ある 18 歳 未満 の 方 で 、 主 に 「 手術 を 伴う 入院 治療 」 など により 機能 回復 が 見込ま れる 場合 に 、 医療 費 の 支給 認定 申請 が でき ます 。 指定 自立 医療 機関 ・ 薬局 で の 保険 内 診療 分 が 対象 です 。
#
# 育成 医療 の 申請 手続 を 教え て ください 。
# 育成 医療 の 申請 は 保護 者 の 住所 地 の 保健 所 に 申請 し ます 。 1 自立 支援 医療 ( 育成 医療 ) 支給 認定 申請 書 、 2 自立 支援 医療 ( 育成 医療 ) 意見 書 、 3 世帯 調 書 、 4 健康 保険 証 、 5 住民 税 額 課税 証明 書 、 6 乳 幼 児 ( 子ども ) 医療 証 、 7 マイ ナンバー の 記載 に 必要 な 書類 、 8 人工 透 [UNK] を 受け て いる 場合 は 、 特定 疾病 療養 受領 証 、 9 免疫 機能 障害 の 方 は 、 免疫 機能 障害 意見 書 など を 提出 し て ください 。 申請 者 以外 の 方 が 代理 で 申請 する 場合 は 、 委任 状 と 代理人 の 方 の 身元 確認 書類 が 必要 です 。 詳しく は お 問い合わせ ください 。 [UNK] お 問い合わせ ( 自治体 の 担当 課 等 の 名称 ) ( 電話 番号 )/( 開 庁 時間 )
#
# 育成 医療 の 申請 に 必要 な もの は 何 です か ?
# 育成 医療 の 申請 に は 、 1 自立 支援 医療 ( 育成 医療 ) 支給 認定 申請 書 、 2 自立 支援 医療 ( 育成 医療 ) 意見 書 、 3 世帯 調 書 、 4 健康 保険 証 、 5 住民 税 額 課税 証明 書 、 6 乳 幼 児 ( 子ども ) 医療 証 、 7 マイ ナンバー の 記載 に 必要 な 書類 、 8 人工 透 [UNK] を 受け て いる 場合 は 、 特定 疾病 療養 受領 証 、 9 免疫 機能 障害 の 方 は 、 免疫 機能 障害 意見 書 など を 提出 し て ください 。 申請 者 以外 の 方 が 代理 で 申請 する 場合 は 、 委任 状 と 代理人 の 方 の 身元 確認 書類 が 必要 です 。 詳しく は お 問い合わせ ください 。 [UNK] お 問い合わせ ( 自治体 の 担当 課 等 の 名称 ) ( 電話 番号 )/( 開 庁 時間 )
#
# 育成 医療 の 申請 手続 は いつ まで に すれ ば いい です か ?
# 育成 医療 の 申請 は 事前 申請 が 原則 です 。 入院 ・ 手術 ・ 通 院 の 予定 が 決まっ たら 、 できるだけ 早く 申請 し て ください 。 治療 が 終了 し て いる 場合 、 指定 自立 医療 機関 が さかのぼ っ て 育成 医療 の 取扱い を 認め ない 場合 は 申請 でき ませ ん 。 また 、 申請 時 に 満 18 歳 に 達し て いる 場合 や 手術 日 が 満 18 歳 に 達し た 日 以降 の 場合 は 対象 外 です 。
#
# 育成 医療 の 申請 場所 を 教え て ください 。
# 育成 医療 の 申請 窓口 は 、 ( 自治体 の 担当 課 等 の 名称 ) です 。
#
# 療 育 医療 の 申請 は 市役所 に 直接 申請 に いか なけれ ば いけ ない の です か ?
# 療 育 医療 の 申請 は 郵 送 ( 簡易 書 留 ) で も でき ます 。
#
# 養育 医療 の 申請 手続 は いつ まで に すれ ば いい です か ?
# ○ ○ 市 に 居住 する 母子 保健 法 第 6 条 第 6 項 に 規定 する 未 熟 児 (※) で 、 医師 が 指定 医療 機関 で の 入院 養育 の 必要 を 認め た 場合 に 、 保険 内 診療 分 の 医療 費 等 の 給付 申請 が でき ます 。 (※) 次 の 両方 もしくは いずれ か に 該当 する もの 。 1 . 出生 時 の 体重 が 2 , 000 g 以下 2 . 体重 に 関係 なく 、 「 生活 力 が 特に 薄 弱 で あっ て 」 、 身体 に 定め られ た 症状 を 呈し て いる 。
#
# 養育 医療 の 申請 手続 を 教え て ください 。
# 養育 医療 の 申請 は 、 お 子 さん の 住所 地 の 保健 所 に 申請 し ます 。 1 養育 医療 給付 申請 書 、 2 養育 医療 意見 書 、 3 世帯 調 書 、 4 健康 保険 証 ( または 資格 証明 書 )、 5 所得 税 額 証明 書 、 6 乳 幼 児 医療 証 、 7 マイ ナンバー の 記載 に 必要 な 書類 など を 提出 し て ください 。 申請 者 以外 の 方 が 代理 で 申請 する 場合 は 、 委任 状 と 代理人 の 方 の 身元 確認 書類 が 必要 です 。 詳しく は お 問い合わせ ください 。 [UNK] お 問い合わせ ( 自治体 の 担当 課 等 の 名称 ) ( 電話 番号 )/( 開 庁 時間 )
#
# 養育 医療 の 申請 に 必要 な もの は 何 です か ?
# 養育 医療 の 申請 に は 、 1 養育 医療 給付 申請 書 、 2 養育 医療 意見 書 、 3 世帯 調 書 、 4 健康 保険 証 ( または 資格 証明 書 )、 5 所得 税 額 証明 書 、 6 乳 幼 児 医療 証 、 7 マイ ナンバー の 記載 に 必要 な 書類 など の 提出 が 必要 です 。 申請 者 以外 の 方 が 代理 で 申請 する 場合 は 、 委任 状 と 代理人 の 方 の 身元 確認 書類 が 必要 です 。 詳しく は お 問い合わせ ください 。 [UNK] お 問い合わせ ( 自治体 の 担当 課 等 の 名称 ) ( 電話 番号 )/( 開 庁 時間 )
#
# 養育 医療 の 申請 手続 は いつ まで に すれ ば いい です か ?
# 養育 医療 の 申請 は 退院 ( 清算 ) 後 の 申請 が でき ませ ん 。 入院 中 に できる だけ 早く 申請 し て ください 。 既に 退院 し て いる 場合 は 、 指定 自立 医療 機関 が さかのぼ っ て 養育 医療 の 取扱い を 認め た 場合 に 限り 申請 でき ます 。
#
# 養育 医療 の 申請 手続 は いつ まで に すれ ば いい です か ?
# 養育 医療 の 申請 は 、 保護 者 が 、 お 子 さん の 住所 地 の 保健 所 に 申請 し ます 。
#
# 養育 医療 の 申請 場所 を 教え て ください 。
# 養育 医療 の 申請 窓口 は 、 ( 自治体 の 担当 課 等 の 名称 ) です 。
#
# 養育 医療 の 申請 は 市役所 に 直接 いか なけれ ば いけ ない の です か ?
# 養育 医療 の 申請 は 郵 送 ( 簡易 書 留 ) で も でき ます 。
#
# 小児 慢性 特定 疾病 の 申請 手続 を 教え て ください 。
# 小児 慢性 特定 疾病 の 申請 は 、 保護 者 の 住所 地 の 保健 所 に 申請 し ます 。 1 小児 慢性 特定 疾病 医療 費 支給 認定 申請 書 兼 同意 書 、 2 小児 慢性 特定 疾病 医療 意見 書 、 3 受 診 医療 機関 申請 書 、 4 世帯 調 書 、 [UNK] 住民 票 、 6 お 子 さん の 健康 保険 証 、 [UNK] 乳 幼 児 ( 子ども ) 医療 証 、 [UNK] マイ ナンバー の 記載 に 必要 な 書類 、 [UNK] 住民 税 課税 ( 非 ) 証明 書 、 10 保険 者 から の 情報 提供 に かかる 同意 書 など を 提出 し て ください 。 申請 者 以外 の 方 が 代理 で 申請 する 場合 は 、 委任 状 と 代理人 の 方 の 身元 確認 書類 が 必要 です 。 詳しく は お 問い合わせ ください 。 [UNK] お 問い合わせ ( 自治体 の 担当 課 等 の 名称 ) ( 電話 番号 )/( 開 庁 時間 )
#
# 小児 慢性 特定 疾病 の 申請 に 必要 な もの は 何 です か ?
# 小児 慢性 特定 疾病 の 申請 に は 、 1 小児 慢性 特定 疾病 医療 費 支給 認定 申請 書 兼 同意 書 、 2 小児 慢性 特定 疾病 医療 意見 書 、 3 受 診 医療 機関 申請 書 、 4 世帯 調 書 、 [UNK] 住民 票 、 6 お 子 さん の 健康 保険 証 、 [UNK] 乳 幼 児 ( 子ども ) 医療 証 、 [UNK] マイ ナンバー の 記載 に 必要 な 書類 、 [UNK] 住民 税 課税 ( 非 ) 証明 書 、 10 保険 者 から の 情報 提供 に かかる 同意 書 など を 提出 し て ください 。 申請 者 以外 の 方 が 代理 で 申請 する 場合 は 、 委任 状 と 代理人 の 方 の 身元 確認 書類 が 必要 です 。 詳しく は お 問い合わせ ください 。 [UNK] お 問い合わせ ( 自治体 の 担当 課 等 の 名称 ) ( 電話 番号 )/( 開 庁 時間 )
#
# 小児 慢性 特定 疾病 の 申請 手続 は いつ まで に すれ ば いい です か ?
# 小児 慢性 特定 疾病 の 申請 は 、 お 子 さん が 18 歳 に なる 前 まで に 申請 し て ください 。
#
# 小児 慢性 特定 疾病 の 申請 手続 は いつ まで に すれ ば いい です か ?
# 小児 慢性 特定 疾病 の 申請 者 と なる 方 は 、 お 子 さん の 健康 保険 の 被 保険 者 です 。 例 ) 父 ( 母 ) の 加入 し て いる 健康 保険 の 被 扶養 者 [UNK] 父 ( 母 ) が 申請 者
#
# 小児 慢性 特定 疾病 の 申請 手続 を 教え て ください 。
# 小児 慢性 特定 疾病 の 申請 窓口 は 、 ( 自治体 の 担当 課 等 の 名称 ) です 。
#
# 小児 慢性 特定 疾病 は 市役所 に 直接 申請 に いか なけれ ば いけ ない の です か ?
# 小児 慢性 特定 疾病 の 申請 は 郵 送 ( 簡易 書 留 ) で も でき ます 。
#
# 児童 手当 の 申請 に 必要 な もの を 教え て ください 。
# 児童 手当 の 申請 に 必要 な もの は 下記 の とおり です 。 1 請求 者 名義 の 金融 機関 の 口座 番号 が わかる もの 2 請求 者 と 配偶 者 の 「 住民 税 課税 ( 非 課 税 ) 証明 書 」 3 印 鑑 ( 朱 肉 を 使う もの ) 4 請求 者 が 厚生 年金 加入 者 ( 被 用 者 ) の 場合 は 、 「 厚生 年金 加入 証明 書 」 (「 健康 保険 証 の コピー 」 で 代え る こと も でき ます 。 ) * 状況 によって は その他 の 書類 が 必要 に なる 場合 が あり ます 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# 児童 手当 の 申請 方法 を 教え て ください 。
# 児童 手当 を 受ける に は 、 認定 請求 が 必要 です 。 まず 、 ○ ○ 市 の ホームページ より 「 児童 手当 ・ 特例 給付 認定 請求 書 」 を ダウンロード し て ご 記入 ください 。 必要 書類 を 添付 し 、 ( 自治体 の 担当 課 等 の 名称 ) へ 郵 送 又は ご 持参 ください 。 【 提出 先 】 ( 自治体 の 担当 課 等 の 名称 、 場所 、 郵 送 する 場合 の 宛 名 及び 住所 等 ) 必要 書類 等 は 以下 の とおり です 。 1 請求 者 名義 の 金融 機関 の 口座 番号 が わかる もの 2 請求 者 と 配偶 者 の 「 住民 税 課税 ( 非 課 税 ) 証明 書 」 3 印 鑑 ( 朱 肉 を 使う もの ) 4 請求 者 が 厚生 年金 加入 者 ( 被 用 者 ) の 場合 は 、 「 厚生 年金 加入 証明 書 」 (「 健康 保険 証 の コピー 」 で 代え る こと も でき ます 。 ) * 状況 によって は その他 の 書類 が 必要 に なる 場合 が あり ます 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L ) [UNK] お 問い合わせ ( 自治体 の 担当 課 等 の 名称 ) ( 電話 番号 )/( 開 庁 時間 )
#
# 第 2 子 出生 後 の 児童 手当 の 手続き を 教え て ください 。
# 「 児童 手当 ・ 特例 給付 額 改定 認定 請求 書 」 を ○ ○ 市 の ホームページ より ダウンロード し て い た だ き 、 必要 事項 を 記入 の 上 、 ( 自治体 の 担当 課 等 の 名称 ) へ 郵 送 又は ご 持参 ください 。 【 提出 先 】 ( 自治体 の 担当 課 等 の 名称 、 場所 、 郵 送 する 場合 の 宛 名 及び 住所 等 ) [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L ) [UNK] お 問い合わせ ( 自治体 の 担当 課 等 の 名称 ) ( 電話 番号 )/( 開 庁 時間 )
#
# 転出 し た 時 の 児童 手当 の 手続き を 教え て ください 。
# 1 .○○ 市 に 転出 届 を 提出 2 .( 自治体 の 担当 課 等 の 名称 ) へ 「 児童 手当 ・ 特例 給付 受給 事由 消滅 届 」 を 提出 3 . 転出 先 で 、 児童 手当 の 申請 を 行う 。 転出 予定 日 の 翌日 から 15 日 以内 に 申請 を 行なっ て ください 。 申請 の 際 に は 「 所得 証明 書 」 が 必要 と なる 場合 が あり ます 。 * 期限 を 経過 する と 手当 を 受け られ ない 月 が 発生 する 場合 が あり ます 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L ) [UNK] お 問い合わせ ( 自治体 の 担当 課 等 の 名称 ) ( 電話 番号 )/( 開 庁 時間 )
#
# 市内 で 引っ越し し た 時 の 児童 手当 の 手続き を 教え て ください 。
# 1 .○○ 市 に 転居 届 を 提出 2 .( 自治体 の 担当 課 等 の 名称 ) へ 「 児童 手当 ・ 特例 給付 住所 等 変更 届 」 を 提出 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L ) [UNK] お 問い合わせ ( 自治体 の 担当 課 等 の 名称 ) ( 電話 番号 )/( 開 庁 時間 )
#
# 児童 手当 の 厚生 年金 加入 証明 書 と は 何 です か ?
# 申請 者 が 被 用 者 ( 厚生 年金 等 加入 者 ) で ある 場合 に 必要 と なる 証明 書 です 。 勤務 先 で 証明 を 受け て ください 。 ただし 、 ご 加入 の 健康 保険 によって は 、 健康 保険 証 の コピー で 代え る こと が でき ます 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L ) [UNK] お 問い合わせ ( 自治体 の 担当 課 等 の 名称 ) ( 電話 番号 )/( 開 庁 時間 )
#
# 夫婦 別 居 する 時 の 児童 手当 の 手続き を 教え て ください 。
# ● 必要 書類 として 「 監 護 事実 の 申 立 書 」 と 「 お 子 様 の 世帯 全員 の 住民 票 ( 続 柄 あり )」 を 提出 する 必要 が あり ます 。 * 受給 者 と お 子 さま の 属する 世帯 の 世帯 主 の 自 署 ・ 押 印 が それぞれ 必要 です 。 ● 離婚 前提 の 別 居 で 受給 者 を 変更 し たい 場合 「 児童 手当 等 の 受給 資格 に 係る 申 立 書 」 と 離婚 協議 中 で ある こと を 明らか に できる 書類 を 提出 する 必要 が あり ます 。 * 状況 によって 、 必要 書類 等 変わる 場合 が あり ます ので 、 詳しく は お 問い合わせ ください 。 [UNK] お 問い合わせ ( 自治体 の 担当 課 等 の 名称 ) ( 電話 番号 )/( 開 庁 時間 )
#
# 離婚 し た 時 の 児童 手当 の 手続き を 教え て ください 。
# # 受給 者 を 変更 する 場合 1 . 離婚 届 を 提出 2 . 現 受給 者 の 「 児童 手当 ・ 特例 給付 受給 事由 消滅 届 」 を 提出 3 . 新しい 受給 者 で 新規 申請 し て い た だ く ため に 「 児童 手当 ・ 特例 給付 認定 請求 書 」 を 提出 4 . 必要 書類 : 離婚 受理 証明 書 又は 戸籍 [UNK] ほか * 状況 によって 、 必要 書類 等 が 変わる 場合 が あり ます ので 、 詳しく は お 問い合わせ ください 。 [UNK] お 問い合わせ ( 自治体 の 担当 課 等 の 名称 ) ( 電話 番号 )/( 開 庁 時間 )
#
# 留学 する 時 の 児童 手当 の 手続き を 教え て ください 。
# お 子 さま が 海外 留学 する 場合 、 「 児童 手当 等 に 係る 海外 留学 に関する 申 立 書 」 と 在学 証明 書 等 留学 の 事実 を 証明 する 書類 〔 書類 が 外国 語 の もの は 、 親族 以外 の 第三者 の 方 が 訳し た 翻訳 書 ( 訳 者 の 署名 ・ 押 印 あり )〕 が 必要 です 。 [UNK] お 問い合わせ ( 自治体 の 担当 課 等 の 名称 ) ( 電話 番号 )/( 開 庁 時間 )
#
# 子ども が 海外 に 住ん で いる 場合 、 児童 手当 は 支給 さ れ ます か ?
# 日本 に 居住 し て い ない と 児童 手当 は 受け 取 れ ませ ん 。 ( 留学 の 場合 は 除く ) [UNK] お 問い合わせ ( 自治体 の 担当 課 等 の 名称 ) ( 電話 番号 )/( 開 庁 時間 )
#
# 子ども が 海外 に 住ん で いる 場合 、 児童 手当 は 支給 さ れ ます か ?
# 戸籍 の 死亡 届 を 出 さ れ て いれ ば 、 児童 手当 の 手続き は 不要 です 。 亡 く なら れ た お 子 さま の 児童 手当 は 、 亡 く なら れ た 月 の 分 まで 支給 さ れ ます 。 * お 子 さま が 複数 人 い て 、 まだ 児童 手当 支給 対象 者 が いる 場合 に は 減 額 の 額 改定 届 が 必要 です 。 [UNK] お 問い合わせ ( 自治体 の 担当 課 等 の 名称 ) ( 電話 番号 )/( 開 庁 時間 )
#
# 親 が 亡くなっ た 時 の 児童 手当 の 手続き を 教え て ください 。
# 児童 手当 の 受給 者 が 亡くなっ た 場合 、 亡くなっ た 日 で 受給 資格 が 消滅 し ます 。 亡 く なら れ た 人 に 代わっ て お 子 さま を 養育 する 保護 者 は 手続き が 必要 です 。 詳しく は お 問い合わせ ください 。 [UNK] お 問い合わせ ( 自治体 の 担当 課 等 の 名称 ) ( 電話 番号 )/( 開 庁 時間 )
#
# 児童 手当 は い つ 振り 込ま れ ます か ?
# 児童 手当 の 支払 月 は 、 2 月 ( 10 ~ 1 月 分 ) ・ 6 月 ( 2 ~ 5 月 分 ) ・ 10 月 ( 6 ~ 9 月 分 ) の 年 3 回 です 。 支払 月 の 前 の 月 まで の 4 か月 分 が まとめ て 支給 さ れ ます 。 また 、 毎回 ○ 日 (○ 日 が 休日 の 場合 の 取り扱い を 記載 し て ください 。 例 「 ○ 日 が 休日 の とき は その 前 営業 日 」 ) に 支払い の 手続き を し ます 。 手続き から ○~○ 日 後 に 振り 込ま れ ます 。 ご 確認 ください 。 [UNK] お 問い合わせ ( 自治体 の 担当 課 等 の 名称 ) ( 電話 番号 )/( 開 庁 時間 )
#
# 児童 手当 が もらえる 月 を 教え て ください
# 児童 手当 の 支払 月 は 、 2 月 ( 10 ~ 1 月 分 ) ・ 6 月 ( 2 ~ 5 月 分 ) ・ 10 月 ( 6 ~ 9 月 分 ) の 年 3 回 です 。 支払 月 の 前 の 月 まで の 4 か月 分 が まとめ て 保護 者 の 口座 に 支給 さ れ ます 。 また 、 毎回 ○ 日 (○ 日 が 休日 の 場合 の 取り扱い を 記載 し て ください 。 例 「 ○ 日 が 休日 の とき は その 前 営業 日 」 ) に 支払い の 手続き を し ます 。 手続き から ○~○ 日 後 に 振り 込ま れ ます 。 ご 確認 下さい 。 上記 内容 を ご 確認 の 上 、 尚 振り 込み が 確認 でき ない 場合 は お 手 数 です が 下記 担当 係 まで ご 連絡 ください 。 [UNK] お 問い合わせ ( 自治体 の 担当 課 等 の 名称 ) ( 電話 番号 )/( 開 庁 時間 )
#
# 児童 手当 の 振 込 口座 を 変更 し たい 。
# # 口座 変更 方法 * 変更 口座 は 、 児童 手当 認定 請求 者 ( 受給 者 ) 本人 の 銀行 口座 に 限り ます 。 「 児童 手当 口座 振 替 依頼 書 」 を ○ ○ 市 の ホームページ より ダウンロード し て い た だ き 、 下記 窓口 まで 郵 送 又は ご 持参 ください 。 【 提出 先 】 ( 自治体 の 担当 課 等 の 名称 、 場所 、 郵 送 する 場合 の 宛 名 及び 住所 等 ) [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L ) [UNK] お 問い合わせ ( 自治体 の 担当 課 等 の 名称 ) ( 電話 番号 )/( 開 庁 時間 )
#
# 児童 手当 の 支給 額 を 教え て ください 。
# [UNK] 0 歳 ~ 3 歳 未満 の お 子 さま は すべて 一 人 につき 15 , 000 円 [UNK] 3 歳 ~ 小学校 修了 前 の 出生 順位 第 1 子 、 第 2 子 の 児童 一 人 につき 10 , 000 円 [UNK] 3 歳 ~ 小学校 修了 前 の 出生 順位 第 3 子 以降 の 児童 一 人 につき 15 , 000 円 [UNK] 中学生 の 子 は すべて 一 人 につき 10 , 000 円 [UNK] 所得 制限 の 限度 額 以上 の 人 は 一律 児童 一 人 につき 5 , 000 円 ( 特例 給付 ) ( 注 ) 出生 順位 は 手当 の 支給 対象 で は ない 18 歳 未満 の 児童 を 含め て 数え ます 。 [UNK] 所得 制限 額 の 詳細 は こちら ( 自治体 HP 内 関連 ページ の UR L ) [UNK] お 問い合わせ ( 自治体 の 担当 課 等 の 名称 ) ( 電話 番号 )/( 開 庁 時間 )
#
# 児童 手当 は いつ まで 支給 さ れ ます か ?
# お 子 さま が 15 歳 に なっ た 最初 の 3 月 分 まで 支給 さ れ ます 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L ) [UNK] お 問い合わせ ( 自治体 の 担当 課 等 の 名称 ) ( 電話 番号 )/( 開 庁 時間 )
#
# 児童 手当 の 更新 について 教え て ください 。
# 児童 手当 は 、 毎年 6 月 1 日 時点 の ご 家族 や 所得 の 状況 について 、 現 [UNK] 届 を 提出 し て い た だ く こと で 更新 と なり ます 。 対象 者 に は ○ 月 中 に 書類 を お 送り し ます 。 現 [UNK] 届 が お 手元 に 届き まし たら 、 現 [UNK] 届 に 必要 事項 を 記入 の 上 、 ご 提出 ください 。 現 [UNK] 届 の 提出 が ない 場合 、 6 月 分 以降 の 児童 手当 が 受給 でき なく なり ます 。 [UNK] 必要 書類 等 、 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L ) [UNK] お 問い合わせ ( 自治体 の 担当 課 等 の 名称 ) ( 電話 番号 )/( 開 庁 時間 )
#
# 児童 手当 現 [UNK] 届 について 教え て ください 。
# 児童 手当 現 [UNK] 届 と は 、 毎年 6 月 1 日 時点 における 状況 を 確認 する ため に 、 児童 手当 を 受給 さ れ て いる 人 に 提出 し て い た だ く もの です 。 対象 者 に は ○ 月 中 に 書類 を お 送り し ます 。 書類 が お 手元 に 届き まし たら 、 現 [UNK] 届 に 必要 事項 を 記入 の 上 、 ご 提出 ください 。 現 [UNK] 届 の 提出 が ない 場合 、 6 月 分 以降 の 児童 手当 が 受給 でき なく なり ます 。 [UNK] 必要 書類 等 、 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L ) [UNK] お 問い合わせ ( 自治体 の 担当 課 等 の 名称 ) ( 電話 番号 )/( 開 庁 時間 )
#
# 児童 手当 現 [UNK] 届 の 提出 を し なかっ たら どう なり ます か ?
# 児童 手当 現 [UNK] 届 の 提出 が ない 場合 、 今後 の 手当 の 支給 が でき なく なり ます 。 期限 が 過ぎ て も 必ず 提出 し て ください 。 なお 、 期日 まで に 提出 が ない 場合 、 次回 の 手当 の 支払い が 遅れる こと が あり ます ので ご 注意 ください 。 さらに 、 2 年間 提出 が ない と 、 受給 権 が 時効 で 消滅 し ます 。 [UNK] お 問い合わせ ( 自治体 の 担当 課 等 の 名称 ) ( 電話 番号 )/( 開 庁 時間 )
#
# 児童 手当 所得 制限 を 超え たら どう なり ます か ?
# 児童 手当 の 所得 制限 額 を 超 え ます と 、 「 特例 給付 」 と なり まし て 、 当面 の 間 、 中学校 修了 まで の お 子 さま 一 人 につき 月額 一律 5 , 000 円 が 支給 さ れ ます 。 [UNK] 所得 制限 額 の 詳細 は こちら ( 自治体 HP 内 関連 ページ の UR L ) [UNK] お 問い合わせ ( 自治体 の 担当 課 等 の 名称 ) ( 電話 番号 )/( 開 庁 時間 )
#
# 里 帰り 出産 し た 時 の 児童 手当 の 申請 について 教え て ください 。
# 里 帰り 出産 し た 場合 でも 、 ○ ○ 市 に 児童 手当 の 申請 を し て ください 。 申請 期限 は 出生 日 の 翌日 から 数え て 15 日 以内 です 。 郵 送 で も 受け付け て いる ので 、 必ず ご 提出 ください 。 * 児童 手当 請求 者 と 、 子ども の 住民 票 が 異なる 場合 は 、 担当 係 まで お 問い合わせ ください 。 [UNK] お 問い合わせ ( 自治体 の 担当 課 等 の 名称 ) ( 電話 番号 )/( 開 庁 時間 )
#
# 児童 手当 の 申請 期限 を 教え て ください 。
# お 子 さま の 出生 日 ・ ○ ○ 市 に 転入 し た 日 の 翌日 から 15 日 以内 に 申請 し て い た だ く 必要 が あり ます 。 期限 を 過ぎ て しまっ た 場合 に は 、 支給 開始 が 遅れ て し まい ます が 、 申請 の 翌月 分 から 支給 でき ます ので 、 できるだけ 早め に ご 申請 ください 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L ) [UNK] お 問い合わせ ( 自治体 の 担当 課 等 の 名称 ) ( 電話 番号 )/( 開 庁 時間 )
#
# 児童 手当 の 申請 者 は 父母 どちら です か ?
# お 子 さま の 父 又は 母 の うち 、 主たる 生計 維持 者 ( 所得 の 高い 人 ) が 請求 者 に なり ます 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L ) [UNK] お 問い合わせ ( 自治体 の 担当 課 等 の 名称 ) ( 電話 番号 )/( 開 庁 時間 )
#
# 児童 手当 の 制度 について 教え て ください 。
# 児童 手当 は 、 中学 3 年 生 まで の 児童 を 養育 し て いる 人 に 一定 の 額 を 支給 する 手当 です 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L ) [UNK] お 問い合わせ ( 自治体 の 担当 課 等 の 名称 ) ( 電話 番号 )/( 開 庁 時間 )
#
# 児童 手当 の 手続き は ( 自治体 の 支所 ・ 出張所 等 ) で でき ます か ?
# ( 自治体 の 支所 ・ 出張所 等 で の 取り扱い を 記載 し て ください 。 ) 例 「 出張所 で は 、 出生 届 又は 転入 届 を 提出 さ れ た 時 のみ 、 同時に 児童 手当 の 手続き を する こと が でき ます 。 」 [UNK] お 問い合わせ ( 自治体 の 担当 課 等 の 名称 ) ( 電話 番号 )/( 開 庁 時間 )
#
# 児童 手当 の 手続き は 郵 送 で でき ます か ?
# 郵 送 で の 手続き も 可能 です 。 ただし 、 ( 自治体 の 担当 課 等 の 名称 ) に 認定 請求 書 等 が 到着 し た 日 が 受付 日 と なり ます ので 、 出生 日 ・ 転出 予定 日 の 翌日 から 数え て 15 日 以内 に ( 自治体 の 担当 課 等 の 名称 ) へ 到着 する よう に 送付 し て ください 。 【 提出 先 】 ( 自治体 の 担当 課 等 の 名称 、 場所 、 郵 送 する 場合 の 宛 名 及び 住所 等 ) [UNK] お 問い合わせ ( 自治体 の 担当 課 等 の 名称 ) ( 電話 番号 )/( 開 庁 時間 )
#
# 施設 など に 入所 し た 時 の 児童 手当 の 手続き を 教え て ください 。
# 児童 養護 施設 等 に 入所 し て いる お 子 さま は 、 施設 の 設置 者 等 が 児童 手当 を 受給 し ます 。 既に ○ ○ 市 から 手当 受給 中 の お 子 さま が 施設 に 入所 する 場合 に は 、 「 児童 手当 ・ 特例 給付 受給 事由 消滅 届 」 が 必要 です 。 [UNK] お 問い合わせ ( 自治体 の 担当 課 等 の 名称 ) ( 電話 番号 )/( 開 庁 時間 )
#
# 児童 手当 で 必要 な 所得 証明 書 について 教え て ください 。
# 児童 手当 で 必要 な 所得 証明 書 と は 「 住民 税 課税 ( 非 課 税 ) 証明 書 」 の こと です 。 必要 な 年度 の 証明 書 は 前年度 の 1 月 1 日 に 在住 し て い た 市区 町村 の 住民 税 担当 課 で 発行 し ます 。 例 ) 平成 29 年度 住民 税 課税 ( 非 課 税 ) 証明 書 は 、 29 年 1 月 1 日 に 在住 し て い た 市区 町村 で 発行 。 * 勤務 先 で 発行 さ れる 源泉 徴収 票 、 住民 税 決定 通知 書 等 で は 代用 でき ませ ん 。 [UNK] お 問い合わせ ( 自治体 の 担当 課 等 の 名称 ) ( 電話 番号 )/( 開 庁 時間 )
#
# 転出 先 で 必要 な 所得 証明 書 の 請求 方法 を 教え て ください 。
# 所得 証明 書 ( 住民 税 課税 ( 非 課 税 ) 証明 書 ) は 住民 税 担当 課 で 請求 が でき ます 。 転出 先 で 必要 と なる 証明 書 の 年度 を ご 確認 の う え 、 必要 年度 の 前年度 の 1 月 1 日 に 在住 し て い た 市区 町村 の 住民 税 担当 課 で 請求 し て ください 。 例 ) 平成 29 年度 住民 税 課税 ( 非 課 税 ) 証明 書 は 、 29 年 1 月 1 日 に 在住 し て い た 市区 町村 で 請求 。 [UNK] ○ ○ 市 で の お 問い合わせ ( 自治体 の 担当 課 等 の 名称 ) ( 電話 番号 )/( 開 庁 時間 )
#
# ( 地域 交流 イベント ・ 地域 活動 イベント 等 ) と は なん です か ?
# ( 地域 交流 イベント ・ 地域 活動 イベント 等 を 実施 し て いる 場合 、 説明 を 記載 し て ください 。 ) < 参加 > < 親子 > ( 親子 で 参加 できる イベント 等 ) と は 、 .........( イベント 内容 等 を 説明 し て ください )......... 事業 です 。 ( イベント 開催 日 ) に 行っ て い ます 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# ( 自治体 の 施設 内 で 開催 さ れる 子ども ・ 保護 者 向け プログラム や イベント 等 ) について 教え て ください 。
# ( 自治体 の 施設 内 で 開催 さ れる 子ども ・ 保護 者 向け プログラム や イベント 等 の 説明 を 記載 し て ください 。 ) [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# 保育 室 と は 何 です か ?
# 保育 室 と は 、 ● ● 県 の 定める 設置 基準 を 満たし た 、 産 休 明け から 2 歳 まで の お 子 さん を 預 かる 小規模 な 保育 施設 です 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# AAA 保育園 について 教え て ください 。
# AAA 保育園 は 、 ( 住所 ) に ある 市立 ( 保育園 / 幼 保 一元 化 施設 ) です 。 詳しく は こちら を ご [UNK] ください 。 ( 自治体 HP 内 関連 ページ の UR L )
#
# 児童 手当 受給 者 の 所得 が 逆転 し た 時 は ?
# 所得 が 逆転 し た 場合 は 、 受給 者 を 変更 し て い た だ き ます 。 現 受給 者 による 「 児童 手当 ・ 特例 給付 受給 事由 消滅 届 」 の 提出 と 新 受給 者 による 新規 申請 手続き が 必要 です 。 [UNK] お 問い合わせ ( 自治体 の 担当 課 等 の 名称 ) ( 電話 番号 )/( 開 庁 時間 )
#
# 児童 手当 保留 通知 が 届き まし た 。
# 児童 手当 の 申請 について 、 不足 書類 の ある 人 に 保留 通知 を お 送り し て い ます 。 保留 通知 に 記載 さ れ て いる 書類 の 提出 を お願い し ます 。 [UNK] お 問い合わせ ( 自治体 の 担当 課 等 の 名称 ) ( 電話 番号 )/( 開 庁 時間 )
#
# 母子 手帳 を なくし た 場合 は 再 発行 でき ます か ?
# 母子 手帳 を なくし た とき は 、 再 交付 を 受け て ください 。 お 子 さん が 出生 前 の 母子 手帳 について は 、 ( 再 交付 を 受け られる 場所 ) で 再 交付 を 受け られ ます 。 お 子 さん が 出生 後 の 母子 手帳 について は 、 ( 再 交付 を 受け られる 場所 ) で 受け られ ます 。 申請 の 際 は ご 本人 確認 できる もの を お 持ち ください 。 [UNK] お 問い合わせ ( 自治体 の 担当 課 等 の 名称 ) ( 電話 番号 )/( 開 庁 時間 ) < 私立 > < 幼稚園 > < 補助 金 > < 申請 手続き > < 昨年 度 > < 今年 度 > 昨年 度 と 今年 度 で 私立 幼稚園 が 異なる 場合 は 、 新しい 私立 幼稚園 で 改めて 、 補助 金 の 申請 を し て い た だ き ます 。
#
# スポーツ センター について 教え て ください 。
# スポーツ センター は ご 利用 に なる 施設 により 利用 時間 が 異なり ます 。 詳しく は こちら を ご [UNK] ください 。 ( 自治体 HP 内 関連 ページ の UR L )
#
# 障害 児 の ため の 手当 について 教え て ください 。
# 障害 児 の ため の 手当 に は 児童 育成 ( 障害 ) 手当 、 特別 児童 扶養 手当 、 障害 児 福祉 手当 が あり ます 。 詳しく は こちら を ご [UNK] ください 。 [UNK] 児童 育成 ( 障害 ) 手当 ( 自治体 HP 内 関連 ページ の UR L ) [UNK] 特別 児童 扶養 手当 ( 自治体 HP 内 関連 ページ の UR L ) [UNK] 障害 児 福祉 手当 ( 自治体 HP 内 関連 ページ の UR L )
#
# 予防 接種 の 問い合わせ 窓口 を 教え て ください 。
# 予防 接種 について は 下記 に お 問い合わせ ください 。 [UNK] お 問い合わせ ( 自治体 の 担当 課 等 の 名称 ) ( 電話 番号 )/( 開 庁 時間 )
#
# 出産 の 不安 を 相談 できる ところ は あり ます か ?
# ○ ○ 市 で は 、 妊娠 し た 人 と パートナー を 対象 に 、 これから の 子育て や 、 地域 で 子育て を する ため の 仲間 づくり に 役立つ よう に 、 ( 母親 学級 等 の イベント ) を 開催 し て い ます 。 ( イベント の 内容 等 を 記載 し て ください 。 ) [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# 児童 手当 の 申請 を 忘れ て しまい まし た 。
# 出生 日 ・ 転入 し た 日 の 翌日 から 15 日 を 過ぎ て しまっ た 場合 に は 、 支払い が 遅れ て しまう 可能 性 が あり ます が 、 児童 手当 は 、 申請 の 翌月 分 から 支給 でき ます ので 、 できるだけ 早め に 申請 し て ください 。 [UNK] お 問い合わせ ( 自治体 の 担当 課 等 の 名称 ) ( 電話 番号 )/( 開 庁 時間 )
#
# ○ ○ 市立 保育園 の 定員 を 教え て ください 。
# ○ ○ 市立 ( 保育園 / 幼 保 一元 化 施設 ) の 定員 は こちら を ご [UNK] ください 。 ( 自治体 HP 内 関連 ページ の UR L )
#
# 私立 保育園 の 定員 を 教え て ください 。
# 私立 ( 保育園 / 幼 保 一元 化 施設 ) の 定員 は こちら を ご [UNK] ください 。 ( 自治体 HP 内 関連 ページ の UR L )
#
# 保育園 の 転 園 の 申し込み の 必要 な 書類 を 教え て ください 。
# 転 園 申 込 書 は 下記 ホームページ から ダウンロード が でき ます 。 PD F を 印刷 し て 記載 し て ください 。 その他 の 必要 書類 について は 入 園 の 申し込み と 同様 、 下記 を ご [UNK] ください 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# ( 自治体 が 行う 出産 助成 等 ) は いくら もらえ ます か ?
# ( 自治体 が 行う 出産 助成 等 ) は ( 助成 額 等 の 内容 を 記載 し て ください 。 ) と なり ます 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# 市役所 は いつ まで 開い て ます か ?
# ○ ○ 市役所 の 開 庁 時間 は ○ 時 ○ 分 から ○ 時 ○ 分 ( 土曜日 ・ 日曜日 、 祝 ・ 休日 および 12 月 29 日 ~ 1 月 3 日 を 除く ) です 。
#
# ( 地域 交流 イベント ・ 地域 活動 イベント 等 ) と は なん です か ?
# ( 地域 交流 イベント ・ 地域 活動 イベント 等 を 実施 し て いる 場合 、 説明 を 記載 し て ください 。 )
#
# 市内 の 認定 こども 園 の 場所 を 教え て ください 。
# ○ ○ 市内 の 認定 こども 園 について は こちら を ご [UNK] ください 。 ( 自治体 HP 内 関連 ページ の UR L )
#
# 戸籍 の 届出 について 教え て ください 。
# 戸籍 の 届出 は 市役所 △ 階 ( 自治体 の 担当 課 等 の 名称 ) にて 受け付け て い ます 。 また 、 夜間 ・ 休日 窓口 で は 、 届 書 の 受領 ( 預かり ) のみ 行っ て い ます 。 翌 開 庁 日 以降 に 戸籍 事務 担当 職員 が 届 書 の 記載 内容 ・ 添付 書類 など の 審査 を 行う ため 、 来 庁 を お願い する 場合 が あり ます 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# 本 日 営業 し て いる 病院 を 教え て ください 。
# ( 都道府県 や 医師 会 が 提供 する 医療 機関 案内 等 の 名称 ) で ご 確認 い た だ け ます 。 [UNK] 詳しく は こちら ( 当該 医療 機関 案内 等 の UR L )
#
# 氏名 が 変わっ た 時 の 児童 手当 は ?
# 「 児童 手当 ・ 特例 給付 氏名 変更 届 」 を 提出 し て い た だ き ます 。 氏名 変更 の 理由 によって は ( 例 . 婚姻 )、 別途 書類 の 提出 を お願い する 場合 が あり ます 。 [UNK] お 問い合わせ ( 自治体 の 担当 課 等 の 名称 ) ( 電話 番号 )/( 開 庁 時間 )
#
# ( 子育て 支援 情報 を まとめ た リーフ レット 等 ) について 教え て ください 。
# ( 子育て 支援 情報 を まとめ た リーフ レット 等 を 作成 し て いる 場合 は 、 説明 を 記載 し て ください 。 ) [UNK] 配布 場所 は こちら ・ AAA ・ BB B
#
# 子ども ・ 子育て 支援 新 制度 について 教え て ください 。
# 子ども ・ 子育て 支援 新 制度 と は 、 平成 24 年 8 月 に 成立 し た 「 子ども ・ 子育て 支援 法 」 、 「 認定 こども 園 法 の 一部 改正 」 、 「 子ども ・ 子育て 支援 法 及び 認定 こども 園 法 の 一部 改正 法 の 施行 に 伴う 関係 法律 の 整備 等 に関する 法律 」 の 子ども ・ 子育て 関連 3 法 に 基づく 制度 の こと を いい ます 。
#
# 市 の 奨学 資金 制度 について 教え て ください 。
# 市 の 奨学 資金 制度 は 、 経済 的 理由 により 高校 など へ の 進学 や 修学 が 困難 な 人 に 、 奨学 資金 を お 貸し する 制度 です 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# 戸籍 の 届出 について 教え て ください 。
# 戸籍 の 平日 夜間 や 休日 の 届出 は 、 ( 受付 場所 ) で 行っ て い ます 。 夜間 ・ 休日 窓口 で は 、 届 書 の 受領 ( 預かり ) のみ 行っ て い ます 。 翌 開 庁 日 以降 に 戸籍 事務 担当 職員 が 届 書 の 記載 内容 ・ 添付 書類 など の 審査 を 行う ため 、 来 庁 を お願い する 場合 が あり ます 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# 創業 支援 について 教え て ください 。
# ○ ○ 市 の 創業 支援 事業 について は こちら を ご [UNK] ください 。 ( 自治体 HP 内 関連 ページ の UR L )
#
# 保育 士 の 募集 は し て い ます か ?
# ○ ○ 市 の 保育 士 の 募集 について は こちら を ご 確認 ください 。 ( 自治体 HP 内 関連 ページ の UR L )
#
# ( 住民 票 ・ 戸籍 担当 課 ) の 窓口 の 混雑 状況 を 教え て ください
# ( 混雑 状況 等 の お 知 ら せ システム が ある 場合 は 、 説明 を 記載 し て ください 。 ) 例 「 ( 住民 票 ・ 戸籍 担当 課 ) 窓口 の 混雑 状況 は こちら を ご 確認 ください 。 ( 自治体 HP 内 関連 ページ の UR L )」
#
# AAA 保健 相談 所 の 電話 番号 を 教え て ください
# AAA 保健 相談 所 の 電話 番号 は 、 ( 電話 番号 ) です 。 ( 自治体 HP 内 関連 ページ の UR L )
#
# 単身 赴任 ( 国内 ) し た 時 の 児童 手当 は ?
# # 児童 手当 の 受給 者 が 単身 赴任 で ○ ○ 市外 に 引っ 越 さ れる 場合 ( 国内 ) 1 .○○ 市 に 転出 届 を 提出 2 .( 自治体 の 担当 課 等 の 名称 ) に 「 児童 手当 ・ 特例 給付 受給 事由 消滅 届 」 を 提出 3 . 転出 先 で 、 児童 手当 の 申請 を 行う [UNK] お 問い合わせ ( 自治体 の 担当 課 等 の 名称 ) ( 電話 番号 )/( 開 庁 時間 )
#
# ( 自治体 が 開催 する 親子 教室 等 ) について 教え て ください 。
# ( 自治体 が 開催 する 親子 教室 等 の 説明 を 記載 し て ください 。 ) [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# なぜ 、 私立 小中学校 の 転校 の 手続き を 教え て ください 。
# ○ ○ 市 に お 住まい で 、 かつ 私立 等 の 小中学校 から 市立 の 小中学校 へ の 転校 を ご 希望 の 方 は 、 市役所 △ 階 ( 自治体 の 担当 課 等 の 名称 ) に 申し出 て ください 。 編入 学 について は 学区 域 の 学校 へ の 就学 と なり ます 。 [UNK] お 問い合わせ ( 自治体 の 担当 課 等 の 名称 ) ( 電話 番号 )/( 開 庁 時間 )
#
# 住民 票 は 代理人 も 受け 取 れ ます か ?
# 住民 票 の 写し の 請求 など を 本人 の 代理人 が 行う 場合 は 、 代理人 の 本人 確認 書類 や 委任 状 等 が 必要 に なり ます 。 [UNK] 必要 な 書類 等 、 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# 市 の 就学 援助 について 教え て ください 。
# ○ ○ 市 で は 、 国 公 立 の 小中学校 に 通う 児童 ・ 生徒 の 保護 者 の 方 に 、 ご 家庭 の 事情 に 応じ て 学校 で かかる 費用 を 補助 し て い ます 。 詳しい こと は 、 学校 を通じて お 知 ら せ し ます 。 ○ ○ 市立 以外 の 国 公 立 小 ・ 中学校 へ 通っ て いる 場合 は 、 下記 まで お 問い合わせ ください 。 [UNK] お 問い合わせ ( 自治体 の 担当 課 等 の 名称 ) ( 電話 番号 )/( 開 庁 時間 )
#
# 一時 保育 は 当日 キャンセル でき ます か ?
# ( キャンセル の 場合 の 対応 を 記載 し て ください 。 ) 例 「 一時 保育 を キャンセル さ れる 場合 は 、 各 施設 へ お 早め に ご 連絡 ください 。 当日 キャンセル の 場合 、 キャンセル 料 が 発生 する 場合 が あり ます 。 詳しく は 各 施設 へ お 問い合わせ ください 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# 転入 し た とき 、 小学校 の 手続き は どう し たら いい です か ?
# 転入 の 際 、 小学校 の 手続き として は 、 転入 手続 の 際 に 、 就学 通知 書 を お 渡し し て い ます 。 前 の 学校 の 在学 証明 書 など とともに 、 指定 の 学校 に 提出 し て 入学 し て ください 。 なお 、 転 入学 さ れる 方 について も 、 学校 選択 希望 制 による 学校 選択 が 可能 です 。 受 入 人数 や 学年 によって 状況 が 異なり ます ので 詳しく は お 問い合わせ ください 。 [UNK] お 問い合わせ ( 自治体 の 担当 課 等 の 名称 ) ( 電話 番号 )/( 開 庁 時間 )
#
# 子ども が 低 体重 で 心配 です 。
# 出生 通知 票 は 、 低 体重 児 届 を かね て い ます 。 出生 通知 書 に ご 記入 の 上 提出 し て ください 。 低 体重 、 授 乳 の 方法 や 体重 の 増え 方 など 、 心配 ごと が ある 人 に は 「 新生 児 訪問 事業 」 として 、 助 産 師 や 地区 担当 保健 師 が 早め の 訪問 を さ せ て い た だ く 場合 が あり ます 。 入院 中 の 人 は 、 電話 連絡 で も 結 構 です 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# 家庭 的 保育 事業 ( 保育 ママ ) について 教え て ください 。
# 家庭 的 保育 事業 と は 、 乳児 又は 幼児 について 、 家庭 的 保育 者 の 居 宅 その他 の 場所 において 、 家庭 的 保育 者 による 保育 を 行う 事業 です 。 児童 福祉 法 第 34 条 の 15 第 2 項 により 、 市区 町村 の 認可 を 受け て 行う もの と 、 認可 を 受け ず に 行う もの が あり ます 。 家庭 的 保育 者 は 、 市区 町村 の 認定 を 受ける 必要 が あり ます 。 ○ ○ 市 の 基準 について は 下記 に 定め が あり ます 。 [UNK] 条例 名 ( 例 「 ○ ○ 市 家庭 的 保育 事業 等 の 設備 及び 運営 に関する 基準 を 定める 条例 」 )) ( 自治体 HP 内 関連 ページ の UR L )
#
# 単身 赴任 ( 国外 ) し た 時 の 児童 手当 は ?
# # 児童 手当 の 受給 者 が 単身 赴任 で 国外 へ 引っ 越 さ れる 場合 1 .○○ 市 に 転出 届 を 提出 2 .( 自治体 の 担当 課 等 の 名称 ) に 「 児童 手当 ・ 特例 給付 受給 事由 消滅 届 」 を 提出 3 . 配偶 者 の 方 で 児童 手当 の 新規 申請 を 行う [UNK] お 問い合わせ ( 自治体 の 担当 課 等 の 名称 ) ( 電話 番号 )/( 開 庁 時間 )
#
# AAA 保育園 の 一時 保育 について 教え て ください 。
# AAA 保育園 で 実施 し て いる 一時 保育 について は こちら を ご [UNK] ください 。 ( 自治体 HP 内 関連 ページ の UR L )
#
# パスポート の 申請 に 必要 な 書類 を 教え て ください 。
# パスポート を 新規 に 発給 する 際 に 必要 な 書類 について は こちら を ご [UNK] ください 。 http s :// www . m of a . go . jp / m of aj / to ko / p ass port / p ass _ 5 . h t m l # 01 ( この ほか 、 都道府県 パスポート センター の UR L ・ 電話 番号 等 を 記載 する こと も 考え られ ます 。 )
#
# 妊娠 届 を 代理 で も 届出 でき ます か ?
# 妊娠 届 ( 母子 手帳 交付 申請 含む ) は 代理 で も 届出 する こと が でき ます 。 ただし 、 妊 婦 ご 本人 と 同一 世帯 の 方 以外 が 代理 申請 する 場合 は 、 委任 状 が 必要 に なり ます 。 また 、 妊娠 届 に は 妊娠 週 数 、 分 [UNK] 予定 日 、 性 病 に関する 健康 診断 ( 血液 検査 ) の 有無 、 結核 に関する 健康 診断 ( レン ト ゲン 検査 ) の 有無 及び 診断 を 受け た 医療 機関 の 名前 ・ 所在地 ・ 診断 者 氏名 を 記入 し て い た だ く 必要 が あり ます ので 、 予め 妊 婦 ( 委任 者 ) ご 本人 に ご 確認 の 上 お 越し ください 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# 子ども の 補助 金 の 申請 手続き を 教え て ください 。
# 幼稚園 など で 配布 し て いる 申請 書 「 ( 補助 金 申請 書 の タイトル )」 に 必要 事項 を 明記 し 、 幼稚園 へ 提出 し て ください 。 当該 年度 に ○ ○ 市 の 住民 税 が 課税 さ れ て い ない 人 は 、 当該 年度 の 「 市区 町 村民 税 納税 ( 税 額 ) 通知 書 」 または 当該 年度 の 「 課税 ( 非 課 税 ) 証明 書 」 を 提出 し て ください 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# ○ ○ 市立 幼稚園 の 抽選 は 、 幼稚園 が 行う の です か 。
# ○ ○ 市立 幼稚園 の 入 園 の 選考 は 、 ○ ○ 市 教育 委員 会 が 行い ます 。
#
# ( 自治体 の 古 着 など の 拠点 回収 ) について 教え て ください 。
# 家庭 で 不 用 に なっ た 、 再 使用 できる 衣類 等 を 拠点 回収 し て い ます 。 回収 さ れ た もの は 、 国内 や 国外 で 再 使用 ( リ ユース ) さ れ ます 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# 出生 届 は 誰 が 届出 すれ ば いい です か ?
# 出生 届 は 父 または 母 が 届出 人 と なり ます 。 届 書 を 父母 以外 の 人 が 持参 する 場合 でも 、 父 ・ 母 が 届出 人 として 署名 押 印 が 必要 です 。 ただし 、 父母 が 法律 上 婚姻 し て い ない 場合 、 母 が 届出 人 と なり ます 。 父 または 母 が 届出 でき ない 場合 、 同居 者 または 出産 に 立ち 会 っ た 医師 ・ 助 産 師 が 届出 を する 必要 が あり ます 。 詳しく は ( 自治体 の 担当 課 等 の 名称 ) まで お 問い合わせ ください 。 [UNK] お 問い合わせ ( 自治体 の 担当 課 等 の 名称 ) ( 電話 番号 )/( 開 庁 時間 )
#
# ○ ○ は 何 ごみ です か ?
# ○ ○ は × × ごみ です 。 ( 必要 に 応じ て 、 ごみ を 出す にあたって の 留意 事項 等 を 追加 し て ください 。 ) 詳しく は こちら を ご [UNK] ください 。 ( 自治体 HP 内 関連 ページ の UR L )
#
# ( 自治体 が 開催 する 幼児 食 講習 会 等 ) について 教え て ください 。
# ( 自治体 が 開催 する 幼児 食 講習 会 等 ) は 、 ○ 月 ○ 日 (○) に 行わ れ ます 。 時間 :○:○~○:○ 場所 :○○○○○ 持ち 物 :○○○○○ [UNK] 申し込み は こちら ( 電話 番号 )/( 開 庁 時間 )
#
# いじめ の 相談 は どこ に すれ ば いい です か ?
# いじめ や ひき こ も り 等 に関する 相談 は 「 ( 自治体 が 設置 する 相談 窓口 等 )」 に ご 相談 ください 。 ( 相談 窓口 等 の 説明 を 記載 し て ください 。 ) [UNK] お 問い合わせ ( 自治体 が 設置 する 相談 窓口 等 の 名称 ) ( 電話 番号 )/( 相談 受付 日時 )
#
# ○ ○ 市 に 幼稚園 は いくつ あり ます か ?
# ○ ○ 市 の 幼稚園 について は こちら を ご 確認 ください 。 [UNK] 市立 幼稚園 一覧 ( 自治体 HP 内 関連 ページ の UR L ) ○ ○ 市 で は 、 市立 幼稚園 に 入 園 できる の は ○ 歳 児 (○ 年 保育 ) と ○ 歳 児 (○ 年 保育 ) です 。 [UNK] 私立 幼稚園 一覧 ( 自治体 HP 内 関連 ページ の UR L ) 私立 幼稚園 の 場合 、 原則 として 3 歳 児 から 最長 3 年 保育 が 可能 です 。 詳しく は 入 園 を 希望 する 幼稚園 へ お 問い合わせ ください 。
#
# 子ども の 予防 接種 について 教え て ください 。
# 子ども の 予防 接種 に は 法律 で 市区 町村 が 接種 を 行う こと が 定め られ て いる 「 定期 予防 接種 」 と 、 それ 以外 の 任意 で 受け られる 「 任意 予防 接種 」 が あり ます 。 ○ ○ 市 で は 、 定期 予防 接種 と 一部 の 任意 予防 接種 について 、 助成 制度 を 設け て い ます 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# ○ ○ 市 の 面積 を 教え て ください 。
# ○ ○ 市 の 面積 は ○ ○ 平方キロメートル です 。 ( この ほか 、 ○ ○ 市 の 面積 について の 特徴 等 が あれ ば 、 適 宜 記載 し て ください )
#
# 子ども 医療 費 助成 について 教え て ください 。
# 乳 幼 児 ( 子ども ) 医療 費 助成 制度 は 、 医療 費 に かかる 保護 者 の 負担 を 軽減 する こと を 目的 として 、 ○ ○ 市 が 医療 費 の 一部 を 助成 する 制度 です 。 乳 幼 児 医療 証 は 小学校 就学 前 の 乳 幼 児 、 子ども 医療 証 は 小学 1 年 生 から 中学 3 年 生 まで の 児童 を 対象 に 発行 し て い ます 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# 3 歳 児 健 診 は い つ です か ?
# 3 歳 児 健 診 は 子ども の 3 歳 の 誕生 月 に 通知 さ れ ます ので 、 指定 の 保健 相談 所 にて 受 診 し て ください 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# 子育て の イベント は あり ます か ?
# ( 自治体 の 担当 課 や 子育て センター 等 の 名称 ) で は 、 毎月 定期 的 に 催し 物 を 行っ て い ます 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# 母子 手帳 は 転出 し て も そのまま 持っ て い て よい です か ?
# 母子 手帳 は 住所 が 変わっ て も そのまま お 使い い た だ け ます 。 再 発行 等 の 手続 は 必要 あり ませ ん 。 [UNK] お 問い合わせ ( 自治体 の 担当 課 や 子育て センター 等 の 名称 ) ( 電話 番号 )/( 開 庁 時間 )
#
# 自転車 放置 禁止 区域 について 教え て ください 。
# 自転車 放置 禁止 区域 について は こちら で ご 確認 ください 。 ( 自治体 HP 内 関連 ページ の UR L )
#
# 保育園 の 募集 時期 は い つ です か ?
# 翌年 4 月 入 園 の 申し込み は 毎年 ○ 月頃 から 受け付け て い ます 。 4 月 以外 の 入 園 について も 申し込み は 受け付け て い ます 。 入 園 申 込 の 締 切 日 等 は 、 以下 の ページ より ご 確認 ください 。 ( 自治体 HP 内 関連 ページ の UR L )
#
# 国民 健康 保険 証 の 返却 について 教え て ください 。
# 有効 期限 が 切れ て いる もの は ( 自治体 の 担当 課 、 支所 ・ 出張所 等 ) へ ご 返却 ください 。 ただし 、 市外 へ 転出 し た とき の 「 国民 健康 保険 証 」 は 、 新しい 住所 へ の 住み 始める 日 の 前日 まで ご 使用 い た だ く もの です ので 、 新しい 住所 へ 住み 始め て から ご 返却 ください 。 上記 返却 先 に 直接 お 持ち い た だ く か 、 ( 自治体 の 担当 課 等 の 名称 ) へ ご 郵 送 ください 。
#
# 就 園 奨励 費 の 手続き について 教え て ください 。
# 就 園 奨励 費 の 申請 は 、 幼稚園 など で 配布 し て いる 申請 書 「 ( 申請 書 の タイトル )」 に 必要 事項 を 明記 し 、 幼稚園 へ 提出 し て ください 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# 乳 幼 児 ・ 子ども 医療 証 の 発行 申請 は 郵 送 で も でき ます か ?
# 申請 期限 は あり ませ ん が 、 助成 を 受け られる の は 申請 の 日 から です 。 ただし 、 出生 ・ 転入 から 14 日 以内 に 申請 する と 、 出生 ・ 転入 の 日 から 有効 です 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# 離婚 の 手続き を 教え て ください 。
# 離婚 する 場合 は 届出 が 必要 と なり ます 。 [UNK] 離婚 届 について は こちら を ご [UNK] ください ( 自治体 HP 内 関連 ページ の UR L )
#
# 市役所 の 開 庁 時間 を 教え て ください 。
# ○ ○ 市役所 の 開 庁 時間 は ○ 時 ○ 分 から ○ 時 ○ 分 ( 土曜日 ・ 日曜日 、 祝 ・ 休日 および 12 月 29 日 ~ 1 月 3 日 を 除く ) です 。
#
# 家事 を 手伝っ て くれる サービス は あり ます か 。
# ( 家事 支援 等 を 行っ て いる 場合 は 記載 し て ください 。 ) 例 「 中学生 以下 の 児童 を 扶養 し て いる ひとり 親 家庭 を 対象 に 家事 援助 者 派遣 事業 を 実施 し て い ます 。 家事 など 日常 生活 に 支障 が ある とき 、 保護 者 が 在 宅 し て いる 時間 帯 に 家事 援助 者 を 派遣 し ます 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )」
#
# 子ども の 不 登校 を 相談 できる ところ は あり ます か ?
# ( 自治体 の 担当 課 等 の 名称 ) で は 、 子ども に関する 様々 な 悩み や 問題 について 相談 に 応じ たり 、 学校 に 行け ない 児童 ・ 生徒 の 元気 回復 や 学習 の 支援 を 行っ て い ます 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# 乳 幼 児 ・ 子ども 医療 証 の 発行 申請 に 必要 な もの を 教え て ください 。
# 乳 幼 児 ・ 子ども 医療 証 の 発行 を 受ける に は 、 お 子 さん の 健康 保険 証 の コピー を 添え て 、 乳 幼 児 ・ 子ども 医療 証 交付 申請 書 を 下記 窓口 まで ご 提出 ください 。 ( 郵 送 受付 可 ) ただし 、 ○ ○ 市 国民 健康 保険 に ご 加入 の 場合 は 、 健康 保険 証 の コピー は 不要 です 。 ※ 出生 し た ばかり で お 子 さん の 健康 保険 証 が 手元 に ない 場合 は 、 父母 の 健康 保険 証 など 、 ご 加入 予定 の 健康 保険 の 保険 証 の コピー を 添え て ください 。 後日 、 お 子 さん の 健康 保険 証 の コピー を ご 提出 い た だ く よう お願い い た し ます 。 【 提出 先 】 ( 自治体 の 担当 課 等 の 名称 、 場所 、 郵 送 する 場合 の 宛 名 及び 住所 等 ) [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# 印 鑑 登録 の 手続き について 教え て ください 。
# 印 鑑 登録 申請 ( 本人 による 申請 ) の 手続き について は こちら を ご [UNK] ください 。 ( 自治体 HP 内 関連 ページ の UR L ) 代理人 による 申請 手続き について は こちら を ご [UNK] ください 。 ( 自治体 HP 内 関連 ページ の UR L )
#
# 妊 婦 健 診 や 乳児 健 診 等 が 受け られる 契約 医療 機関 は どこ です か ?
# 妊 婦 健 診 や 乳児 健 診 等 が 受け られる 市内 の 契約 医療 機関 について は こちら を ご [UNK] ください 。 ( 自治体 HP 内 関連 ページ の UR L )
#
# 資源 ごみ について 教え て ください 。
# 資源 ごみ と は 、 蛍光 管 類 、 スプ レー 缶 ・ カセット ボン ベ 、 古 紙 、 びん 、 缶 、 ペット ボ トル など です 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# 市役所 の 開 庁 時間 を 教え て ください 。
# ○ ○ 市役所 内 の 駐車 場 ・ 駐 輪 場 について は こちら を ご [UNK] ください 。 ( 自治体 HP 内 関連 ページ の UR L )
#
# 近く の 公園 を 教え て ください 。
# ( 位置 情報 を 利用 し て 近隣 の 施設 を 検索 する 機能 が ある 場合 は 、 検索 方法 を 記載 し て ください 。 ) 例 「 お 近く の 公園 は 、 メニュー の 周辺 施設 検索 より 探す こと が でき ます 。 周辺 施設 検索 を タップ し て 位置 情報 を 送っ て ください 。 」
#
# 乳 幼 児 ・ 子ども 医療 証 の 発行 申請 は 郵 送 で も でき ます か ?
# 乳 幼 児 ・ 子ども 医療 証 の 発行 は 郵 送 で も 申請 が でき ます 。 お 子 さん の 健康 保険 証 の コピー を 添え て 、 乳 幼 児 ・ 子ども 医療 証 交付 申請 書 を 下記 窓口 まで 郵 送 し て ください 。 【 提出 先 】 ( 自治体 の 担当 課 等 の 名称 、 場所 、 郵 送 する 場合 の 宛 名 及び 住所 等 ) [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# 子ども の 健康 保険 証 の 手続き について 教え て ください 。
# 出生 し た ばかり で お 子 さん の 健康 保険 証 が 手元 に ない 場合 は 、 父母 の 健康 保険 証 など 、 ご 加入 予定 の 健康 保険 の 保険 証 の コピー を 添え て ください 。 後日 、 お 子 さん の 健康 保険 証 の コピー を ご 提出 い た だ く よう お願い い た し ます 。 ただし 、 ○ ○ 市 国民 健康 保険 に ご 加入 の 場合 は 、 健康 保険 証 の コピー は 不要 です 。 【 提出 先 】 ( 自治体 の 担当 課 等 の 名称 、 場所 、 郵 送 する 場合 の 宛 名 及び 住所 等 ) [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# 子ども の 医療 証 は 市外 の 病院 で も 使え ます か ?
# 乳 幼 児 ・ 子ども 医療 証 は ● ● 県内 で あれ ば 使え ます 。 健康 保険 証 と 一緒 に 医療 機関 の 窓口 で 医療 証 を ご 提示 ください 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# 子ども の 医療 証 は ● ● 県 外 の 病院 で も 使え ます か ?
# 乳 幼 児 ・ 子ども 医療 証 は ● ● 県 外 の 医療 機関 で は 使え ませ ん 。 健康 保険 証 のみ を 使っ て い た だ き 、 自己 負担 し た 残り の 分 は 、 ○ ○ 市 へ 払い 戻し の 申請 を し て ください 。 ※ ただし 、 県内 ・ 県 外 を 問わ ず 、 健康 保険 証 を 使わ ず に 全額 自己 負担 し た 場合 、 コル セット や 弱 視 用 眼鏡 など 医療 用 の 補 装 具 を 購入 し た 場合 、 または 入院 し て 医療 費 が 高額 に なっ た 場合 に は 、 この 支給 申請 前 に 加入 さ れ て いる 健康 保険 へ の 手続き が 必要 と なり ます 。 [UNK] 支給 申請 は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# 子ども の 医療 証 の 再 発行 は でき ます か ?
# 乳 幼 児 ・ 子ども 医療 証 は 再 発行 が でき ます 。 「 乳 幼 児 ・ 子ども 医療 証 再 交付 申請 書 」 を 下記 窓口 まで ご 提出 ください 。 ( 郵 送 受付 可 ) 申請 後 、 再 発行 し た 医療 証 を 郵 送 い た し ます 。 【 提出 先 】 ( 自治体 の 担当 課 等 の 名称 、 場所 、 郵 送 する 場合 の 宛 名 及び 住所 等 ) [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# 市内 で 引っ越し し た とき の 乳 幼 児 ・ 子ども 医療 証 の 手続き を 教え て ください 。
# 乳 幼 児 ・ 子ども 医療 証 の 住所 が 変わっ た とき は 、 子ども 医療 費 助成 申請 事項 変更 届 を 下記 窓口 まで ご 提出 ください 。 申請 後 、 新しい 医療 証 を 郵 送 い た し ます 。 なお 、 新しい 医療 証 が 届く まで の 間 は そのまま 古い 医療 証 を お 使い ください 。 【 提出 先 】 ( 自治体 の 担当 課 等 の 名称 、 場所 、 郵 送 する 場合 の 宛 名 及び 住所 等 ) [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# 氏名 が 変わっ た とき の 乳 幼 児 ・ 子ども 医療 証 の 手続き を 教え て ください 。
# 乳 幼 児 ・ 子ども 医療 証 の 氏名 が 変わっ た とき は 、 子ども 医療 費 助成 申請 事項 変更 届 を 下記 窓口 まで ご 提出 ください 。 申請 後 、 新しい 医療 証 を 郵 送 い た し ます 。 なお 、 新しい 医療 証 が 届く まで の 間 は そのまま 古い 医療 証 を お 使い ください 。 【 提出 先 】 ( 自治体 の 担当 課 等 の 名称 、 場所 、 郵 送 する 場合 の 宛 名 及び 住所 等 ) [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# 子ども の 医療 証 の 保護 者 の 変更 は でき ます か ?
# 子ども の 医療 証 の 保護 者 の 変更 を する 場合 は 、 子ども 医療 費 助成 申請 事項 変更 届 を 下記 窓口 まで ご 提出 ください 。 申請 後 、 新しい 医療 証 を 郵 送 い た し ます 。 なお 、 新しい 医療 証 が 届く まで の 間 は そのまま 古い 医療 証 を お 使い ください 。 【 提出 先 】 ( 自治体 の 担当 課 等 の 名称 、 場所 、 郵 送 する 場合 の 宛 名 及び 住所 等 ) [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# 子ども の 医療 証 を 使わ ず に 病院 を 受 診 し て しまっ た の です が 。
# 医療 機関 で 自己 負担 し た 分 は 、 ○ ○ 市 へ 払い 戻し の 申請 を し て ください 。 ※ ただし 、 県内 ・ 県 外 を 問わ ず 、 健康 保険 証 を 使わ ず に 全額 自己 負担 し た 場合 、 コル セット や 弱 視 用 眼鏡 など 医療 用 の 補 装 具 を 購入 し た 場合 、 または 入院 し て 医療 費 が 高額 に なっ た 場合 に は 、 この 支給 申請 前 に 加入 さ れ て いる 健康 保険 へ の 手続き が 必要 と なり ます 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# 子ども の 医療 証 は 健康 診断 で も 使え ます か ?
# 健康 診断 に 乳 幼 児 ・ 子ども 医療 証 は 使え ませ ん 。
#
# 子ども の 医療 証 は 予防 接種 で も 使え ます か ?
# 予防 接種 に 乳 幼 児 ・ 子ども 医療 証 は 使え ませ ん 。
#
# 児童 扶養 手当 証書 を なくし た とき は ?
# 児童 扶養 手当 証書 を 失 くし た とき は 、 ( 自治体 の 担当 課 等 の 名称 ) にて 証書 亡 失 届 を 提出 し て ください 。 再 発行 の 手続き を い た し ます 。 < 入院 > < 食事 > < 療養 > 入院 時 の 食事 療養 費 の 自己 負担 分 ( 子ども の 医療 費 ) は 、 ○ ○ 市 へ 払い 戻し の 申請 を し て ください 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# 子ども の 医療 証 は 補 装 具 の 助成 対象 です か ?
# 補 装 具 を 購入 し た 場合 は 、 加入 し て いる 健康 保険 組合 等 に 医療 費 申請 を し た う え で 、 ○ ○ 市 へ 払い 戻し の 申請 を し て ください 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# 子ども の 医療 証 の 払 戻 ( 現金 給付 ) の 申請 期限 は ?
# 子ども の 医療 証 の 払 戻 の 申請 期限 は 、 原則 領 収 印 の 日付 から 5 年間 です 。 ただし 、 健康 保険 証 を 使わ ず に 全額 自己 負担 し た 場合 、 コル セット や 弱 視 用 眼鏡 など 医療 用 の 補 装 具 を 購入 し た 場合 は 別途 ご 相談 ください 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# 子ども の 医療 証 の 払 戻 ( 現金 給付 ) の 申請 は 郵 送 で も でき ます か ?
# 子ども の 医療 証 の 払 戻 申請 は 郵 送 で も でき ます 。 領 収 書 の 原本 と お 子 様 の 健康 保険 証 の コピー を 添え て 、 子ども 医療 助成 費 支給 申請 書 を 下記 まで ご 提出 ください 。 【 提出 先 】 ( 自治体 の 担当 課 等 の 名称 、 場所 、 郵 送 する 場合 の 宛 名 及び 住所 等 ) [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# 子ども の 医療 証 は 更新 が あり ます か ?
# ( 更新 時 の 取り扱い について 記載 し て ください 。 ) 医療 証 は 毎年 更新 さ れ 、 有効 期限 は 毎年 9 月 30 日 まで です 。 10 月 1 日 以降 の 新しい 医療 証 は 、 自動的 に ご 自宅 へ 郵 送 い た し ます 。 この ほか 、 小学校 へ 入学 する お 子 さん は 3 月 31 日 に 乳 幼 児 医療 証 の 有効 期限 が 切れ る ので 、 4 月 1 日 以降 の 子ども 医療 証 を 自動的 に ご 自宅 へ 郵 送 い た し ます 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# 児童 扶養 手当 は いつ まで 支給 さ れ ます か ?
# 児童 扶養 手当 の 資格 は 、 お 子 さま の 出生 から 18 歳 に 達し た 日 以降 の 最初 の 3 月 31 日 まで です 。 ( 児童 に 中 度 以上 の 障害 が ある 場合 は 20 歳 未満 まで ) [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# 障害 児 の ため の 手当 について 教え て ください 。
# 障害 児 の ため の 手当 に は 児童 育成 ( 障害 ) 手当 、 特別 児童 扶養 手当 、 障害 児 福祉 手当 が あり ます 。 詳しく は こちら を ご [UNK] ください 。 [UNK] 児童 育成 ( 障害 ) 手当 ( 自治体 HP 内 関連 ページ の UR L ) [UNK] 特別 児童 扶養 手当 ( 自治体 HP 内 関連 ページ の UR L ) [UNK] 障害 児 福祉 手当 ( 自治体 HP 内 関連 ページ の UR L )
#
# 児童 扶養 手当 の 申請 に 必要 な もの を 教え て ください 。
# 児童 扶養 手当 の 申請 に 必要 な もの は 下記 の とおり です 。 1 申請 者 と 児童 の 戸籍 [UNK] 2 申請 者 名義 の 銀行 口座 の わかる もの 3 所得 証明 書 ( 公 簿 により 確認 できる 場合 は 、 必要 あり ませ ん ) 4 申請 者 と 児童 が 加入 し て いる 健康 保険 証 5 印 鑑 他 状況 によって 必要 な 書類 が 異なり ます 。 詳しく は 、 ( 自治体 の 担当 課 等 の 名称 ) まで お 問い合わせ ください 。 [UNK] お 問い合わせ ( 自治体 の 担当 課 等 の 名称 ) ( 電話 番号 )/( 開 庁 時間 )
#
# 児童 扶養 手当 ( ひとり 親 手当 ) は 郵 送 で も 申請 でき ます か ?
# 児童 扶養 手当 ( ひとり 親 手当 ) の 申請 は 、 窓口 で の 面 談 が 必要 に なり ます 。 ( 自治体 の 担当 課 等 の 名称 ) まで お 越し ください 。
#
# 児童 扶養 手当 ( ひとり 親 手当 ) は ( 自治体 の 支所 ・ 出張所 等 ) で 申請 でき ます か ?
# 児童 扶養 手当 ( ひとり 親 手当 ) の 申請 は 、 窓口 で の 面 談 が 必要 に なり ます 。 ( 自治体 の 支所 ・ 出張所 等 ) で は 申請 でき ませ ん 。 ( 自治体 の 担当 課 等 の 名称 ) まで お 越し ください 。
#
# 児童 扶養 手当 ( ひとり 親 手当 ) は 未婚 でも 受け られ ます か ?
# ひとり 親 手当 は 未婚 で も 受給 でき ます が 、 その ほか 受給 条件 が あり ます 。 詳しく は 以下 の ページ を ご [UNK] い た だ く か 、 または ( 自治体 の 担当 課 等 の 名称 ) まで お 問い合わせ ください 。 ( 自治体 HP 内 関連 ページ の UR L ) [UNK] お 問い合わせ ( 自治体 の 担当 課 等 の 名称 ) ( 電話 番号 )/( 開 庁 時間 )
#
# 児童 扶養 手当 ( ひとり 親 手当 ) 受給 者 が 市内 で 住所 が 変わっ た 時 の 手続き を 教え て ください 。
# 児童 扶養 手当 ( ひとり 親 手当 ) 受給 者 が 市内 で 転居 さ れ た 場合 は 、 ( 自治体 の 担当 課 等 の 名称 ) にて 住所 変更 の 手続き が 必要 です 。
#
# 児童 扶養 手当 ( ひとり 親 手当 ) 受給 者 が 市外 から 転出 する 際 の 手続き を 教え て ください 。
# 児童 扶養 手当 ( ひとり 親 手当 ) 受給 者 が 市外 へ 転出 する 場合 は 、 ( 自治体 の 担当 課 等 の 名称 ) にて 住所 変更 の 手続き が 必要 です 。
#
# 児童 扶養 手当 ( ひとり 親 手当 ) 受給 者 が 市外 から 転入 し た 際 の 手続き を 教え て ください 。
# 児童 扶養 手当 ( ひとり 親 手当 ) 受給 者 が 転入 さ れ た 場合 は 、 ( 自治体 の 担当 課 等 の 名称 ) にて 住所 変更 の 手続き が 必要 です 。
#
# ( 自治体 で 実施 さ れ て いる 病院 を 教え て ください 。
# ( 申請 方法 、 有効 期限 、 更新 等 の 手続き について 記載 し て ください 。 )
#
# 児童 扶養 手当 は 離婚 調停 中 でも 申請 でき ます か ?
# 離婚 調停 中 は 児童 扶養 手当 の 申請 は でき ませ ん 。 離婚 が 成立 し て から 申請 し て ください 。
#
# 児童 扶養 手当 が 認定 さ れる まで の 期間 は 。
# 児童 扶養 手当 は 、 必要 書類 が 揃っ て から 、 認定 まで 約 ○ か月 程 かかり ます 。
#
# 児童 扶養 手当 ( ひとり 親 手当 ) は 郵 送 で も 申請 でき ます か ?
# 児童 扶養 手当 ( ひとり 親 手当 ) の 申請 は 、 窓口 で の 面 談 が 必要 に なり ます 。 ( 自治体 の 担当 課 等 の 名称 ) まで お 越し ください 。
#
# ひとり 親 手当 は 子ども と 別 居 し て い て も 受け られ ます か ?
# ひとり 親 手当 は 子ども と 別 居 し て い て も 、 必要 書類 を 提出 すれ ば 受け られ ます 。 ただし 、 児童 扶養 手当 は 父子 の 別 居 監 護 について は でき かね ます 。
#
# 児童 扶養 手当 証書 を なくし た とき は ?
# 児童 扶養 手当 証書 を 失 くし た とき は 、 ( 自治体 の 担当 課 等 の 名称 ) にて 証書 亡 失 届 を 提出 し て ください 。 再 発行 の 手続き を い た し ます 。 < 入院 > < 食事 > < 療養 > 入院 時 の 食事 療養 費 の 自己 負担 分 ( 子ども の 医療 費 ) は 、 ○ ○ 市 へ 払い 戻し の 申請 を し て ください 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# 児童 扶養 手当 受給 者 で 子ども が 死亡 し た 場合 は ?
# 児童 扶養 手当 受給 者 で 子ども が 死亡 し た 場合 、 児童 扶養 手当 受給 資格 が 喪失 し ます 。 ( 自治体 の 担当 課 等 の 名称 ) にて 資格 喪失 届 を 提出 し て ください 。
#
# 児童 扶養 手当 の 現 [UNK] 届 の 時期 は ?
# 児童 扶養 手当 の 現 [UNK] 届 は 、 毎年 8 月 です 。 8 月 中 の 提出 が ない と 今後 の 手当 の 支給 が 遅れる こと が あり ます 。 また 必要 書類 によって は 、 提出 が 遅れる こと で 支給 額 が 減 額 さ れる こと が あり ます 。
#
# 児童 扶養 手当 の 現 [UNK] 届 を 出さ ない と どう なり ます か ?
# 児童 扶養 手当 の 現 [UNK] 届 の 提出 が ない 場合 、 現 [UNK] 届 が 提出 さ れる まで の 期間 、 手当 の 支給 が 停止 し ます 。 現 [UNK] 届 未 提出 者 は 、 未 提出 状況 が 2 年間 継続 する と 、 自動的 に 資格 喪失 と なり ます 。
#
# 再婚 ( 事実 婚 ) し たら 児童 扶養 手当 は どう なり ます か ?
# 再婚 ( 事実 婚 含む ) さ れ た 場合 、 児童 扶養 手当 の 受給 資格 は 喪失 し ます 。 ( 自治体 の 担当 課 等 の 名称 ) にて 速やか に 資格 喪失 届 を 提出 し て ください 。 申請 が 遅れる と 、 再婚 ( 事実 婚 ) 後 に も 手当 が 支給 さ れ て し まい ます 。 その 場合 は 支給 さ れ た 手当 を 返還 する 必要 が あり ます ので ご 注意 ください 。
#
# 児童 扶養 手当 額 は 収入 が 変化 し たら 変わり ます か ?
# 児童 扶養 手当 の 手当 額 は 、 1 年間 の 所得 額 に 応じ て 決定 し ます 。 毎年 8 月 の 現 [UNK] 届 提出 時 に 、 前年 の 所得 を 確認 し て その 年度 の 手当 額 を 決定 し ます 。
#
# 児童 扶養 手当 は 離婚 調停 中 でも 申請 でき ます か ?
# 離婚 調停 中 は 児童 扶養 手当 の 申請 は でき ませ ん 。 離婚 が 成立 し て から 申請 し て ください 。
#
# ひとり 親 手当 は 離婚 後 元 配偶 者 と 同居 し て い て も 受け られ ます か ?
# 元 配偶 者 と 同居 し て いる 場合 、 ひとり 親 手当 を 受ける こと は でき ませ ん 。
#
# ( 自治体 の 子育て 支援 センター 等 の 名称 ) の 利用 方法 を 教え て ください 。
# ( 自治体 の 子育て 支援 センター 等 の 名称 ) の 利用 は ( 利用 対象 者 ) が 対象 で 、 料金 は ( 利用 料 ) です 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# ( 自治体 の 子育て 支援 センター 等 の 名称 ) の 利用 日 や 利用 時間 について 教え て ください 。
# ( 自治体 の 子育て 支援 センター 等 の 名称 ) の 利用 時間 は ( 利用 可能 日時 を 記載 し て ください 。 例 「 月 火 木 土 の 9 : 30 ~ 16 : 30 と 水 9 : 00 ~ 12 : 00 」) です 。 ただし 、 ( 年末年始 等 の 休 館 日 を 記載 し て ください 。 例 「 日 ・ 祝日 及び 12 / 29 ~ 1 / 3 」) は お 休み です 。
#
# ( 自治体 の 子育て 支援 センター 等 の 名称 ) の 利用 に 予約 は 必要 です か 。
# ( 予約 の 必要 の 有無 について 記載 し て ください 。 )
#
# ( 子育て 支援 施設 において 実施 する 支援 事業 等 ) の 利用 方法 を 教え て ください 。
# ( 子育て 支援 施設 において 実施 する 支援 事業 等 ) の 利用 は ( 対象 者 を 記載 し て ください ) が 対象 で 、 料金 は ( 料金 を 記載 し て ください ) です 。
#
# ( 子育て 支援 施設 において 実施 する 支援 事業 等 ) の 利用 日 や 時間 について 教え て ください 。
# ( 子育て 支援 施設 において 実施 する 支援 事業 等 ) の 利用 は ( 利用 可能 日時 を 記載 し て ください ) です 。 ただし 日 ・ 祝日 及び 12 / 29 ~ 1 / 3 は お 休み です 。 施設 ごと の 休 館 日 も あり ます 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# ( 支所 ・ 出張所 、 市民 サービス センター 等 ) の 開設 時間 を 教え て ください 。
# ( 支所 ・ 出張所 、 市民 サービス センター 等 ) の 開設 時間 は 平日 ( 月曜日 ~ 金曜日 )○ 時 ~○ 時 土曜日 ○ 時 ~○ 時 (※) に なり ます 。 (※) × 時 ~ × 時 の 入口 は 限ら れ ます 。 取扱 業務 を 確認 の 上 ご 利用 ください 。 日曜日 、 祝 ・ 休日 、 年末年始 は 閉 設 し ます 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# 保育園 は 何 か所 まで 希望 でき ます か ?
# 認可 保育園 、 市立 幼 保 一元 化 施設 及び 小規模 保育 事業 は あわせ て 最大 ○ 園 まで 、 市立 保育 室 及び 居 宅 訪問 型 保育 事業 は 最大 あわせ て ○ 園 まで 希望 の 申し込み が でき ます 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# セク ハラ について 相談 する 場所 を 教え て ください 。
# セク ハラ 、 DV など の 相談 は ( 自治体 の 担当 課 や 女性 相談 センター 等 の 名称 ) で 受け付け て い ます 。 ( 事前 予約 の 必要 性 、 相談 方法 ( 面 談 、 電話 等 ) 等 の 説明 を 記載 し て ください 。 ) [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# ( スポーツ センター 等 において 実施 さ れる 子ども 向け スポーツ 教室 等 ) について 教え て ください 。
# ( スポーツ センター 等 において 実施 さ れる 子ども 向け スポーツ 教室 等 ) は 、 ( 対象 年齢 ) を 対象 と し た 子ども 向け ○ ○ 教室 です 。 ( 教室 等 の 内容 、 特徴 を 記載 し て ください 。 ) [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# 課税 証明 書 の 申請 について 教え て ください 。
# 住民 税 課税 ( 非 課 税 ) 証明 書 は 、 ( 申請 場所 ( 自治体 の 担当 課 、 支所 ・ 出張所 等 )) で 申請 でき ます 。 申請 に は 本人 確認 の ため の 身分 証明 書 が 必要 です 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# がん 検 診 について 教え て ください 。
# がん 検 診 に は 「 がん 一 次 検 診 」 と 「 新た な ステージ に 入っ た がん 検 診 の 総合 支援 事業 」 の 2 種類 が あり ます 。 対象 者 に は クー ポン 券 ・ 検 診 の お 知 ら せ など を 送付 し ます 。 40 歳 以上 の 対象 者 に は 複数 の クー ポン 券 が 届く こと が あり ます 。 [UNK] がん 一 次 検 診 ( 自治体 HP 内 関連 ページ の UR L ) [UNK] 新た な ステージ に 入っ た がん 検 診 の 総合 支援 事業 ( 自治体 HP 内 関連 ページ の UR L )
#
# 子宮 がん 検 診 について 教え て ください 。
# ...
# ヒト パ ピロ ーマ ウイルス は 皮膚 や 粘膜 に 感染 する ウイルス で 、 100 以上 の 種類 に 分類 さ れ て い ます 。 これら の うち 主 に 粘膜 に 感染 する 種類 は 、 性行為 を 介し て 生じる 表 皮 の 微 少 な キ ズ から 、 生殖 器 粘膜 に 侵入 し て 感染 する ウイルス で あり 、 海外 において は 性 活動 を 行う 女性 の 50 % 以上 が 、 生涯 で 一 度 は 感染 する と 推定 さ れ て い ます 。 ワクチン の 中 に は 、 いくつ か の 種類 の ヒト パ ピロ ーマ ウイルス ( HP V ) の ウイルス 成分 が 含ま れ て おり 、 予防 接種 を 受け た お 子 様 は 、 これら に対する 免疫 を 獲得 する こと が でき ます 。 体内 に 免疫 が できる と 、 HP V に かかる こと を 防ぐ こと が でき ます 。 ただし 、 予防 接種 により 、 軽い 副 反応 が み られる こと が あり ます 。 また 、 極めて 稀 です が 、 重い 副 反応 が おこ る こと が あり ます 。 予防 接種 後 に み られる 反応 等 、 詳しく は こちら を ご [UNK] ください 。 ( 自治体 HP 内 関連 ページ の UR L )
#
# 肺炎 球菌 定期 予防 接種 について 教え て ください 。
# 肺炎 球菌 予防 接種 は 、 平成 26 年 10 月 1 日 より 、 定期 予防 接種 に なり まし た 。 過去 に 肺炎 球菌 ワクチン を 接種 し た こと の ない 、 初めて 接種 する 人 が 対象 と なり ます 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# 学校 施設 の 開放 について 教え て ください 。
# 地域 の スポーツ 交流 、 コミュニケーション を 図る 場 として 、 学校 教育 に 支障 の ない 範囲 で 学校 施設 を 開放 し て い ます 。 使用 できる 施設 は 体育館 ・ 校 庭 、 会議 室 等 です 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# ○ ○ 市 の 公園 について 教え て ください 。
# ○ ○ 公園 に は ドッグ ラン が あり ます 。 ( 利用 方法 を 記載 し て ください 。 例 「 ご 利用 に は 公園 管理 センター で の 登録 が 必要 です 。 」 ) [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# 動物 の 死体 処理 について 教え て ください 。
# 飼っ て い た 動物 の 死体 が 処理 でき ない とき 、 または 公道 上 に 放置 さ れ て いる とき について は こちら を ご [UNK] ください 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# ○ ○ 市 清掃 事務所 の 場所 を 教え て ください 。
# ○ ○ 市 清掃 事務所 の 場所 について は こちら を ご 確認 ください 。 ( 自治体 HP 内 関連 ページ の UR L )
#
# ( 保育園 等 に 在籍 する 保護 者 向け 緊急 メール 等 ) について 教え て ください 。
# ( 保育園 等 に 在籍 する 保護 者 向け 緊急 メール 等 ) と は 、 ( システム の 説明 を 記載 ください 。 ) です 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# ( 保育園 等 に 在籍 する 保護 者 向け 緊急 メール 等 ) の 登録 方法 を 教え て ください 。
# ( 保育園 等 に 在籍 する 保護 者 向け 緊急 メール 等 の 登録 方法 を 記載 し て ください 。 )
#
# AD HD について 教え て ください 。
# AD HD は At te n t ion Def ic it Hy per act iv ity Dis ord er の 略 で 、 発達 段階 に 不 釣り 合い な 注意 力 や 衝動 性 、 多 動 性 を 特徴 と する 神経 発達 症 もしくは 行動 障害 です 。 お 子 さん の 成長 や 性格 、 生活 環境 や 事情 によって 解決 策 が 違い ます 。 まずは 保健 師 に ご 相談 ください 。 AAA 保健 相談 所 :( 電話 番号 )(○ 時 ○ 分 から ○ 時 ○ 分 ) BB B 保健 相談 所 :( 電話 番号 )(○ 時 ○ 分 から ○ 時 ○ 分 )
#
# ( 子育て 支援 センター 等 ) の 年末年始 の 開館 日 を 教え て ください 。
# ( 子育て 支援 センター 等 ) は 12 月 29 日 から 1 月 3 日 まで 休 館 と なり ます 。 新年 は 1 月 4 日 から の 開館 と なり ます 。
#
# 市役所 は いつ まで 開い て ます か ?
# ○ ○ 市役所 の 開 庁 時間 は ○ 時 ○ 分 から ○ 時 ○ 分 ( 土曜日 ・ 日曜日 、 祝 ・ 休日 および 12 月 29 日 ~ 1 月 3 日 を 除く ) です 。
#
# 子ども が 生まれ たら 、 どんな もの が あり ます か 。
# ( 自治体 の 発行 する 広報 誌 ) は 、 毎月 ○ 回 (○ 日 ・ ○ 日 ) 発行 し 、 市内 全 世帯 に 各 戸 配布 し て い ます 。 発行 日 を 過ぎ て も 届 か ない 場合 は 、 お 手 数 です が 、 ( 自治体 の 担当 課 等 ) へ 連絡 し て ください 。 [UNK] お 問い合わせ ( 自治体 の 担当 課 等 の 名称 ) ( 電話 番号 )/( 開 庁 時間 ) [UNK] その他 の 配布 場所 等 、 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# 子ども が 遊 べ る 公園 を 教え て ください 。
# ○ ○ 公園 が ( 地域 名 ) × 丁 目 に あり ます 。 ( 公園 の 特徴 等 を 記載 し て ください 。 ) [UNK] ○ ○ 公園 ( 自治体 HP 内 関連 ページ の UR L )
#
# Q R コード を 教え て ください 。
# ○ ○ 市 LINE 公式 アカウント の Q R コード は こちら に なり ます 。 ( Q R コード を 表示 する UR L )
#
# 野 良 犬 について どこ に 相談 すれ ば いい です か ?
# 野 良 犬 の 相談 は こちら に ご 相談 ください 。 ( 自治体 ・ 保健 所 等 の HP 内 関連 ページ の UR L )
#
# い の し し について どこ に 相談 すれ ば いい です か ?
# い の し し の 相談 は こちら に ご 相談 ください 。 ( 自治体 ・ 保健 所 等 の HP 内 関連 ページ の UR L )
#
# ( 高齢 者 向け 生活 支援 の 担い 手 養成 研修 ) について 教え て ください 。
# ( 高齢 者 向け 生活 支援 の 担い 手 養成 研修 を 行っ て いる 場合 、 説明 を 記載 し て ください 。 ) [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# ○ ○ 市 の 公園 について 教え て ください 。
# ○ ○ 市 に は 、 ○ か 所 の 市立 公園 が 存在 し ます 。 ( 設備 面 等 で 特徴 的 な 公園 について は 、 説明 を 追加 し て ください 。 ) [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# ( ペット を 飼 う にあたって 役 に 立つ 情報 を まとめ た リーフ レット 等 ) について 教え て ください 。
# ( ペット を 飼 う にあたって 役 に 立つ 情報 を まとめ た リーフ レット 等 を 作成 し て いる 場合 は 、 記載 し て ください 。 ) 例 「 ペット 便利 帳 で は 飼い 主 が 守る 大事 な ルール や 市 の 協力 獣 医師 施設 の 紹介 を し て い ます 。 市役所 2 階 ○ ○ 課 、 市民 サービス センター で 配布 し て い ます 。 [UNK] こちら から ダウンロード も でき ます ( 自治体 HP 内 関連 ページ の UR L )」
#
# 妊 婦 の 食事 について 教え て ください 。
# 妊 婦 が 望ましい 食 生活 を 実践 する ため に 、 1 日 に 何 を どれ だけ 食べ たら よい か について 厚生 労働省 から 指針 が 公表 さ れ て い ます 。 詳しく は こちら を ご [UNK] ください 。 [UNK] 妊 産 婦 の ため の 食 生活 指針 ( 厚生 労働省 )【 PD F 】 http :// www . m h l w . go . jp / h oud ou / 2006 / 02 / d l / h 02 01 - 3 b 01 . p d f http :// www . m h l w . go . jp / h oud ou / 2006 / 02 / d l / h 02 01 - 3 b 02 . p d f
#
# 乳 腺 炎 に なっ たら どこ の 病院 に 行け ば いい です か ?
# 診療 について は 、 ( 都道府県 や 医師 会 が 提供 する 医療 機関 案内 等 ) にて 病院 を 探す こと が でき ます 。 [UNK] 詳しく は こちら ( 当該 医療 機関 案内 等 の UR L )
#
# ○ ○ 市 の 未来 像 について 教え て ください 。
# ( 目指し て いる 未来 像 や 掲げ て いる スローガン 等 について の 説明 を 記載 し て ください 。 ) [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# 登録 内容 の 修正 方法 を 教え て ください 。
# ( チャット ボット の 使用 にあたり アカウント に 情報 を 登録 する 場合 、 修正 方法 を 記載 し て ください 。 ) 例 「 本 アカウント に 登録 さ れ た お 住 い の 地域 や お 子 さま の 人数 等 、 登録 情報 を 変更 する 場合 は アンケート の 再 入力 が 必要 です 。 メニュー の 「 登録 内容 の 修正 」 を タップ し て 再度 アンケート に ご 回答 ください 。 」
#
# 近く の 病院 を 教え て ください 。
# ( 都道府県 や 医師 会 が 提供 する 医療 機関 案内 等 の 名称 ) で 、 県内 の 医療 機関 の 場所 や 診療 の 内容 など の 情報 を 提供 し て い ます 。 [UNK] 詳しく は こちら ( 当該 医療 機関 案内 等 の UR L )
#
# 放課後 クラブ の 利用 方法 について 教え て ください 。
# ( 利用 方法 を 記載 し て ください 。 ) 例 「 放課後 クラブ を 利用 する に は 毎年 度 、 事前 に 会員 登録 が 必要 です 。 登録 申請 は 、 随時 各 放課後 クラブ 室 で 受付 け て い ます 。 毎月 20 日 ( 3 月 を 除く ) まで に 登録 申請 を し て い た だ く と 、 翌月 から 利用 可能 と なり ます 。 また 、 必ず スポーツ 安全 保険 に 加入 し て い た だ き ます 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )」
#
# ( 犯罪 等 の 発生 お 知 ら せ サービス 等 ) について 教え て ください 。
# ( 犯罪 等 の 発生 お 知 ら せ サービス 等 の 説明 を 記載 し て ください 。 ) 例 「 「 ○ ○ 市 安全 ・ 安心 メール 」 は 、 市内 で 発生 し た 犯罪 や 安全 ・ 安心 に関する 情報 、 および 市内 外 の 災害 情報 や 各種 防災 情報 を 、 携帯 電話 、 スマート フォン または パソコン に メール で 配信 する サービス です 。 配信 を 希望 する 情報 、 受信 する 時間 を 任意 に 設定 する こと が でき ます 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )」
#
# ○ ○ 市 の 地図 は あり ます か ?
# ○ ○ 市 の 案内 図 について は こちら を ご [UNK] ください 。 ( 自治体 HP 内 関連 ページ の UR L )
#
# どんな 質問 が でき ます か ?
# ( 回答 可能 な 分野 ・ 範囲 を 記載 し て ください 。 ) 例 「 今 は 子育て 分野 が 中心 です が 、 話し か け て い た だ けれ ば 、 できるだけ お 答 え し たい と 思っ て い ます 。 今 は 答え ら え ない ご 質問 も 、 学習 し て 答え られる よう に なり ます ので 、 たくさん 話し か け て ください ね ♪」
#
# 保育園 は 何 時 から 預け られ ます か ?
# ( 預け られる 時間 を 記載 し て ください 。 ) 例 「 お 子 さん の 保育 時間 は 、 各 保育園 の 開園 時間 内 で 、 家庭 の 状況 等 を 考慮 し ながら 、 保護 者 と 相談 の 上 で 園 が 決定 し ます 。 支給 認定 証 の 保育 必要 量 ( 保育 標準 時間 ・ 保育 短時間 ) の 範囲 内 で 必要 最低限 の 時間 と なり ます 。 開園 時間 について は 保育園 によって 異なり ます ので 、 各 園 の 開園 時間 を ご 確認 ください 。 」
#
# 転入 し た 後 の 手続き について 教え て ください 。
# ○ ○ 市 に 転入 する とき に 必要 な 手続き や 届出 について は こちら を ご [UNK] ください 。 ( 自治体 HP 内 関連 ページ の UR L )
#
# インフルエンザ と お た ふく かぜ の 予防 接種 記録 票 が 送ら れ て き ませ ん 。
# インフルエンザ と お た ふく かぜ の 予防 接種 記録 票 は 、 ○ ○ 市 から は お 送り し ませ ん 。 希望 する 市内 指定 医療 機関 に 、 直接 ご 予約 ください 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# ( 観光 名所 等 ) について 教え て ください 。
# ( 観光 名所 等 の 説明 を 記載 し て ください 。 ) 例 「 渋谷 駅 ハチ 公 口 に は ハチ 公 の 銅像 が 飾ら れ て い ます 。 ハチ 公 は 大正 時代 、 飼い 主 が 亡くなっ た の を 知ら ず 、 毎日 渋谷 駅前 で 帰り を 待っ て い た そう です 。 」
#
# 自転車 に は 何 人 まで 子ども を 乗せ られ ます か ?
# 自転車 の 乗車 人員 は ( 都道府県 の 定める 道路 交通 規則 ) にて 制限 さ れ て い ます 。 ( 所在 する 都道府県 の 道路 交通 規則 の 内容 を 記載 し て ください 。 ) 東京 都 の 例 「 原則 二 人 乗り は 禁止 です が 、 運転 者 が 16 歳 以上 で あっ て 、 幼児 用 の 座席 を 取り付け た 自転車 に 6 歳 未満 の 幼児 を 乗せる 場合 や 、 運転 者 が 16 歳 以上 で あっ て 、 幼児 二 人 同 乗 用 自転車 として 認め られ た 自転車 に 6 歳 未満 の 幼児 を 1 〜 2 人 乗せる 場合 等 は 、 それぞれ 2 人 、 3 人 乗り が 許容 さ れ て い ます 。 」 )
#
# 子ども が 生まれ たら 、 どの よう な 手当 が あり ます か 。
# 子ども の 手当 について は こちら を ご [UNK] ください 。 ( 自治体 HP 内 関連 ページ の UR L ) < よう > 子ども の 手当 ・ 助成 として は 、 児童 手当 と 子ども 医療 費 助成 制度 が あり ます 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L ) [UNK] お 問い合わせ ( 自治体 の 担当 課 等 の 名称 ) ( 電話 番号 )/( 開 庁 時間 )
#
# 転 園 届 の 提出 場所 を 教え て ください 。
# ( 転 園 届 の 提出 について 記載 し て ください 。 ) 例 「 保育園 の 転 園 届 は ○ ○ 課 へ 届出 の 手続き を し て ください 。 郵 送 や 保育園 等 で の 受付 は し て い ませ ん 。 」
#
# 水道 管 が 凍結 し たら どう すれ ば いい です か ?
# 水道 管 の 凍結 ・ 断 水 に ご 注意 ください 。 [UNK] 詳しく は ( 自治体 の 水道 局 等 ) ホームページ を ご [UNK] ください 。 ( 自治体 の 水道 局 等 の HP 内 関連 ページ の UR L 等 )
#
# 固定 資産 税 の 納税 証明 書 は どこ で 取れ ます か ?
# ○ ○ 市 で は 、 ( 申請 場所 ( 自治体 の 担当 課 、 支所 ・ 出張所 等 )) で 申請 でき ます 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# パスポート の 申請 窓口 を 教え て ください 。
# パスポート の 窓口 について は こちら を ご [UNK] ください 。 ( 自治体 HP 内 関連 ページ の UR L ) ( この ほか 、 都道府県 パスポート センター の UR L ・ 電話 番号 等 を 記載 する こと も 考え られ ます 。 )
#
# 大人 の 女性 の 検 診 に は 何 が あり ます か ?
# 健康 診 査 は 、 年齢 や 、 加入 し て いる 医療 保険 によって 、 利用 できる 制度 が 異なり ます 。 ( 自治体 において 実施 し て いる 健 診 内容 を 記載 し て ください 。 ) 例 「 ○ ○ 市 で は 、 39 歳 以下 の 方 の 国 保 無料 健康 診 査 、 40 歳 以上 の 方 の 特定 健 診 、 各種 の がん 検 診 等 を 実施 し て い ます 。 がん 検 診 で は 、 20 歳 以上 の 女性 は 子宮 頸 がん 検 診 、 40 歳 以上 の 女性 は 乳 がん 検 診 を 受ける こと が でき ます 。 [UNK] 各種 健 診 一覧 ( 自治体 HP 内 関連 ページ の UR L ) [UNK] がん 一 次 検 診 ( 自治体 HP 内 関連 ページ の UR L ) [UNK] 妊 産 婦 の 健 診 ・ 相談 ( 自治体 HP 内 関連 ページ の UR L )」
#
# 延長 保育 を やっ て いる ところ を 教え て ください 。
# ○ ○ 市 で 延長 保育 を 実施 し て いる 保育園 について は こちら を ご [UNK] ください 。 ( 自治体 HP 内 関連 ページ の UR L )
#
# 児童 手当 が もらえる 月 を 教え て ください
# 児童 手当 は 、 認定 請求 を し た 月 の 翌月 分 から 支給 を 開始 し 、 原則 として 、 毎年 2 ・ 6 ・ 10 月 に それぞれ 前 月 分 まで が 支払わ れ ます 。
#
# 児童 手当 が もらえる 月 を 教え て ください
# 児童 手当 は 、 認定 請求 を し た 月 の 翌月 分 から 支給 を 開始 し 、 原則 として 、 毎年 2 ・ 6 ・ 10 月 に それぞれ 前 月 分 まで が 支払わ れ ます 。
#
# マイ ナン バー カード の 申請 方法 を 教え て ください 。
# マイ ナン バー カード の 申請 方法 について は こちら を ご 確認 ください 。 ( 自治体 HP 内 関連 ページ の UR L ) 現在 、 ○ ○ 市 で は 申請 い た だ い て から 交付 通知 書 を 送付 する まで に 、 約 ○ ヵ月 程度 の 期間 を 要する 見込み です 。
#
# 国民 健康 保険 の 手続き に 必要 な 書類 を 教え て ください 。
# 国民 健康 保険 の 手続 ・ 届出 に 必要 な 書類 は 届出 の 内容 によって 異なり ます 。 詳しく は こちら を ご [UNK] ください 。 ( 自治体 HP 内 関連 ページ の UR L )
#
# 確定 申告 書 の 作成 会場 について 教え て ください 。
# 確定 申告 について は こちら を ご [UNK] ください 。 ( 自治体 HP 内 関連 ページ の UR L )
#
# 子育て は どこ に 相談 すれ ば いい です か ?
# ( 自治体 の 担当 課 や 子育て センター 等 ) で は 育児 全般 の 相談 を 実施 し て い ます 。 また 、 ( 自治体 の 担当 課 や 子育て センター 等 ) で は 子ども の 発達 や 育児 について 、 不安 や 悩み など の 相談 に 応じ て い ます 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# 生活 困窮 について どこ に 相談 すれ ば いい です か ?
# 病気 や け が など で 生活 に 困っ て いる 人 や 、 収入 が 少なく て 生活 に 困っ て いる 人 など 、 暮らし について 心配 ごと が ある 人 は ( 自治体 の 担当 課 等 ) に ご 相談 ください 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# 子ども の 発 育 に 不安 が ある の です が 、 どう すれ ば いい です か ?
# ( 子ども の 発達 について 相談 できる 場所 について 記載 し て ください 。 ) 例 「 子ども 発達 相談 センター で は 、 お 子 さん の 発達 や 育児 の 不安 、 悩み の 相談 に 応じ て い ます 。 まずは 気 軽 に 電話 で ご 相談 ください 。 [UNK] お 問い合わせ ( 自治体 の 担当 課 等 の 名称 ) ( 電話 番号 )/( 開 庁 時間 ) 詳しく は こちら を ご [UNK] ください 。 ( 自治体 HP 内 関連 ページ の UR L )
#
# 放課後 等 デイ サービス について 教え て ください 。
# 放課後 等 デイ サービス と は 、 学校 通学 中 の 児童 に 、 生活 能力 向上 の ため の 訓練 等 を 提供 し 自立 を 促進 する とともに 、 放課後 等 の 居場所 づくり を 推進 する 事業 です 。 ( 実施 場所 ・ 実施 団体 等 ) において 実施 さ れ て い ます 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# 学習 障害 の 相談 は どこ で でき ます か ?
# 子供 に かかわる 様々 な 悩み など について 電子 メール により 、 ○ ○ 市内 の 児童 ・ 生徒 または その 保護 者 を 対象 に 相談 を 受け付け て い ます 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# 1 歳 6 か月 児 健 診 について 教え て ください 。
# 1 歳 6 か月 児 健 診 は 母子 保健 法 に 定め られ た 子ども の 定期 健 診 の 一つ です 。 子ども の 発達 の 状況 を 確認 する とともに 、 歯 の 健 診 も 行い ます 。 対象 の 方 に は 1 歳 ○ か月 に 達する 月 の ( 上旬 / 中旬 / 下旬 ) に 通知 さ れ ます 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# 認可 外 保育 施設 について 教え て ください 。
# 認可 外 保育 施設 と は 認可 を 受け ず に 運営 する 保育 施設 の こと です 。 市 が 設置 し 、 民間 事業 者 に 運営 を 委託 し て いる 認可 外 保育 施設 に 市立 保育 室 が あり ます 。 市立 保育 室 は 市立 ・ 私立 保育園 に 申し込み を 行ない 、 待機 児童 と なっ た 人 のみ を 対象 と し て い ます 。 [UNK] 市立 保育 室 ( 自治体 HP 内 関連 ページ の UR L ) その他 の 認可 外 保育 施設 の 一覧 について は こちら を ご [UNK] ください 。 [UNK] 認可 外 保育 施設 一覧 表 ( 自治体 HP 内 関連 ページ の UR L )
#
# 戸籍 [UNK] の 請求 方法 を 教え て ください 。
# ○ ○ 市 に 本 籍 が ある 人 は 、 窓口 で 交付 を 受ける こと が でき ます 。 必要 な もの 等 、 詳しく は こちら を ご [UNK] ください 。 ( 自治体 HP 内 関連 ページ の UR L )
#
# 子ども の 歯科 健 診 ( 1 歳 6 か月 健 診 ) について 教え て ください 。
# 1 歳 6 か月 を 迎える と 奥 歯 も そろ そ ろ 生え て き ます 。 歯 の トラブル 予防 に 重要 な この 時期 に 歯科 健 診 を し て 歯 医 者 さん の チェック を 行い ます 。 対象 の 方 に は 1 歳 ○ か月 に 達する 月 の ( 上旬 / 中旬 / 下旬 ) に 通知 さ れ ます 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# 精神 保健 相談 について 教え て ください 。
# 「 精神 保健 相談 」 と は 、 指定 の 日 に 、 専門 医 が 精神 障害 の 人 や その 家族 の 相談 に 応じる もの です 。 ( 事前 予約 の 有無 等 、 精神 保健 相談 の 説明 を 適 宜 記載 し て ください ) ひとり で 悩 ま ず 、 気 軽 に 相談 し て ください 。 [UNK] 相談 日 の 日程 等 、 詳しく は こちら を ご 確認 ください ( 自治体 HP 内 関連 ページ の UR L )
#
# 子ども の 身体 測定 は 行っ て い ます か ?
# ( 身体 測定 の 実施 施設 ) で は 指定 の 日 に 身体 測定 を 行っ て い ます 。 詳しく は ( 身体 測定 の 実施 施設 ) の 催し 物 一覧 を ご 確認 ください 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# 子ども が 相談 できる ところ は あり ます か ?
# ( 自治体 の 担当 課 や 子育て センター 等 ) で は 、 18 歳 未満 の 子ども と その 家庭 に関する 相談 を 行なっ て い ます 。 困っ て いる こと 、 悩ん で いる こと 、 どんな こと でも 気 軽 に 相談 し て ください 。 相談 内容 に 合っ た 、 他 の 専門 機関 と 一緒 に 考え ます 。 [UNK] 相談 専用 電話 ( 電話 番号 )
#
# ○ 年 ○ 月 入 園 の 保育園 の 募集 人数 を 教え て ください 。
# ○ 年 ○ 月 入 園 の 各 園 の 募集 人数 は こちら を ご [UNK] ください 。 ( 自治体 HP 内 関連 ページ の UR L ) 空き 状況 について は こちら を ご 確認 ください 。 ( 自治体 HP 内 関連 ページ の UR L )
#
# ヒ ブ ワ クチン について 教え て ください 。
# ヒ ブ ワ クチン は 、 インフルエンザ 菌 b 型 ( Hi b ) による 感染 症 の 予防 ワクチン です 。 ヒ ブ は 、 髄 膜 炎 、 敗 血 症 、 肺炎 など 、 乳 幼 児 の 重 篤 な 感染 症 を 引き起こす 病原 最近 です 。 特に 、 細菌 性 髄 膜 炎 は 、 原因 の 半分 以上 が ヒ ブ と いわ れ て い ます 。 細菌 性 髄 膜 炎 は 初期 症状 が 風邪 に 似 て いる ため 早期 発見 が 難しく 、 治療 を し て も まれ に 死亡 し たり 、 後遺 症 が 残っ たり する こと が ある ので 、 ワクチン による 予防 が 非常 に 大切 です 。 予防 接種 は 生後 2 月 から 生後 60 月 に 至る まで の 間 に ある お 子 さん が 対象 と なり ます 。 ( 5 歳 の 誕生 日 の 前日 まで 接種 でき ます ) [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# 近隣 の 問題 について どこ に 相談 すれ ば いい です か ?
# 騒音 ・ 振動 ・ 悪 臭 など 生活 環境 に関する の 問題 は 近隣 の 方 どう し で の 解決 が 一番 です が 、 どうしても 我慢 の でき ない 場合 は こちら に 相談 し て ください 。 ( 自治体 HP 内 関連 ページ の UR L )
#
# ( 子育て 支援 施設 において 実施 する 支援 事業 等 ) の 場所 を 教え て ください 。
# ( 子育て 支援 施設 において 実施 する 支援 事業 等 ) は 、 ( 実施 場所 ) 等 で 実施 し て い ます 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# 小児 慢性 特定 疾病 の 医療 費 助成 制度 について 教え て ください 。
# 小児 慢性 特定 疾病 医療 費 助成 制度 と は 、 小児 慢性 特定 疾病 に かかっ て いる 児童 等 について 、 健全 育成 の 観点 から 、 患 児 家庭 の 医療 費 の 負担 軽減 を 図る ため 、 その 医療 費 の 自己 負担 分 の 一部 を 助成 する 制度 です 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# 小児 慢性 特定 疾病 の 対象 疾病 について 教え て ください 。
# 小児 慢性 特定 疾病 医療 費 助成 制度 における 対象 疾病 は 以下 の ページ に 掲載 さ れ て い ます 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# 復 職 に関する 申 立 書 について 教え て ください 。
# ( 復 職 に関する 申 立 書 について 記載 し て ください 。 ) 例 「 保護 者 が 育児 休業 を 取得 し て いる 期間 は 、 お 子 さん を 保育園 で お 預かり する こと は でき ませ ん が 、 入 園 し た 月 ( 1 月 入 園 のみ 3 月 まで ) に 復 職 する こと を 条件 に 申し込み でき ます 。 その 際 、 就 労 証明 書 の 他 に 、 ○ ○ 市 指定 の 「 復 職 に関する 申 立 書 」 ( 保護 者 の 申 立て ) を 提出 し 、 入 園 後 に 「 復 職 証明 書 」 ( 勤務 先 の 証明 ) を 提出 する こと が 必要 です 。 復 職 に関する 申 立 書 は 以下 から ダウンロード が でき ます 。 ( 自治体 HP 内 関連 ページ の UR L )」
#
# たばこ の 問題 について 教え て ください 。
# ( たばこ の 問題 へ の 取り組み 等 の 説明 を 記載 し て ください 。 ) 例 「 ○ ○ 市 で は 、 「 歩行 喫煙 は し ない 」 「 たばこ は 決め られ た 場所 で 吸 う 」 という ルール を 平成 ○ 年 に 定め 、 喫煙 者 の モラ ル と マナー の 向上 を 図っ て い ます 。 「 歩行 喫煙 禁止 」 の 路面 表示 や 看板 、 [UNK] 旗 の 設置 、 美 化 活動 の 強化 など を通じて 、 歩き たばこ や ポ イ 捨て を し ない 環境 づくり を 推進 し 、 「 非 喫煙 者 、 喫煙 者 の 誰 も が 快適 に 過 ご せる 環境 整備 」 を 目指し て い ます 。 」
#
# ○ ○ 年度 の 住民 税 の 申告 について 教え て ください
# ○ ○ 年度 の 住民 税 の 申告 について は こちら を ご [UNK] ください 。 ( 自治体 HP 内 関連 ページ の UR L )
#
# ( 市民 体育 大会 等 ) について 教え て ください 。
# ( 市民 体育 大会 等 ) と は 、 ( 市民 体育 大会 等 の 説明 を 記載 し て ください )。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# 住民 票 の 受け取り の 予約 は でき ます か ?
# ( 電話 による 証明 書 予約 サービス が ある 場合 ) 本人 請求 の 住民 票 の 写し について は 、 窓口 が 開い て いる 時間 に 来 所 でき ない 人 も 、 電話 で の 申 込 で 休日 や 平日 の 時間 外 に 受け取る こと が でき ます 。 [UNK] 詳しく は こちら ( 自治体 HP 内 関連 ページ の UR L )
#
# ( 保育 担当 課 ) の 場所 を 教え て ください 。
# ( 保育 担当 課 ) は ○ ○ 市役所 本庁 舎 の × 階 に あり ます 。 [UNK] 庁舎 案内 図 ( 自治体 HP 内 関連 ページ の UR L )
#
# 保育 の し おり が ほしい です 。
# ( 該当 する もの が あれ ば 記載 し て ください 。 ) 例 「 保育 の し おり と は 各 保育園 で 作成 し 、 入 園 時 等 に 配布 し て いる 園 の ルール 等 を 記載 し た もの です 。 通っ て いる 保育園 で 入手 でき ます ので 、 各 保育園 に お 問い合わせ ください 。 」
#
# 避難 所 は どこ です か ?
# ○ ○ 市 の 避難 所 施設 は 市立 小中学校 など ○ か 所 が 指定 さ れ て い ます 。 詳しく は こちら を ご [UNK] ください 。 [UNK] 避難 所 施設 一覧 ( 自治体 HP 内 関連 ページ の UR L )
#
# 一時 集合 場所 は どこ です か ?
# ※ ※ 一時 集合 所 を 採用 し て いる 自治体 ( 都 区 、 大阪 市 ) のみ ※ ※ ○ ○ 区 の 一時 ( いっ と き ) 集合 場所 は 区立 学校 の 校 庭 や 区立 公園 など が あて られ て い ます 。 ここ で 災害 の 状況 を 見 極 め ます 。 また 、 避難 場所 へ 避難 する ため に 集合 し ます 。 避難 場所 に 近い とき は 、 直接 避難 場所 へ 集合 し ます 。 詳しく は こちら を ご [UNK] ください 。 [UNK] 一時 ( いっ と き ) 集合 場所 一覧 ( 自治体 HP 内 関連 ページ の UR L )
#
# 避難 場所 は どこ です か ?
# ○ ○ 市 の 避難 場所 は ○ ○ 公園 など ○ か 所 が あて られ て い ます 。 詳しく は こちら を ご [UNK] ください 。 [UNK] 避難 場所 一覧 ( 自治体 HP 内 関連 ページ の UR L )
#
# 防災 地図 が 見 たい 。
# ○ ○ 市 の 防災 地図 について は こちら を ご [UNK] ください 。 ( 自治体 HP 内 関連 ページ の UR L )
#
# 帰宅 困難 者 の 避難 施設 は どこ です か ?
# 帰宅 困難 者 の ため の 支援 ( 受 入 ) 施設 について は こちら を ご [UNK] ください 。 ( 自治体 HP 内 関連 ページ の UR L )
#
# 住民 税 の 納税 証明 書 を 取り たい 。
# 住民 税 の 納税 証明 書 は 、 ( 申請 場所 ( 自治体 の 担当 課 、 支所 ・ 出張所 等 )) で 発行 し て い ます 。 申請 方法 等 、 詳しく は こちら を ご [UNK] ください 。 ( 自治体 HP 内 関連 ページ の UR L )
#
# 軽自動車 税 の 納税 証明 書 を 取り たい 。
# 軽自動車 税 の 納税 証明 書 は 、 ( 申請 場所 ( 自治体 の 担当 課 、 支所 ・ 出張所 等 )) で 発行 し て い ます 。 申請 方法 等 、 詳しく は こちら を ご [UNK] ください 。 ( 自治体 HP 内 関連 ページ の UR L )
#
# 住民 税 の 計算 方法 を 教え て ください 。
# 住民 税 の 算出 方法 について は こちら を ご [UNK] ください 。 ( 自治体 HP 内 関連 ページ の UR L )

# %%
ret = evaluate(dataset, predictions)
bleu = eval_qg(res_dict, qg_results)
# Out:
# Unanswered question 139 will receive score 0.
# Unanswered question 177 will receive score 0.

# %%
ret
# Out:
# {'exact_match': 71.26050420168067, 'f1': 86.27622391107421}

# %%
bleu*100
# Out:
# 91.56965195959954

# %% [markdown]
# ## テキストファイルからドキュメントを作る

# %%
all_text = open('../data/kosodate/document_v2.txt', 'r', encoding='utf-8').read()

# %%
# 大区分
text_group = all_text.split('\n\n')

# %%
len(text_group)
# Out:
# 174

# %%
for i in range(10):
    print(text_group[i])
    print('----------')
# Out:
# 赤ちゃんの成長や性格、生活環境や事情によって解決策が違います。保健師にご相談ください。お話を伺って一緒に考えましょう。
# AAA保健相談所：（電話番号）（○時○分から○時○分）
# BBB保健相談所：（電話番号）（○時○分から○時○分）
# ----------
# （自治体の発行する広報誌）は、毎月○回（○日・○日）発行し、市内全世帯に各戸配布しています。
# 発行日を過ぎても届かない場合は、お手数ですが、（自治体の担当課等）へ連絡してください。
# ◆お問い合わせ
# （自治体の担当課等の名称）
# （電話番号）／（開庁時間）
# ▼その他の配布場所等、詳しくはこちら
# （自治体HP内関連ページのURL）
# ----------
# <10か月>
# 受診票を再発行します。
# （自治体の担当課や子育てセンター等の名称）へお問い合わせください。
# ◆お問い合わせ
# （自治体の担当課や子育てセンター等の名称）
# （電話番号）／（開庁時間）
# ----------
# <1歳>
# 	<6か月>
# 	1歳6か月児健診は母子保健法に定められた子どもの定期健診の一つです。子どもの発達の状況を確認するとともに、歯の健診も行います。対象の方には1歳○か月に達する月の（上旬／中旬／下旬）に通知されます。
# 	▼詳しくはこちら
# 	（自治体HP内関連ページのURL）
# 	<保健所>
# 	1歳児健診は保健所では実施していません。
# 	○○市では、3・4か月健診、1歳6か月歯科健診、3歳児健診を無料で行っています。
# 	また、6・7か月健診、9・10か月健診、1歳6か月健診については、受診票を郵送しています。
# 	●●県内（1歳6か月健診は○○市内のみ）の契約医療機関に受診票をお持ちください。
# 	契約医療機関についてはこちらをご覧ください。
# 	（自治体HP内関連ページのURL）
# ----------
# <3歳>
# 3歳児健診で尿が取れない場合でも、健診後、4歳になる前日までに健診受付時間内に、尿をお持ちいただければ追加で検査できます。
# お子さんの成長に合わせてお持ちください。
# また、健診の朝の尿が難しい場合は、健診会場でお取りいただくこともできます。
# 3歳児健診は子どもの3歳の誕生月に通知されますので、指定の保健相談所にて受診してください。
# ▼詳しくはこちら
# （自治体HP内関連ページのURL）
# 健診の日時や場所はお住まいの地域により異なります。
# 次の健診の日時等は電話でお問い合わせください。
# ◆お問い合わせ
# （自治体の担当課等の名称）
# （電話番号）／（開庁時間）
# ----------
# <5才>
# 	<息子>
# 		<最近>
# 		ご心配ですね。赤ちゃんの成長や性格、生活環境や事情によって解決策が違います。まずは保健師にご相談ください。
# 		AAA保健相談所：（電話番号）（○時○分から○時○分）
# 		BBB保健相談所：（電話番号）（○時○分から○時○分）
# ----------
# <7か月>
# 受診票を再発行します。
# （自治体の担当課や子育てセンター等の名称）へお問い合わせください。
# ◆お問い合わせ
# （自治体の担当課や子育てセンター等の名称）
# （電話番号）／（開庁時間）
# ----------
# <ADHD>
# ADHDはAttention Deficit Hyperactivity Disorderの略で、発達段階に不釣り合いな注意力や衝動性、多動性を特徴とする神経発達症もしくは行動障害です。
# お子さんの成長や性格、生活環境や事情によって解決策が違います。まずは保健師にご相談ください。
# AAA保健相談所：（電話番号）（○時○分から○時○分）
# BBB保健相談所：（電話番号）（○時○分から○時○分）
# ----------
# <BCG>
# BCGとは結核を予防するワクチンの通称です。生後5か月から7か月（生後1歳に至るまで）の間に接種することとなっています。
# ▼詳しくはこちら
# （自治体HP内関連ページのURL）
# ----------
# <LGBT>
# LGBTとはセクシャル・マイノリティ、性的少数者を表す総称です。
# L（レズビアン）は同性を好きになる女性
# G（ゲイ）は同性を好きになる男性
# B（バイセクシュアル）は性別にかかわらず恋愛対象になる人
# T（トランスジェンダー）は身体的な性別と自認する性が一致しない（性別違和）人。性同一性障害の人が含まれます。
# 性分化疾患（DSD）などもあり、実はからだの性も単純には二分できません。
# SOGI（ソギ）と略される場合が増えています。
# SO＝Sexual Orientation（性的指向）
# GI＝Gender Identity（性自認）
# ----------

# %%
text_group_tokens = [tokenizer.tokenize(t) for t in text_group]

# %%
for i in range(10):
    print(text_group_tokens[i])
    print('----------')
# Out:
# ['赤ちゃん', 'の', '成長', 'や', '性格', '、', '生活', '環境', 'や', '事情', 'によって', '解決', '策', 'が', '違い', 'ます', '。', '保健', '師', 'に', 'ご', '相談', 'ください', '。', 'お', '##話', 'を', '伺', '##っ', 'て', '一緒', 'に', '考え', 'ましょ', 'う', '。', 'AAA', '保健', '相談', '所', ':', '##(', '電話', '番号', ')(', '##○', '時', '○', '分', 'から', '○', '時', '○', '分', ')', 'BB', '##B', '保健', '相談', '所', ':', '##(', '電話', '番号', ')(', '##○', '時', '○', '分', 'から', '○', '時', '○', '分', ')']
# ----------
# ['(', '自治体', 'の', '発行', 'する', '広報', '誌', ')', 'は', '、', '毎月', '○', '回', '(', '##○', '日', '・', '○', '日', ')', '発行', 'し', '、', '市内', '全', '世帯', 'に', '各', '##戸', '配布', 'し', 'て', 'い', 'ます', '。', '発行', '日', 'を', '過ぎ', 'て', 'も', '届か', 'ない', '場合', 'は', '、', 'お', '##手', '##数', 'です', 'が', '、', '(', '自治体', 'の', '担当', '課', '等', ')', 'へ', '連絡', 'し', 'て', 'ください', '。', '[UNK]', 'お', '問い合わせ', '(', '自治体', 'の', '担当', '課', '等', 'の', '名称', ')', '(', '電話', '番号', ')/', '##(', '開', '庁', '時間', ')', '[UNK]', 'その他', 'の', '配布', '場所', '等', '、', '詳しく', 'は', 'こちら', '(', '自治体', 'HP', '内', '関連', 'ページ', 'の', 'UR', '##L', ')']
# ----------
# ['<', '10', 'か月', '>', '受', '##診', '票', 'を', '再', '発行', 'し', 'ます', '。', '(', '自治体', 'の', '担当', '課', 'や', '子育て', 'センター', '等', 'の', '名称', ')', 'へ', 'お', '問い合わせ', 'ください', '。', '[UNK]', 'お', '問い合わせ', '(', '自治体', 'の', '担当', '課', 'や', '子育て', 'センター', '等', 'の', '名称', ')', '(', '電話', '番号', ')/', '##(', '開', '庁', '時間', ')']
# ----------
# ['<', '1', '歳', '>', '<', '6', 'か月', '>', '1', '歳', '6', 'か月', '児', '健', '診', 'は', '母子', '保健', '法', 'に', '定め', 'られ', 'た', '子ども', 'の', '定期', '健', '診', 'の', '一つ', 'です', '。', '子ども', 'の', '発達', 'の', '状況', 'を', '確認', 'する', 'とともに', '、', '歯', 'の', '健', '診', 'も', '行い', 'ます', '。', '対象', 'の', '方', 'に', 'は', '1', '歳', '○', 'か月', 'に', '達する', '月', 'の', '(', '上旬', '/', '中旬', '/', '下旬', ')', 'に', '通知', 'さ', 'れ', 'ます', '。', '[UNK]', '詳しく', 'は', 'こちら', '(', '自治体', 'HP', '内', '関連', 'ページ', 'の', 'UR', '##L', ')', '<', '保健', '##所', '>', '1', '歳', '##児', '健', '診', 'は', '保健', '##所', 'で', 'は', '実施', 'し', 'て', 'い', 'ませ', 'ん', '。', '○', '○', '市', 'で', 'は', '、', '3', '・', '4', 'か月', '健', '診', '、', '1', '歳', '6', 'か月', '歯科', '健', '診', '、', '3', '歳', '##児', '健', '診', 'を', '無料', 'で', '行っ', 'て', 'い', 'ます', '。', 'また', '、', '6', '・', '7', 'か月', '健', '診', '、', '9', '・', '10', 'か月', '健', '診', '、', '1', '歳', '6', 'か月', '健', '診', 'について', 'は', '、', '受', '##診', '票', 'を', '郵', '##送', 'し', 'て', 'い', 'ます', '。', '●', '●', '県内', '(', '1', '歳', '6', 'か月', '健', '診', 'は', '○', '○', '市内', 'のみ', ')', 'の', '契約', '医療', '機関', 'に', '受', '##診', '票', 'を', 'お', '持ち', 'ください', '。', '契約', '医療', '機関', 'について', 'は', 'こちら', 'を', 'ご', '##覧', 'ください', '。', '(', '自治体', 'HP', '内', '関連', 'ページ', 'の', 'UR', '##L', ')']
# ----------
# ['<', '3', '歳', '>', '3', '歳', '##児', '健', '診', 'で', '尿', 'が', '取れ', 'ない', '場合', 'でも', '、', '健', '診', '後', '、', '4', '歳', 'に', 'なる', '前日', 'まで', 'に', '健', '診', '受付', '時間', '内', 'に', '、', '尿', 'を', 'お', '持ち', 'いただ', '##けれ', 'ば', '追加', 'で', '検査', 'でき', 'ます', '。', 'お', '##子', '##さん', 'の', '成長', 'に', '合わせ', 'て', 'お', '持ち', 'ください', '。', 'また', '、', '健', '診', 'の', '朝', 'の', '尿', 'が', '難しい', '場合', 'は', '、', '健', '診', '会場', 'で', 'お', '取り', 'いただ', '##く', 'こと', 'も', 'でき', 'ます', '。', '3', '歳', '##児', '健', '診', 'は', '子ども', 'の', '3', '歳', 'の', '誕生', '月', 'に', '通知', 'さ', 'れ', 'ます', 'ので', '、', '指定', 'の', '保健', '相談', '所', 'にて', '受', '##診', 'し', 'て', 'ください', '。', '[UNK]', '詳しく', 'は', 'こちら', '(', '自治体', 'HP', '内', '関連', 'ページ', 'の', 'UR', '##L', ')', '健', '診', 'の', '日時', 'や', '場所', 'は', 'お', '住まい', 'の', '地域', 'により', '異なり', 'ます', '。', '次', 'の', '健', '診', 'の', '日時', '等', 'は', '電話', 'で', 'お', '問い合わせ', 'ください', '。', '[UNK]', 'お', '問い合わせ', '(', '自治体', 'の', '担当', '課', '等', 'の', '名称', ')', '(', '電話', '番号', ')/', '##(', '開', '庁', '時間', ')']
# ----------
# ['<', '5', '才', '>', '<', '息子', '>', '<', '最近', '>', 'ご', '心配', 'です', 'ね', '。', '赤ちゃん', 'の', '成長', 'や', '性格', '、', '生活', '環境', 'や', '事情', 'によって', '解決', '策', 'が', '違い', 'ます', '。', 'まずは', '保健', '師', 'に', 'ご', '相談', 'ください', '。', 'AAA', '保健', '相談', '所', ':', '##(', '電話', '番号', ')(', '##○', '時', '○', '分', 'から', '○', '時', '○', '分', ')', 'BB', '##B', '保健', '相談', '所', ':', '##(', '電話', '番号', ')(', '##○', '時', '○', '分', 'から', '○', '時', '○', '分', ')']
# ----------
# ['<', '7', 'か月', '>', '受', '##診', '票', 'を', '再', '発行', 'し', 'ます', '。', '(', '自治体', 'の', '担当', '課', 'や', '子育て', 'センター', '等', 'の', '名称', ')', 'へ', 'お', '問い合わせ', 'ください', '。', '[UNK]', 'お', '問い合わせ', '(', '自治体', 'の', '担当', '課', 'や', '子育て', 'センター', '等', 'の', '名称', ')', '(', '電話', '番号', ')/', '##(', '開', '庁', '時間', ')']
# ----------
# ['<', 'AD', '##HD', '>', 'AD', '##HD', 'は', 'At', '##te', '##n', '##t', '##ion', 'Def', '##ic', '##it', 'Hy', '##per', '##act', '##iv', '##ity', 'Dis', '##ord', '##er', 'の', '略', 'で', '、', '発達', '段階', 'に', '不', '釣り', '##合い', 'な', '注意', '力', 'や', '衝動', '性', '、', '多', '動', '性', 'を', '特徴', 'と', 'する', '神経', '発達', '症', 'もしくは', '行動', '障害', 'です', '。', 'お', '##子', '##さん', 'の', '成長', 'や', '性格', '、', '生活', '環境', 'や', '事情', 'によって', '解決', '策', 'が', '違い', 'ます', '。', 'まずは', '保健', '師', 'に', 'ご', '相談', 'ください', '。', 'AAA', '保健', '相談', '所', ':', '##(', '電話', '番号', ')(', '##○', '時', '○', '分', 'から', '○', '時', '○', '分', ')', 'BB', '##B', '保健', '相談', '所', ':', '##(', '電話', '番号', ')(', '##○', '時', '○', '分', 'から', '○', '時', '○', '分', ')']
# ----------
# ['<', 'BC', '##G', '>', 'BC', '##G', 'と', 'は', '結核', 'を', '予防', 'する', 'ワクチン', 'の', '通称', 'です', '。', '生後', '5', 'か月', 'から', '7', 'か月', '(', '生後', '1', '歳', 'に', '至る', 'まで', ')', 'の', '間', 'に', '接種', 'する', 'こと', 'と', 'なっ', 'て', 'い', 'ます', '。', '[UNK]', '詳しく', 'は', 'こちら', '(', '自治体', 'HP', '内', '関連', 'ページ', 'の', 'UR', '##L', ')']
# ----------
# ['<', 'LGBT', '>', 'LGBT', 'と', 'は', 'セク', '##シャル', '##・', '##マイ', '##ノ', '##リティ', '、', '性的', '少数', '者', 'を', '表す', '総称', 'です', '。', 'L', '(', 'レズビアン', ')', 'は', '同性', 'を', '好き', 'に', 'なる', '女性', 'G', '(', 'ゲイ', ')', 'は', '同性', 'を', '好き', 'に', 'なる', '男性', 'B', '(', 'バイ', '##セク', '##シュア', '##ル', ')', 'は', '性別', 'に', 'かかわら', 'ず', '恋愛', '対象', 'に', 'なる', '人', 'T', '(', 'トランス', '##ジェン', '##ダー', ')', 'は', '身体', '的', 'な', '性別', 'と', '自', '##認', 'する', '性', 'が', '一致', 'し', 'ない', '(', '性', '別', '違和', ')', '人', '。', '性', '同一', '性', '障害', 'の', '人', 'が', '含ま', 'れ', 'ます', '。', '性', '分化', '疾患', '(', 'DS', '##D', ')', 'など', 'も', 'あり', '、', '実は', 'から', 'だ', 'の', '性', 'も', '単純', 'に', 'は', '二', '分', 'でき', 'ませ', 'ん', '。', 'SO', '##G', '##I', '(', 'ソ', '##ギ', ')', 'と', '略さ', 'れる', '場合', 'が', '増え', 'て', 'い', 'ます', '。', 'SO', '=', 'Se', '##x', '##ual', 'Or', '##ient', '##ation', '(', '性', '的', '指向', ')', 'GI', '=', 'Gen', '##der', 'I', '##de', '##n', '##t', '##ity', '(', '性', '自', '##認', ')']
# ----------

# %%
# context_length <= 256 となるように分割する
max([len(t) for t in text_group_tokens])
# Out:
# 5375

# %%
documents = []
for t in text_group_tokens:
    if len(t) <= 256:
        documents.append(t)
    else:
        tmp = t[:]
        while len(tmp) > 256:
            documents.append(tmp[:256])
            # 半分ずらす
            tmp = tmp[128:]
        if len(tmp) > 0:
            documents.append(tmp)

# %%
len(documents)
# Out:
# 412

# %%
max([len(t) for t in documents])
# Out:
# 256

# %%
print(documents[:100])
# Out:
# [['赤ちゃん', 'の', '成長', 'や', '性格', '、', '生活', '環境', 'や', '事情', 'によって', '解決', '策', 'が', '違い', 'ます', '。', '保健', '師', 'に', 'ご', '相談', 'ください', '。', 'お', '##話', 'を', '伺', '##っ', 'て', '一緒', 'に', '考え', 'ましょ', 'う', '。', 'AAA', '保健', '相談', '所', ':', '##(', '電話', '番号', ')(', '##○', '時', '○', '分', 'から', '○', '時', '○', '分', ')', 'BB', '##B', '保健', '相談', '所', ':', '##(', '電話', '番号', ')(', '##○', '時', '○', '分', 'から', '○', '時', '○', '分', ')'], ['(', '自治体', 'の', '発行', 'する', '広報', '誌', ')', 'は', '、', '毎月', '○', '回', '(', '##○', '日', '・', '○', '日', ')', '発行', 'し', '、', '市内', '全', '世帯', 'に', '各', '##戸', '配布', 'し', 'て', 'い', 'ます', '。', '発行', '日', 'を', '過ぎ', 'て', 'も', '届か', 'ない', '場合', 'は', '、', 'お', '##手', '##数', 'です', 'が', '、', '(', '自治体', 'の', '担当', '課', '等', ')', 'へ', '連絡', 'し', 'て', 'ください', '。', '[UNK]', 'お', '問い合わせ', '(', '自治体', 'の', '担当', '課', '等', 'の', '名称', ')', '(', '電話', '番号', ')/', '##(', '開', '庁', '時間', ')', '[UNK]', 'その他', 'の', '配布', '場所', '等', '、', '詳しく', 'は', 'こちら', '(', '自治体', 'HP', '内', '関連', 'ページ', 'の', 'UR', '##L', ')'], ['<', '10', 'か月', '>', '受', '##診', '票', 'を', '再', '発行', 'し', 'ます', '。', '(', '自治体', 'の', '担当', '課', 'や', '子育て', 'センター', '等', 'の', '名称', ')', 'へ', 'お', '問い合わせ', 'ください', '。', '[UNK]', 'お', '問い合わせ', '(', '自治体', 'の', '担当', '課', 'や', '子育て', 'センター', '等', 'の', '名称', ')', '(', '電話', '番号', ')/', '##(', '開', '庁', '時間', ')'], ['<', '1', '歳', '>', '<', '6', 'か月', '>', '1', '歳', '6', 'か月', '児', '健', '診', 'は', '母子', '保健', '法', 'に', '定め', 'られ', 'た', '子ども', 'の', '定期', '健', '診', 'の', '一つ', 'です', '。', '子ども', 'の', '発達', 'の', '状況', 'を', '確認', 'する', 'とともに', '、', '歯', 'の', '健', '診', 'も', '行い', 'ます', '。', '対象', 'の', '方', 'に', 'は', '1', '歳', '○', 'か月', 'に', '達する', '月', 'の', '(', '上旬', '/', '中旬', '/', '下旬', ')', 'に', '通知', 'さ', 'れ', 'ます', '。', '[UNK]', '詳しく', 'は', 'こちら', '(', '自治体', 'HP', '内', '関連', 'ページ', 'の', 'UR', '##L', ')', '<', '保健', '##所', '>', '1', '歳', '##児', '健', '診', 'は', '保健', '##所', 'で', 'は', '実施', 'し', 'て', 'い', 'ませ', 'ん', '。', '○', '○', '市', 'で', 'は', '、', '3', '・', '4', 'か月', '健', '診', '、', '1', '歳', '6', 'か月', '歯科', '健', '診', '、', '3', '歳', '##児', '健', '診', 'を', '無料', 'で', '行っ', 'て', 'い', 'ます', '。', 'また', '、', '6', '・', '7', 'か月', '健', '診', '、', '9', '・', '10', 'か月', '健', '診', '、', '1', '歳', '6', 'か月', '健', '診', 'について', 'は', '、', '受', '##診', '票', 'を', '郵', '##送', 'し', 'て', 'い', 'ます', '。', '●', '●', '県内', '(', '1', '歳', '6', 'か月', '健', '診', 'は', '○', '○', '市内', 'のみ', ')', 'の', '契約', '医療', '機関', 'に', '受', '##診', '票', 'を', 'お', '持ち', 'ください', '。', '契約', '医療', '機関', 'について', 'は', 'こちら', 'を', 'ご', '##覧', 'ください', '。', '(', '自治体', 'HP', '内', '関連', 'ページ', 'の', 'UR', '##L', ')'], ['<', '3', '歳', '>', '3', '歳', '##児', '健', '診', 'で', '尿', 'が', '取れ', 'ない', '場合', 'でも', '、', '健', '診', '後', '、', '4', '歳', 'に', 'なる', '前日', 'まで', 'に', '健', '診', '受付', '時間', '内', 'に', '、', '尿', 'を', 'お', '持ち', 'いただ', '##けれ', 'ば', '追加', 'で', '検査', 'でき', 'ます', '。', 'お', '##子', '##さん', 'の', '成長', 'に', '合わせ', 'て', 'お', '持ち', 'ください', '。', 'また', '、', '健', '診', 'の', '朝', 'の', '尿', 'が', '難しい', '場合', 'は', '、', '健', '診', '会場', 'で', 'お', '取り', 'いただ', '##く', 'こと', 'も', 'でき', 'ます', '。', '3', '歳', '##児', '健', '診', 'は', '子ども', 'の', '3', '歳', 'の', '誕生', '月', 'に', '通知', 'さ', 'れ', 'ます', 'ので', '、', '指定', 'の', '保健', '相談', '所', 'にて', '受', '##診', 'し', 'て', 'ください', '。', '[UNK]', '詳しく', 'は', 'こちら', '(', '自治体', 'HP', '内', '関連', 'ページ', 'の', 'UR', '##L', ')', '健', '診', 'の', '日時', 'や', '場所', 'は', 'お', '住まい', 'の', '地域', 'により', '異なり', 'ます', '。', '次', 'の', '健', '診', 'の', '日時', '等', 'は', '電話', 'で', 'お', '問い合わせ', 'ください', '。', '[UNK]', 'お', '問い合わせ', '(', '自治体', 'の', '担当', '課', '等', 'の', '名称', ')', '(', '電話', '番号', ')/', '##(', '開', '庁', '時間', ')'], ['<', '5', '才', '>', '<', '息子', '>', '<', '最近', '>', 'ご', '心配', 'です', 'ね', '。', '赤ちゃん', 'の', '成長', 'や', '性格', '、', '生活', '環境', 'や', '事情', 'によって', '解決', '策', 'が', '違い', 'ます', '。', 'まずは', '保健', '師', 'に', 'ご', '相談', 'ください', '。', 'AAA', '保健', '相談', '所', ':', '##(', '電話', '番号', ')(', '##○', '時', '○', '分', 'から', '○', '時', '○', '分', ')', 'BB', '##B', '保健' ...

# %% [markdown]
# ## 指定のファイルからQA生成

# %%
def document_preprocess(documents, device):
    res = []
    for d in documents:
        res.append(['[CLS]'])
        res[-1].extend(d)
        res[-1].append('[SEP]')
        while len(res[-1]) < 256+2:
            res[-1].append('[PAD]')
        res[-1] =  tokenizer.convert_tokens_to_ids(res[-1])
    return torch.tensor(res, dtype=torch.long, device=device)

# %%
def docs_to_qas(c_ids, trainer, tokenizer):
    
    res = []
    
    tmp = [[] for i in range(3)]
    
    for n in range(3):
        batch_prior_q_ids, batch_prior_start, batch_prior_end, prior_z_prob = trainer.generate_prior(c_ids)
    
        for i in range(len(c_ids)):
            dic = {}
            dic['context'] = to_string(c_ids[i], tokenizer)
            dic['question'] = to_string(batch_prior_q_ids[i], tokenizer)
            dic['answer'] = to_string(c_ids[i][batch_prior_start[i]:(batch_prior_end[i] + 1)], tokenizer)
            tmp[n].append(dic)
    
    for i in range(len(c_ids)):
        for n in range(3):
            res.append(tmp[n][i])
    
    return res

# %%
def qa_generation(text_dir, save_dir, trainer, tokenizer, save_encoding='utf-8'):
    all_text = open(text_dir, 'r', encoding='utf-8').read()
    
    # 大区分
    text_group = all_text.split('\n\n')
    text_group_tokens = [tokenizer.tokenize(t) for t in text_group]
    
    # context_length <= 256 となるように分割する
    documents = []
    for t in text_group_tokens:
        if len(t) <= 256:
            documents.append(t)
        else:
            tmp = t[:]
            while len(tmp) > 256:
                documents.append(tmp[:256])
                # 半分ずらす
                tmp = tmp[128:]
            if len(tmp) > 0:
                documents.append(tmp)
                
    # ドキュメントの前処理
    document_ids = document_preprocess(documents, args.device)
    
    batch = []
    idx = 0
    while idx < len(document_ids):
        batch.append(document_ids[idx:idx+32])
        idx += 32
    
    results = []
    for data in batch:
        results.extend( docs_to_qas(data, trainer, tokenizer) )

    df = pd.DataFrame(results, columns=['question', 'answer'])
    df.to_csv(save_dir, encoding=save_encoding)
    
    return df

# %%
text_dir= '../data/kosodate/document_v2.txt'
save_dir = '../data/kosodate/result.csv'

# %%
qa_generation(text_dir, save_dir, trainer, tokenizer, save_encoding='cp932')
# Out:
#                                      question  \
# 0     出産 の 成長 や 出産 の 相談 は どこ に すれ ば いい です か ?
# 1     出産 の 成長 や 出産 の 相談 は どこ に すれ ば いい です か ?
# 2     出産 の 成長 や 出産 の 相談 は どこ に すれ ば いい です か ?
# 3        ( 自治体 の 古 着 など の 配布 場所 を 教え て ください 。
# 4        ( 自治体 の 古 着 など の 配布 場所 を 教え て ください 。
# ...                                       ...
# 1231              養子 縁組 の 届出 場所 を 教え て ください 。
# 1232              養子 縁組 の 届出 場所 を 教え て ください 。
# 1233            ○ ○ 市 の 駐輪 場 について 教え て ください 。
# 1234            ○ ○ 市 の 駐輪 場 について 教え て ください 。
# 1235            ○ ○ 市 の 駐輪 場 について 教え て ください 。
#
#                                                  answer
# 0     赤ちゃん の 成長 や 性格 、 生活 環境 や 事情 によって 解決 策 が 違い ます ...
# 1           BBB 保健 相談 所 :( 電話 番号 )(○ 時 ○ 分 から ○ 時 ○ 分 )
# 2     赤ちゃん の 成長 や 性格 、 生活 環境 や 事情 によって 解決 策 が 違い ます ...
# 3     [UNK] その他 の 配布 場所 等 、 詳しく は こちら ( 自治体 HP 内 関連 ...
# 4     [UNK] その他 の 配布 場所 等 、 詳しく は こちら ( 自治体 HP 内 関連 ...
# ...                                                 ...
# 1231  養子 縁組 は 届出 によって 法的 に 嫡出 親子 関係 が 成立 し ます 。 養子 縁...
# 1232  養子 縁組 は 届出 によって 法的 に 嫡出 親子 関係 が 成立 し ます 。 養子 縁...
# 1233  ○ ○ 市 の 駐輪場 について は こちら を ご覧 ください 。 ( 自治体 HP 内 ...
# 1234  ○ ○ 市 の 駐輪場 について は こちら を ご覧 ください 。 ( 自治体 HP 内 ...
# 1235  ○ ○ 市 の 駐輪場 について は こちら を ご覧 ください 。 ( 自治体 HP 内 ...
#
# [1236 rows x 2 columns]
